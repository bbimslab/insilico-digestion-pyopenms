# %%
from Bio.Seq import Seq
from Bio.SeqRecord import SeqRecord
from Bio import SeqIO
import pandas as pd

# List of sequences as SeqRecord objects
sequences = [
    SeqRecord(Seq("MKWVTFISLLFLFSSAYS"), id="Protein1", description="Description of Protein1"),
    SeqRecord(Seq("LLLKAGAGAGAWWDAGVVF"), id="Protein2", description="Description of Protein2"),
    SeqRecord(Seq("VVVVKKKRRRNNNDDD"), id="Protein3", description="Description of Protein3"),
]

# Write to FASTA file
with open("proteins.fasta", "w") as output_file:
    SeqIO.write(sequences, output_file, "fasta")

# %%
import csv

# Load the CSV file
file_path = "proteins.csv"  # Update with the path to your file
output_fasta = "proteins.fasta"

# Read CSV and write to FASTA
with open(file_path, "r") as csv_file, open(output_fasta, "w") as fasta_file:
    reader = csv.DictReader(csv_file)
    for row in reader:
        protein_id = row['Id']  # Column name for protein ID
        sequence = row['Sequence']    # Column name for sequence
        fasta_file.write(f">{protein_id}\n")  # Write header
        fasta_file.write(f"{sequence}\n")    # Write sequence

# %% [markdown]
# Validating Fasta Sequence

# %%
from Bio import SeqIO

def validate_fasta(file_path):
    try:
        # Try parsing the FASTA file
        for record in SeqIO.parse(file_path, "fasta"):
            if not record.seq:  # Check for empty sequences
                print(f"Warning: Sequence for {record.id} is empty.")
            else:
                print(f"Sequence {record.id} is valid.")
    except Exception as e:
        print(f"Error: {e}")

# Example usage
file_path = "ENDO_MASTER_LCMS_PLASMA.fasta"
validate_fasta(file_path)
# Out:
# Sequence tr|A0A481SHK9|A0A481SHK9_HUMAN is valid.
# Sequence tr|B3VL17|B3VL17_HUMAN is valid.
# Sequence tr|Q9H1I6|Q9H1I6_HUMAN is valid.
# Sequence tr|E9PFT6|E9PFT6_HUMAN is valid.
# Sequence tr|B2RBS8|B2RBS8_HUMAN is valid.
# Sequence tr|A0A024R1Z6|Release is valid.
# Sequence tr|G3V1N2|G3V1N2_HUMAN is valid.
# Sequence tr|D9ZGF2|D9ZGF2_HUMAN is valid.
# Sequence tr|A0A075B6Z2|A0A075B6Z2_HUMAN is valid.
# Sequence tr|Q9HAR8|Q9HAR8_HUMAN is valid.
# Sequence sp|P0DOX5|IGG1_HUMAN is valid.
# Sequence tr|B0YJC4|B0YJC4_HUMAN is valid.
# Sequence sp|P0C0S8|H2A1_HUMAN is valid.
# Sequence tr|A0A385HVZ2|A0A385HVZ2_HUMAN is valid.
# Sequence tr|A0A024QZJ4|A0A024QZJ4_HUMAN is valid.
# Sequence tr|B4DI63|B4DI63_HUMAN is valid.
# Sequence tr|H0YCU9|H0YCU9_HUMAN is valid.
# Sequence tr|H6VRF8|H6VRF8_HUMAN is valid.
# Sequence tr|B4DPP6|B4DPP6_HUMAN is valid.
# Sequence tr|D2JYH4|D2JYH4_HUMAN is valid.
# Sequence tr|C8C504|C8C504_HUMAN is valid.
# Sequence tr|A0A481SHK9|A0A481SHK9_HUMAN is valid.
# Sequence tr|B3VL17|B3VL17_HUMAN is valid.
# Sequence tr|B4DW52|B4DW52_HUMAN is valid.
# Sequence tr|A0A2R8Y793|A0A2R8Y793_HUMAN is valid.
# Sequence tr|D9ZGF2|D9ZGF2_HUMAN is valid.
# Sequence sp|P02452|CO1A1_HUMAN is valid.
# Sequence sp|Q6S8J3|POTEE_HUMAN is valid.
# Sequence tr|A0A385HVZ2|A0A385HVZ2_HUMAN is valid.
# Sequence sp|Q562R1|ACTBL_HUMAN is valid.
# Sequence tr|A0A2R3Z0D6|A0A2R3Z0D6_HUMAN is valid.
# Sequence tr|V9HVZ7|V9HVZ7_HUMAN is valid.
# Sequence tr|A0A384NPX1|A0A384NPX1_HUMAN is valid.
# Sequence tr|Q60FE5|Q60FE5_HUMAN is valid.
# Sequence tr|V9HWE1|V9HWE1_HUMAN is valid.
# Sequence tr|B4DI63|B4DI63_HUMAN is valid.
# Sequence tr|B3KPS3|B3KPS3_HUMAN is valid.
# Sequence tr|H6VRG2|H6VRG2_HUMAN is valid.
# Sequence tr|A0A384P5H7|A0A384P5H7_HUMAN is valid.
# Sequence tr|B4E3P1|B4E3P1_HUMAN is valid.
# Sequence tr|A0A4P8J2G1|A0A4P8J2G1_HUMAN is valid.
# Sequence tr|S6B2C3|S6B2C3_HUMAN is valid.
# Sequence tr|Q5TCU3|Q5TCU3_HUMAN is valid.
# Sequence tr|A0A0S2Z3H5|A0A0S2Z3H5_HUMAN is valid.
# Sequence tr|A0A0S2Z2Z6|A0A0S2Z2Z6_HUMAN is valid.
# Sequence tr|Q5U0D2|Q5U0D2_HUMAN is valid.
# Sequence tr|A0A024QZJ4|A0A024QZJ4_HUMAN is valid.
# Sequence sp|Q14315|FLNC_HUMAN is valid.
# Sequence tr|A0A024R321|Release is valid.
# Sequence tr|Q6N094|Q6N094_HUMAN is valid.
# Sequence tr|Q6MZV7|Q6MZV7_HUMAN is valid.
# Sequence sp|P0C0S8|H2A1_HUMAN is valid.
# Sequence sp|P35908|K22E_HUMAN is valid.
# Sequence tr|A0A075B6Z2|A0A075B6Z2_HUMAN is valid.
# Sequence tr|A0A0U4BW16|A0A0U4BW16_HUMAN is valid.
# Sequence tr|Q5TCI8|Q5TCI8_HUMAN is valid.
# Sequence tr|W8QEH3|W8QEH3_HUMAN is valid.
# Sequence tr|A0A024R1Z6|Release is valid.
# Sequence tr|B3KS75|B3KS75_HUMAN is valid.
# Sequence tr|A0A024QZZ7|Release is valid.
# Sequence tr|B7Z2W3|B7Z2W3_HUMAN is valid.
# Sequence tr|A0A7I2V4Y4|A0A7I2V4Y4_HUMAN is valid.
# Sequence tr|Q6FHG6|Q6FHG6_HUMAN is valid.
# Sequence tr|Q6MZX9|Q6MZX9_HUMAN is valid.
# Sequence tr|Q6ZW64|Q6ZW64_HUMAN is valid.
# Sequence tr|A0A384NYT8|A0A384NYT8_HUMAN is valid.
# Sequence tr|A0A8I5KZ38|A0A8I5KZ38_HUMAN is valid.
# Sequence tr|A0A024QZN4|Release is valid.
# Sequence tr|H7C2E7|H7C2E7_HUMAN is valid.
# Sequence tr|B4DTD5|B4DTD5_HUMAN is valid.
# Sequence tr|A0A140VJJ6|A0A140VJJ6_HUMAN is valid.
# Sequence tr|A0A6Q8PF43|A0A6Q8PF43_HUMAN is valid.
# Sequence tr|A0A024R6I7|Release is valid.
# Sequence sp|Q2M2I3|FA83E_HUMAN is valid.
# Sequence tr|H7C0A1|H7C0A1_HUMAN is valid.
# Sequence tr|E9PHT9|E9PHT9_HUMAN is valid.
# Sequence tr|F6M2K3|F6M2K3_HUMAN is valid.
# Sequence tr|K7EQQ3|K7EQQ3_HUMAN is valid.
# Sequence tr|A0A1B0GVI3|A0A1B0GVI3_HUMAN is valid.
# Sequence tr|H0Y3H2|H0Y3H2_HUMAN is valid.
# Sequence tr|A0A1B4WRL5|A0A1B4WRL5_HUMAN is valid.
# Sequence tr|A0A481SHK9|A0A481SHK9_HUMAN is valid.
# Sequence tr|Q9H1I6|Q9H1I6_HUMAN is valid.
# Sequence tr|Q9HAR8|Q9HAR8_HUMAN is valid.
# Sequence tr|A8K9P0|A8K9P0_HUMAN is valid.
# Sequence tr|A0A075B6Z2|A0A075B6Z2_HUMAN is valid.
# Sequence tr|G3V1N2|G3V1N2_HUMAN is valid.
# Sequence tr|A0A1B0GVI3|A0A1B0GVI3_HUMAN is valid.
# Sequence tr|B4DI63|B4DI63_HUMAN is valid.
# Sequence tr|A0A385HVZ2|A0A385HVZ2_HUMAN is valid.
# Sequence tr|B0YJC4|B0YJC4_HUMAN is valid.
# Sequence sp|P0DOX5|IGG1_HUMAN is valid.
# Sequence tr|Q53HU8|Q53HU8_HUMAN is valid.
# Sequence tr|H0YCU9|H0YCU9_HUMAN is valid.
# Sequence tr|Q6FH10|Q6FH10_HUMAN is valid.
# Sequence tr|H6VRF8|H6VRF8_HUMAN is valid.
# Sequence tr|A0A024R3E3|A0A024R3E3_HUMAN is valid.
# Sequence tr|A0A0U4BW16|A0A0U4BW16_HUMAN is valid.
# Sequence tr|A0A024QZJ4|A0A024QZJ4_HUMAN is valid.
# Sequence tr|B7ZW00|B7ZW00_HUMAN is valid.
# Sequence tr|B4DPP6|B4DPP6_HUMAN is valid.
# Sequence tr|D2JYH4|D2JYH4_HUMAN is valid.
# Sequence tr|A8K3K1|A8K3K1_HUMAN is valid.
# Sequence sp|P02452|CO1A1_HUMAN is valid.
# Sequence tr|B4DW52|B4DW52_HUMAN is valid.
# Sequence tr|A0A804GS07|A0A804GS07_HUMAN is valid.
# Sequence sp|Q6S8J3|POTEE_HUMAN is valid.
# Sequence tr|V9HVZ7|V9HVZ7_HUMAN is valid.
# Sequence sp|Q562R1|ACTBL_HUMAN is valid.
# Sequence tr|A0A481SHK9|A0A481SHK9_HUMAN is valid.
# Sequence tr|C8C504|C8C504_HUMAN is valid.
# Sequence tr|B7ZW00|B7ZW00_HUMAN is valid.
# Sequence tr|A0A1B0GVI3|A0A1B0GVI3_HUMAN is valid.
# Sequence tr|Q9H319|Q9H319_HUMAN is valid.
# Sequence tr|A0A384NPX1|A0A384NPX1_HUMAN is valid.
# Sequence tr|A0A2R3Z0D6|A0A2R3Z0D6_HUMAN is valid.
# Sequence tr|A0A0K2BMD8|A0A0K2BMD8_HUMAN is valid.
# Sequence tr|A0A385HVZ2|A0A385HVZ2_HUMAN is valid.
# Sequence tr|Q60FE5|Q60FE5_HUMAN is valid.
# Sequence tr|H6VRF8|H6VRF8_HUMAN is valid.
# Sequence tr|A0A0S2Z3H5|A0A0S2Z3H5_HUMAN is valid.
# Sequence tr|H6VRG2|H6VRG2_HUMAN is valid.
# Sequence tr|B0YJC4|B0YJC4_HUMAN is valid.
# Sequence tr|Q53HU8|Q53HU8_HUMAN is valid.
# Sequence sp|P0DOX5|IGG1_HUMAN is valid.
# Sequence tr|B4DI63|B4DI63_HUMAN is valid.
# Sequence tr|Q5TCU3|Q5TCU3_HUMAN is valid.
# Sequence sp|Q71U36|TBA1A_HUMAN is valid.
# Sequence tr|Q6PIL8|Q6PIL8_HUMAN is valid.
# Sequence tr|A0A4P8J2G1|A0A4P8J2G1_HUMAN is valid.
# Sequence tr|B3KPS3|B3KPS3_HUMAN is valid.
# Sequence tr|A0A075B6Z2|A0A075B6Z2_HUMAN is valid.
# Sequence tr|A0A0K0K1I0|A0A0K0K1I0_HUMAN is valid.
# Sequence tr|B4DNG6|B4DNG6_HUMAN is valid.
# Sequence sp|Q14315|FLNC_HUMAN is valid.
# Sequence tr|B3KS75|B3KS75_HUMAN is valid.
# Sequence tr|A0A2R8Y5V9|A0A2R8Y5V9_HUMAN is valid.
# Sequence tr|Q5U0D2|Q5U0D2_HUMAN is valid.
# Sequence sp|P01861|IGHG4_HUMAN is valid.
# Sequence tr|Q6FH10|Q6FH10_HUMAN is valid.
# Sequence tr|A0A0S2Z3G9|A0A0S2Z3G9_HUMAN is valid.
# Sequence tr|A0A384N669|A0A384N669_HUMAN is valid.
# Sequence tr|A0A1W2PQU7|A0A1W2PQU7_HUMAN is valid.
# Sequence tr|A0A7R6KYT5|A0A7R6KYT5_HUMAN is valid.
# Sequence tr|H0YJW3|H0YJW3_HUMAN is valid.
# Sequence tr|Q6FHG6|Q6FHG6_HUMAN is valid.
# Sequence tr|M1VPF4|M1VPF4_HUMAN is valid.
# Sequence tr|A0A494BZZ2|A0A494BZZ2_HUMAN is valid.
# Sequence sp|P04259|K2C6B_HUMAN is valid.
# Sequence tr|F8VUF6|F8VUF6_HUMAN is valid.
# Sequence sp|Q05707|COEA1_HUMAN is valid.
# Sequence tr|H7C0A1|H7C0A1_HUMAN is valid.
# Sequence tr|A0A384P5H7|A0A384P5H7_HUMAN is valid.
# Sequence tr|A0A384MDP3|A0A384MDP3_HUMAN is valid.
# Sequence tr|Q0VAS5|Q0VAS5_HUMAN is valid.
# Sequence tr|K7EPT8|K7EPT8_HUMAN is valid.
# Sequence tr|Q96GE1|Q96GE1_HUMAN is valid.
# Sequence tr|Q562Z4|Q562Z4_HUMAN is valid.
# Sequence tr|Q5TCI8|Q5TCI8_HUMAN is valid.
# Sequence tr|A0A024R3E3|A0A024R3E3_HUMAN is valid.
# Sequence tr|A0A0S2Z2Z6|A0A0S2Z2Z6_HUMAN is valid.
# Sequence tr|B4E216|B4E216_HUMAN is valid.
# Sequence tr|Q562Q5|Q562Q5_HUMAN is valid.
# Sequence sp|P06702|S10A9_HUMAN is valid.
# Sequence tr|C8C504|C8C504_HUMAN is valid.
# Sequence tr|B3VL31|B3VL31_HUMAN is valid.
# Sequence tr|Q52MT0|Q52MT0_HUMAN is valid.
# Sequence tr|A0A075B6Z2|A0A075B6Z2_HUMAN is valid.
# Sequence tr|Q9H1I6|Q9H1I6_HUMAN is valid.
# Sequence tr|H6VRF8|H6VRF8_HUMAN is valid.
# Sequence tr|G3V1N2|G3V1N2_HUMAN is valid.
# Sequence tr|A0A248RGE3|A0A248RGE3_HUMAN is valid.
# Sequence tr|S4R407|S4R407_HUMAN is valid.
# Sequence sp|P16402|H13_HUMAN is valid.
# Sequence tr|Q8NEQ1|Q8NEQ1_HUMAN is valid.
# Sequence sp|Q5U649|CL060_HUMAN is valid.
# Sequence tr|A0A384NKW7|A0A384NKW7_HUMAN is valid.
# Sequence tr|D9YZU5|D9YZU5_HUMAN is valid.
# Sequence tr|B3VL17|B3VL17_HUMAN is valid.
# Sequence tr|B3VL31|B3VL31_HUMAN is valid.
# Sequence tr|Q52MT0|Q52MT0_HUMAN is valid.
# Sequence tr|Q6J1Z7|Q6J1Z7_HUMAN is valid.
# Sequence tr|C8C504|C8C504_HUMAN is valid.
# Sequence tr|A0A804GS07|A0A804GS07_HUMAN is valid.
# Sequence tr|H6VRG2|H6VRG2_HUMAN is valid.
# Sequence tr|H0YA55|H0YA55_HUMAN is valid.
# Sequence sp|A5A3E0|POTEF_HUMAN is valid.
# Sequence sp|Q6S8J3|POTEE_HUMAN is valid.
# Sequence tr|V9HWE1|V9HWE1_HUMAN is valid.
# Sequence tr|B2RBS8|B2RBS8_HUMAN is valid.
# Sequence sp|Q562R1|ACTBL_HUMAN is valid.
# Sequence tr|B3KPS3|B3KPS3_HUMAN is valid.
# Sequence tr|A0A0K2BMD8|A0A0K2BMD8_HUMAN is valid.
# Sequence sp|P35908|K22E_HUMAN is valid.
# Sequence tr|A0A024QZZ7|Release is valid.
# Sequence tr|F8VQQ4|F8VQQ4_HUMAN is valid.
# Sequence sp|Q71U36|TBA1A_HUMAN is valid.
# Sequence tr|A0A1B0GVI3|A0A1B0GVI3_HUMAN is valid.
# Sequence tr|Q0IIN1|Q0IIN1_HUMAN is valid.
# Sequence tr|A0A384NYT8|A0A384NYT8_HUMAN is valid.
# Sequence tr|H7C0A1|H7C0A1_HUMAN is valid.
# Sequence tr|A0A7P0T945|A0A7P0T945_HUMAN is valid.
# Sequence sp|P08727|K1C19_HUMAN is valid.
# Sequence tr|Q8IWP6|Q8IWP6_HUMAN is valid.
# Sequence tr|Q0VAS5|Q0VAS5_HUMAN is valid.
# Sequence tr|G3V2A3|G3V2A3_HUMAN is valid.
# Sequence tr|A0A248RGE3|A0A248RGE3_HUMAN is valid.
# Sequence tr|F6M2K3|F6M2K3_HUMAN is valid.
# Sequence tr|B4DQQ2|B4DQQ2_HUMAN is valid.
# Sequence tr|A0A075B6Z2|A0A075B6Z2_HUMAN is valid.
# Sequence sp|P16402|H13_HUMAN is valid.
# Sequence sp|Q5XKE5|K2C79_HUMAN is valid.
# Sequence sp|P04259|K2C6B_HUMAN is valid.
# Sequence sp|P13647|K2C5_HUMAN is valid.
# Sequence tr|S4R407|S4R407_HUMAN is valid.
# Sequence sp|P02452|CO1A1_HUMAN is valid.
# Sequence sp|P43652|AFAM_HUMAN is valid.
# Sequence sp|P06733|ENOA_HUMAN is valid.
# Sequence sp|O14791|APOL1_HUMAN is valid.
# Sequence sp|P02749|APOH_HUMAN is valid.
# Sequence sp|Q96KN2|CNDP1_HUMAN is valid.
# Sequence sp|P07738|PMGE_HUMAN is valid.
# Sequence sp|P23560|BDNF_HUMAN is valid.
# Sequence sp|P04003|C4BPA_HUMAN is valid.
# Sequence sp|P20851|C4BPB_HUMAN is valid.
# Sequence sp|P00918|CAH2_HUMAN is valid.
# Sequence sp|P04040|CATA_HUMAN is valid.
# Sequence sp|P10909|CLUS_HUMAN is valid.
# Sequence sp|Q14019|COTL1_HUMAN is valid.
# Sequence sp|P00742|FA10_HUMAN is valid.
# Sequence sp|P00748|FA12_HUMAN is valid.
# Sequence sp|P13671|CO6_HUMAN is valid.
# Sequence sp|P02748|CO9_HUMAN is valid.
# Sequence sp|P36980|FHR2_HUMAN is valid.
# Sequence sp|P08185|CBG_HUMAN is valid.
# Sequence sp|P02741|CRP_HUMAN is valid.
# Sequence sp|P11021|BIP_HUMAN is valid.
# Sequence sp|P35555|FBN1_HUMAN is valid.
# Sequence sp|P30043|BLVRB_HUMAN is valid.
# Sequence sp|O00182|LEG9_HUMAN is valid.
# Sequence sp|P69905|HBA_HUMAN is valid.
# Sequence sp|P68871|HBB_HUMAN is valid.
# Sequence sp|P05546|HEP2_HUMAN is valid.
# Sequence sp|Q04756|HGFA_HUMAN is valid.
# Sequence sp|Q14520|HABP2_HUMAN is valid.
# Sequence sp|Q9Y6R7|FCGBP_HUMAN is valid.
# Sequence sp|Q06033|ITIH3_HUMAN is valid.
# Sequence sp|P05231|IL6_HUMAN is valid.
# Sequence sp|P55268|LAMB2_HUMAN is valid.
# Sequence sp|P41159|LEP_HUMAN is valid.
# Sequence sp|P00338|LDHA_HUMAN is valid.
# Sequence sp|Q13228|SBP1_HUMAN is valid.
# Sequence sp|Q8WXI7|MUC16_HUMAN is valid.
# Sequence sp|O14786|NRP1_HUMAN is valid.
# Sequence sp|Q06830|PRDX1_HUMAN is valid.
# Sequence sp|P32119|PRDX2_HUMAN is valid.
# Sequence sp|P36955|PEDF_HUMAN is valid.
# Sequence sp|P00747|PLMN_HUMAN is valid.
# Sequence sp|P07737|PROF1_HUMAN is valid.
# Sequence sp|Q9NZQ7|PD1L1_HUMAN is valid.
# Sequence sp|P02760|AMBP_HUMAN is valid.
# Sequence sp|Q15084|PDIA6_HUMAN is valid.
# Sequence sp|P05109|S10A8_HUMAN is valid.
# Sequence sp|Q92954|PRG4_HUMAN is valid.
# Sequence sp|P00734|THRB_HUMAN is valid.
# Sequence sp|P52566|GDIR2_HUMAN is valid.
# Sequence sp|P49908|SEPP1_HUMAN is valid.
# Sequence sp|P27169|PON1_HUMAN is valid.
# Sequence sp|P04278|SHBG_HUMAN is valid.
# Sequence sp|P00441|SODC_HUMAN is valid.
# Sequence sp|Q13190|STX5_HUMAN is valid.
# Sequence sp|P07996|TSP1_HUMAN is valid.
# Sequence sp|P49767|VEGFC_HUMAN is valid.
# Sequence sp|P07225|PROS_HUMAN is valid.
# Sequence sp|P04275|VWF_HUMAN is valid.
# Sequence sp|P25311|ZA2G_HUMAN is valid.

# %% [markdown]
# Trypsin digestion | Output a CSV file

# %%
import pyopenms as oms
import csv

# Specify the local FASTA file
fasta_file = "6503_trypsin.fasta"  # Replace with your FASTA file name
output_csv = "digested_peptides_6503_trypsin.csv"

# Load the protein sequence from the FASTA file
with open(fasta_file, "r") as f:
    lines = f.readlines()
    protein_sequence = "".join(line.strip() for line in lines if not line.startswith(">"))  # Exclude the header

# Convert the protein sequence to an AASequence object
protein = oms.AASequence.fromString(protein_sequence)

# Initialize the protease digestion class
digestion = oms.ProteaseDigestion()

# Set digestion enzyme (default is trypsin)
digestion.getEnzymeName()  # Should return "Trypsin"

# Set the number of missed cleavages
digestion.setMissedCleavages(2)

# Perform digestion with length constraints (7-40 residues)
min_length = 7
max_length = 40
result = []
digestion.digest(protein, result, min_length, max_length)

# Prepare peptide data for CSV output
peptides = [peptide.toString() for peptide in result]

# Write peptides to a CSV file
with open(output_csv, mode="w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["Peptide Sequence"])
    for peptide in peptides:
        writer.writerow([peptide])

print(f"Digestion complete. {len(peptides)} peptides written to {output_csv}")
# Out:
# Digestion complete. 10199 peptides written to digested_peptides_6503_trypsin.csv

# %% [markdown]
# Lys-C Digestion

# %%
import pyopenms as oms
import csv

# Specify the local FASTA file
fasta_file = "6503_lysC.fasta"  # Replace with your FASTA file name
output_csv = "digested_peptides_6503_lysC.csv"

# Load the protein sequence from the FASTA file
with open(fasta_file, "r") as f:
    lines = f.readlines()
    protein_sequence = "".join(line.strip() for line in lines if not line.startswith(">"))  # Exclude the header

# Convert the protein sequence to an AASequence object
protein = oms.AASequence.fromString(protein_sequence)

# Initialize the protease digestion class
digestion = oms.ProteaseDigestion()

# Set digestion enzyme to Lys-C
digestion.setEnzyme("Lys-C")

# Set the number of missed cleavages
digestion.setMissedCleavages(2)

# Perform digestion with length constraints (7-40 residues)
min_length = 7
max_length = 40
result = []
digestion.digest(protein, result, min_length, max_length)

# Prepare peptide data for CSV output
peptides = [peptide.toString() for peptide in result]

# Write peptides to a CSV file
with open(output_csv, mode="w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["Peptide Sequence"])
    for peptide in peptides:
        writer.writerow([peptide])

print(f"Lys-C digestion complete. {len(peptides)} peptides written to {output_csv}")
# Out:
# Lys-C digestion complete. 1093 peptides written to digested_peptides_6503_lysC.csv

# %% [markdown]
# Digested peptides to a structured csv

# %%
import pyopenms as oms
import csv

# Specify the local FASTA file
fasta_file = "insulin.fasta"  # Replace with your FASTA file name
output_csv = "digested_peptides_insulin_3.csv"

# Load the protein sequence from the FASTA file
with open(fasta_file, "r") as f:
    lines = f.readlines()
    protein_sequence = "".join(line.strip() for line in lines if not line.startswith(">"))  # Exclude the header

# Convert the protein sequence to an AASequence object
protein = oms.AASequence.fromString(protein_sequence)

# Initialize the protease digestion class
digestion = oms.ProteaseDigestion()

# Set digestion enzyme (default is trypsin)
digestion.getEnzymeName()  # Should return "Trypsin"

# Set the number of missed cleavages
digestion.setMissedCleavages(0)

# Perform digestion with length constraints (7-40 residues)
min_length = 0
max_length = 400
result = []
digestion.digest(protein, result, min_length, max_length)

# Prepare peptide data for CSV output
peptides = [peptide.toString() for peptide in result]

# Write peptides to a CSV file
with open(output_csv, mode="w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["id", "sequence"])
    for idx, peptide in enumerate(peptides, 1):
        writer.writerow([idx, peptide])

print(f"Digestion complete. {len(peptides)} peptides written to {output_csv}")
# Out:
# Digestion complete. 2 peptides written to digested_peptides_insulin_3.csv

# %% [markdown]
# Generate Molecular Formulas

# %%
import pandas as pd
import pyopenms as oms

# Load the CSV file
input_file = "md_bsa.csv"  # Replace with your file name
output_file = "mol_bsa.csv"
data = pd.read_csv(input_file)

# Function to compute molecular formula
def get_molecular_formula(sequence):
    try:
        
        seq_obj = oms.AASequence.fromString(sequence)
        return str(seq_obj.getFormula())
    except Exception as e:
        return f"Error: {e}"

# Apply the function to the Sequence column
data["MolecularFormula"] = data["sequence"].apply(get_molecular_formula)

# Save the results to a new CSV
data.to_csv(output_file, index=False)
print(f"Results saved to {output_file}")
# Out:
# Results saved to mol_bsa.csv

# %% [markdown]
# Added Oxidated Methionine modification

# %%
import pyopenms as oms
import csv

# Specify the local FASTA file
fasta_file = "insulin.fasta"  # Replace with your FASTA file name
output_csv = "md_insulin.csv"

# Load the protein sequence from the FASTA file
with open(fasta_file, "r") as f:
    lines = f.readlines()
    protein_sequence = "".join(line.strip() for line in lines if not line.startswith(">"))  # Exclude the header

# Convert the protein sequence to an AASequence object
protein = oms.AASequence.fromString(protein_sequence)

# Initialize the protease digestion class
digestion = oms.ProteaseDigestion()

# Set digestion enzyme (default is trypsin)
digestion.getEnzymeName()  # Should return "Trypsin"

# Set the number of missed cleavages
digestion.setMissedCleavages(0)

# Perform digestion with length constraints (7-40 residues)
min_length = 0
max_length = 400
result = []
digestion.digest(protein, result, min_length, max_length)

# Prepare peptide data for CSV output
peptides = [peptide.toString() for peptide in result]

# Define the oxidation modification for methionine
variable_mod_names = [b"Oxidation (M)"]
variable_modifications = oms.ModifiedPeptideGenerator.getModifications(variable_mod_names)

# Apply the variable modifications to the digested peptides
modified_peptides = []
for peptide in result:
    oms.ModifiedPeptideGenerator.applyVariableModifications(variable_modifications, peptide, 1, modified_peptides, False)

# Combine original and modified peptides
all_peptides = peptides + [peptide.toString() for peptide in modified_peptides]

# Write peptides to a CSV file
with open(output_csv, mode="w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["id", "sequence"])
    for idx, peptide in enumerate(all_peptides, 1):
        writer.writerow([idx, peptide])

print(f"Digestion complete. {len(all_peptides)} peptides written to {output_csv}")
# Out:
# Digestion complete. 2 peptides written to md_insulin.csv

# %% [markdown]
# Modified column Names | outputs Csv with Name and Molecular Formulae

# %%
import pyopenms as oms
import csv

# Specify the local FASTA file
fasta_file = "6504_lysC.fasta"  # Replace with your FASTA file name
output_csv = "6504_lysC_formulas.csv"

# Load the protein sequence from the FASTA file
with open(fasta_file, "r") as f:
    lines = f.readlines()
    protein_sequence = "".join(line.strip() for line in lines if not line.startswith(">"))  # Exclude the header

# Convert the protein sequence to an AASequence object
protein = oms.AASequence.fromString(protein_sequence)

# Initialize the protease digestion class
digestion = oms.ProteaseDigestion()

# Set digestion enzyme (default is trypsin)
digestion.getEnzymeName()  # Should return "Trypsin"

# Set the number of missed cleavages
digestion.setMissedCleavages(1)

# Perform digestion with length constraints (7-40 residues)
min_length = 7
max_length = 40
result = []
digestion.digest(protein, result, min_length, max_length)

# Prepare peptide data for CSV output
peptides = [peptide.toString() for peptide in result]

# Define the oxidation modification for methionine
variable_mod_names = [b"Oxidation (M)"]
variable_modifications = oms.ModifiedPeptideGenerator.getModifications(variable_mod_names)

# Apply the variable modifications to the digested peptides
modified_peptides = []
for peptide in result:
    oms.ModifiedPeptideGenerator.applyVariableModifications(variable_modifications, peptide, 1, modified_peptides, False)

# Combine original and modified peptides
all_peptides = peptides + [peptide.toString() for peptide in modified_peptides]

# Function to compute molecular formula
def get_molecular_formula(sequence):
    try:
        # Convert the sequence to an AASequence object
        seq_obj = oms.AASequence.fromString(sequence)
        # Get the molecular formula
        return str(seq_obj.getFormula())
    except Exception as e:
        return f"Error: {e}"

# Write peptides to a CSV file with Name and Molecular Formula columns
with open(output_csv, mode="w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["Name", "Molecular Formula"])
    for peptide in all_peptides:
        name = f"{fasta_file.split('.')[0]}_{peptide}"
        molecular_formula = get_molecular_formula(peptide)
        writer.writerow([name, molecular_formula])

print(f"Digestion complete. {len(all_peptides)} peptides written to {output_csv}")
# Out:
# Digestion complete. 2338 peptides written to 6504_lysC_formulas.csv

# %% [markdown]
# Removed peptides with unknown amino acids X

# %%
import pyopenms as oms
import csv

# Specify the local FASTA file
fasta_file = "ENDO_MASTER_LCMS_PLASMA.fasta"  # Replace with your FASTA file name
output_csv = "peptides_with_formulas_ENDO_MASTER_LCMS_PLASMA.csv"

# Load the protein sequence from the FASTA file
with open(fasta_file, "r") as f:
    lines = f.readlines()
    protein_sequence = "".join(line.strip() for line in lines if not line.startswith(">"))  # Exclude the header

# Convert the protein sequence to an AASequence object
protein = oms.AASequence.fromString(protein_sequence)

# Initialize the protease digestion class
digestion = oms.ProteaseDigestion()

# Set digestion enzyme (default is trypsin)
digestion.getEnzymeName()  # Should return "Trypsin"

# Set the number of missed cleavages
digestion.setMissedCleavages(1)

# Perform digestion with length constraints (7-40 residues)
min_length = 6
max_length = 40
result = []
digestion.digest(protein, result, min_length, max_length)

# Prepare peptide data for CSV output
peptides = [peptide.toString() for peptide in result]

# Define the oxidation modification for methionine
variable_mod_names = [b"Oxidation (M)"]
variable_modifications = oms.ModifiedPeptideGenerator.getModifications(variable_mod_names)

# Apply the variable modifications to the digested peptides
modified_peptides = []
for peptide in result:
    oms.ModifiedPeptideGenerator.applyVariableModifications(variable_modifications, peptide, 1, modified_peptides, False)

# Combine original and modified peptides
all_peptides = peptides + [peptide.toString() for peptide in modified_peptides]

# Remove sequences with 'X' amino acid
filtered_peptides = [peptide for peptide in all_peptides if 'X' not in peptide]

# Function to compute molecular formula
def get_molecular_formula(sequence):
    try:
        # Convert the sequence to an AASequence object
        seq_obj = oms.AASequence.fromString(sequence)
        # Get the molecular formula
        return str(seq_obj.getFormula())
    except Exception as e:
        return f"Error: {e}"

# Write peptides to a CSV file with Name and Molecular Formula columns
with open(output_csv, mode="w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["Name", "Molecular Formula"])
    for peptide in filtered_peptides:
        name = f"{fasta_file.split('.')[0]}_{peptide}"
        molecular_formula = get_molecular_formula(peptide)
        writer.writerow([name, molecular_formula])

print(f"Digestion complete. {len(filtered_peptides)} peptides written to {output_csv}")
# Out:
# Digestion complete. 32592 peptides written to peptides_with_formulas_ENDO_MASTER_LCMS_PLASMA.csv

# %% [markdown]
# Read files seperately and output to one file

# %%
import pyopenms as oms
import csv

# List of FASTA files to process
fasta_files = ["6503_lysC.fasta", "6503_trypsin.fasta", "6504_lysC.fasta", "6504_trypsin.fasta", "6507_lysC.fasta", "6507_trypsin.fasta"]
output_csv = "peptides_with_formulas_seperate.csv"

# Function to read the protein sequence from a FASTA file
def read_protein_sequence(fasta_file):
    with open(fasta_file, "r") as f:
        lines = f.readlines()
        # Concatenate all non-header lines
        return "".join(line.strip() for line in lines if not line.startswith(">"))

# Function to compute molecular formula for a sequence
def get_molecular_formula(sequence):
    try:
        # Convert the sequence to an AASequence object
        seq_obj = oms.AASequence.fromString(sequence)
        # Get the molecular formula
        return str(seq_obj.getFormula())
    except Exception as e:
        return f"Error: {e}"

# Initialize the protease digestion class
digestion = oms.ProteaseDigestion()
digestion.setMissedCleavages(1)  # Allow one missed cleavage

# Define digestion parameters
min_length = 6
max_length = 40

# Define oxidation modification for methionine
variable_mod_names = [b"Oxidation (M)"]
variable_modifications = oms.ModifiedPeptideGenerator.getModifications(variable_mod_names)

# Open the CSV file for writing
with open(output_csv, mode="w", newline="") as file:
    writer = csv.writer(file)
    # Write header
    writer.writerow(["Name", "Molecular Formula"])

    # Process each FASTA file
    for fasta_file in fasta_files:
        # Read protein sequence
        protein_sequence = read_protein_sequence(fasta_file)
        protein = oms.AASequence.fromString(protein_sequence)

        # Perform digestion
        result = []
        digestion.digest(protein, result, min_length, max_length)

        # Prepare peptides
        peptides = [peptide.toString() for peptide in result]

        # Apply variable modifications
        modified_peptides = []
        for peptide in result:
            oms.ModifiedPeptideGenerator.applyVariableModifications(
                variable_modifications, peptide, 1, modified_peptides, False
            )

        # Combine original and modified peptides
        all_peptides = peptides + [peptide.toString() for peptide in modified_peptides]

        # Filter peptides (remove those containing 'X')
        filtered_peptides = [peptide for peptide in all_peptides if 'X' not in peptide]

        # Write peptides and formulas to the CSV
        for peptide in filtered_peptides:
            name = f"{fasta_file.split('.')[0]}_{peptide}"
            molecular_formula = get_molecular_formula(peptide)
            writer.writerow([name, molecular_formula])

print(f"Digestion complete. Results written to {output_csv}.")
# Out:
# Digestion complete. Results written to peptides_with_formulas_seperate.csv.

# %% [markdown]
# Getting Protein Name of the peptide from fasta header to the name

# %%
import pyopenms as oms
import csv

# Specify the local FASTA file
fasta_file = "ENDO_MASTER_LCMS_PLASMA.fasta"  # Replace with your FASTA file name
output_csv = "Peptides_2MC_ENDO_MASTER_LCMS_PLASMA.csv"

# Parse the FASTA file to extract protein names and sequences
def parse_fasta(file_path):
    proteins = []
    with open(file_path, "r") as f:
        lines = f.readlines()
        protein_name = ""
        protein_sequence = ""
        for line in lines:
            line = line.strip()
            if line.startswith(">"):
                if protein_name and protein_sequence:
                    proteins.append((protein_name, protein_sequence))
                protein_name = line.lstrip(">")
                protein_sequence = ""
            else:
                protein_sequence += line
        if protein_name and protein_sequence:
            proteins.append((protein_name, protein_sequence))
    return proteins

# Load all proteins from the FASTA file
proteins = parse_fasta(fasta_file)

# Initialize the protease digestion class
digestion = oms.ProteaseDigestion()
digestion.setMissedCleavages(2)  # Set the number of missed cleavages
min_length = 6
max_length = 40

# Define the oxidation modification for methionine
variable_mod_names = [b"Oxidation (M)"]
variable_modifications = oms.ModifiedPeptideGenerator.getModifications(variable_mod_names)

# Prepare to write to the CSV
with open(output_csv, mode="w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["Name", "Molecular Formula"])

    # Process each protein
    for protein_name, protein_sequence in proteins:
        protein = oms.AASequence.fromString(protein_sequence)
        result = []
        digestion.digest(protein, result, min_length, max_length)

        # Get peptides and apply modifications
        peptides = [peptide.toString() for peptide in result]
        modified_peptides = []
        for peptide in result:
            oms.ModifiedPeptideGenerator.applyVariableModifications(variable_modifications, peptide, 1, modified_peptides, False)

        # Combine original and modified peptides
        all_peptides = peptides + [peptide.toString() for peptide in modified_peptides]

        # Remove sequences with 'X' amino acid
        filtered_peptides = [peptide for peptide in all_peptides if 'X' not in peptide]

        # Compute molecular formulas and write to CSV
        for peptide in filtered_peptides:
            name = f"{protein_name}@{peptide}"  # Include the protein name
            try:
                seq_obj = oms.AASequence.fromString(peptide)
                molecular_formula = str(seq_obj.getFormula())
            except Exception as e:
                molecular_formula = f"Error: {e}"
            writer.writerow([name, molecular_formula])

print(f"Digestion complete. Peptides written to {output_csv}")
# Out:
# Digestion complete. Peptides written to Peptides_2MC_ENDO_MASTER_LCMS_PLASMA.csv

# %% [markdown]
# Code for outputing data in the template format

# %%
import pyopenms as oms
import csv

# Specify the local FASTA file
fasta_file = "mcherry.fasta"  # Replace with your FASTA file name
output_csv = "mcherry.csv"

# Parse the FASTA file to extract protein names and sequences
def parse_fasta(file_path):
    proteins = []
    with open(file_path, "r") as f:
        lines = f.readlines()
        protein_name = ""
        protein_sequence = ""
        for line in lines:
            line = line.strip()
            if line.startswith(">"):
                if protein_name and protein_sequence:
                    proteins.append((protein_name, protein_sequence))
                protein_name = line.lstrip(">")
                protein_sequence = ""
            else:
                protein_sequence += line
        if protein_name and protein_sequence:
            proteins.append((protein_name, protein_sequence))
    return proteins

# Load all proteins from the FASTA file
proteins = parse_fasta(fasta_file)

# Initialize the protease digestion class
digestion = oms.ProteaseDigestion()
digestion.setMissedCleavages(1)  # Set the number of missed cleavages
min_length = 6
max_length = 40

# Define the oxidation modification for methionine
variable_mod_names = [b"Oxidation (M)"]
variable_modifications = oms.ModifiedPeptideGenerator.getModifications(variable_mod_names)

# Prepare to write to the CSV
with open(output_csv, mode="w", newline="") as file:
    writer = csv.writer(file)
    # Define output headers
    headers = ["RT", "Formula", "Name", "CCS [M+H]+", "CCS [M+Na]+", "CCS [M-H]-",
               "KEGG", "CAS", "PubChem", "ChemSpider", "HMDB", "BioCyc",
               "Metlin", "LipidMaps", "UserID", "InChI"]
    writer.writerow(headers)

    # Process each protein
    for protein_name, protein_sequence in proteins:
        protein = oms.AASequence.fromString(protein_sequence)
        result = []
        digestion.digest(protein, result, min_length, max_length)

        # Get peptides and apply modifications
        peptides = [peptide.toString() for peptide in result]
        modified_peptides = []
        for peptide in result:
            oms.ModifiedPeptideGenerator.applyVariableModifications(variable_modifications, peptide, 1, modified_peptides, False)

        # Combine original and modified peptides
        all_peptides = peptides + [peptide.toString() for peptide in modified_peptides]

        # Remove sequences with 'X' amino acid
        filtered_peptides = [peptide for peptide in all_peptides if 'X' not in peptide]

        # Compute molecular formulas and write to CSV
        for peptide in filtered_peptides:
            name = f"{protein_name}@{peptide}"  # Include the protein name
            try:
                seq_obj = oms.AASequence.fromString(peptide)
                molecular_formula = str(seq_obj.getFormula())
                # Placeholder values for other fields
                retention_time = ""
                ccs_mh_plus = ""
                ccs_mna_plus = ""
                ccs_mh_minus = ""
                kegg = ""
                cas = ""
                pubchem = ""
                chemspider = ""
                hmdb = ""
                biocyc = ""
                metlin = ""
                lipidmaps = ""
                user_id = ""
                inchi = ""
            except Exception as e:
                molecular_formula = f"Error: {e}"

            # Write the row
            writer.writerow([retention_time, molecular_formula, name, ccs_mh_plus,
                             ccs_mna_plus, ccs_mh_minus, kegg, cas, pubchem, chemspider,
                             hmdb, biocyc, metlin, lipidmaps, user_id, inchi])

print(f"Digestion complete. Peptides written to {output_csv}")
# Out:
# Digestion complete. Peptides written to mcherry.csv

# %%
import pandas as pd

# Path to your CSV file
file_path = "human_pro_peptides_detailed.csv"  # Replace with your actual CSV file path

# Load the CSV file
df = pd.read_csv(file_path)

# Remove duplicates based on the entire row
df_cleaned = df.drop_duplicates()

# Save the cleaned data to a new CSV file
output_path = "cleaned_file.csv"  # Specify the output file name
df_cleaned.to_csv(output_path, index=False)

print(f"Duplicates removed. Cleaned file saved to {output_path}")
# Out:
# Duplicates removed. Cleaned file saved to cleaned_file.csv

# %% [markdown]
# Calculate number of unique proteins in FASTA

# %%
def count_unique_proteins_in_fasta(file_path):
    """
    Counts the number of unique proteins in a given FASTA file.

    :param file_path: Path to the FASTA file
    :return: Number of unique proteins
    """
    unique_proteins = set()  # Set to store unique protein identifiers
    with open(file_path, "r") as file:
        for line in file:
            if line.startswith(">"):
                protein_id = line.strip()  # Get the header line (remove whitespace)
                unique_proteins.add(protein_id)  # Add to set (duplicates automatically ignored)
    return len(unique_proteins)

# Example usage
fasta_file = "ENDO_MASTER_LCMS_PLASMA.fasta"  # Replace with your FASTA file name
num_unique_proteins = count_unique_proteins_in_fasta(fasta_file)
print(f"The number of unique proteins in the FASTA file is: {num_unique_proteins}")
# Out:
# The number of unique proteins in the FASTA file is: 186

# %% [markdown]
# Code for Splitting the CSV

# %%
import pyopenms as oms
import pandas as pd
import math

# Specify the local FASTA file
fasta_file = "mouse_nw.fasta"  # Replace with your FASTA file name
output_excel_prefix = "new_mouse_peptides"
max_rows_per_file = 500000  # Set to a safe limit below Excel's max

# Parse the FASTA file to extract protein names and sequences
def parse_fasta(file_path):
    proteins = []
    with open(file_path, "r") as f:
        lines = f.readlines()
        protein_name = ""
        protein_sequence = ""
        for line in lines:
            line = line.strip()
            if line.startswith(">"):
                if protein_name and protein_sequence:
                    proteins.append((protein_name, protein_sequence))
                protein_name = line.lstrip(">")
                protein_sequence = ""
            else:
                protein_sequence += line
        if protein_name and protein_sequence:
            proteins.append((protein_name, protein_sequence))
    return proteins

# Load all proteins from the FASTA file
proteins = parse_fasta(fasta_file)

digestion = oms.ProteaseDigestion()
digestion.setMissedCleavages(1)
min_length = 6
max_length = 40

variable_mod_names = [b"Oxidation (M)"]
variable_modifications = oms.ModifiedPeptideGenerator.getModifications(variable_mod_names)

all_peptides = []

for protein_name, protein_sequence in proteins:
    protein = oms.AASequence.fromString(protein_sequence)
    result = []
    digestion.digest(protein, result, min_length, max_length)
    peptides = [peptide.toString() for peptide in result]
    modified_peptides = []
    for peptide in result:
        oms.ModifiedPeptideGenerator.applyVariableModifications(variable_modifications, peptide, 1, modified_peptides, False)
    
    all_peptides.extend([(protein_name, peptide) for peptide in peptides if 'X' not in peptide])
    all_peptides.extend([(protein_name, p.toString()) for p in modified_peptides if 'X' not in p.toString()])

# Split data into multiple files
num_files = math.ceil(len(all_peptides) / max_rows_per_file)
for i in range(num_files):
    start_idx = i * max_rows_per_file
    end_idx = min((i + 1) * max_rows_per_file, len(all_peptides))
    batch = all_peptides[start_idx:end_idx]
    
    data = []
    for protein_name, peptide in batch:
        try:
            seq_obj = oms.AASequence.fromString(peptide)
            molecular_formula = str(seq_obj.getFormula())
        except Exception as e:
            molecular_formula = f"Error: {e}"
        
        data.append(["", molecular_formula, f"{protein_name}@{peptide}", "", "", "", "", "", "", "", "", "", "", "", "", ""])
    
    df = pd.DataFrame(data, columns=["RT", "Formula", "Name", "CCS [M+H]+", "CCS [M+Na]+", "CCS [M-H]-",
                                      "KEGG", "CAS", "PubChem", "ChemSpider", "HMDB", "BioCyc",
                                      "Metlin", "LipidMaps", "UserID", "InChI"])
    
    output_file = f"{output_excel_prefix}_part{i+1}.xlsx"
    df.to_excel(output_file, index=False, engine='openpyxl')
    print(f"Written {output_file}")

print("Digestion complete. Peptides written to multiple Excel files.")
# Out:
# Written new_mouse_peptides_part1.xlsx
# Written new_mouse_peptides_part2.xlsx
# Written new_mouse_peptides_part3.xlsx
# Written new_mouse_peptides_part4.xlsx
# Digestion complete. Peptides written to multiple Excel files.

# %% [markdown]
# Code for fetch FASTA Sequences from uniprot

# %%
import pandas as pd
import re
import requests
import pyopenms as oms
import csv

# ----------- Step 1: Read LC-MS/MS CSV and Clean Headers -----------
input_csv = "1.csv"  # Replace with your actual file path
df = pd.read_csv(input_csv, sep="\t")  # Change sep="," if needed
df.columns = df.columns.str.strip()  # Clean column names

print("Detected columns:", df.columns.tolist())

# ----------- Step 2: Try to Automatically Detect the Protein Group Column -----------
protein_col = None
for col in df.columns:
    if "protein" in col.lower() and "group" in col.lower():
        protein_col = col
        break

if not protein_col:
    raise KeyError("❌ Could not find a 'Protein Group Name'-like column in your file.")

print(f"✅ Using column: {protein_col} to extract UniProt IDs")

# ----------- Step 3: Extract UniProt IDs from the Detected Column -----------
def extract_uniprot_id(entry):
    match = re.search(r"\|([A-Z0-9]+)\|", str(entry))
    return match.group(1) if match else None

df['UniProt_ID'] = df[protein_col].apply(extract_uniprot_id)
unique_ids = df['UniProt_ID'].dropna().unique()

# ----------- Step 4: Fetch FASTA Sequences from UniProt -----------
fasta_file = "master_proteins.fasta"
base_url = "https://rest.uniprot.org/uniprotkb/{}.fasta"

with open(fasta_file, "w") as fasta_out:
    for uid in unique_ids:
        response = requests.get(base_url.format(uid))
        if response.status_code == 200:
            fasta_out.write(response.text)
            print(f"✅ Fetched: {uid}")
        else:
            print(f"❌ Failed to fetch {uid} (status {response.status_code})")

# ----------- Step 5: Parse FASTA File -----------
def parse_fasta(file_path):
    proteins = []
    with open(file_path, "r") as f:
        lines = f.readlines()
        name = ""
        seq = ""
        for line in lines:
            line = line.strip()
            if line.startswith(">"):
                if name and seq:
                    proteins.append((name, seq))
                name = line[1:]
                seq = ""
            else:
                seq += line
        if name and seq:
            proteins.append((name, seq))
    return proteins

proteins = parse_fasta(fasta_file)

# ----------- Step 6: Set Up Digestion Parameters -----------
digestion = oms.ProteaseDigestion()
digestion.setEnzyme("Trypsin")
digestion.setMissedCleavages(1)
min_len = 6
max_len = 40

modifications = oms.ModifiedPeptideGenerator.getModifications([b"Oxidation (M)"])

# ----------- Step 7: In Silico Digestion + Export to MetaboScape Format -----------
output_csv = "metaboscape_peptides.csv"
with open(output_csv, "w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow([
        "RT", "Formula", "Name", "Mass", "CCS [M+H]+", "CCS [M+Na]+", "CCS [M-H]-",
        "KEGG", "CAS", "PubChem", "ChemSpider", "HMDB", "BioCyc",
        "Metlin", "LipidMaps", "UserID", "InChI"
    ])

    for protein_name, protein_seq in proteins:
        try:
            aa_seq = oms.AASequence.fromString(protein_seq)
        except Exception as e:
            print(f"⚠️ Error parsing {protein_name}: {e}")
            continue

        peptides = []
        digestion.digest(aa_seq, peptides, min_len, max_len)

        modified_peptides = []
        for p in peptides:
            oms.ModifiedPeptideGenerator.applyVariableModifications(modifications, p, 1, modified_peptides, False)

        all_peptides = set([p.toString() for p in peptides] + [p.toString() for p in modified_peptides])
        all_peptides = [pep for pep in all_peptides if "X" not in pep]

        for pep_str in all_peptides:
            try:
                seq_obj = oms.AASequence.fromString(pep_str)
                formula = seq_obj.getFormula().toString()
                mass = seq_obj.getMonoWeight()
            except Exception as e:
                formula = f"Error: {e}"
                mass = ""

            name = f"{protein_name}@{pep_str}"
            writer.writerow(["", formula, name, mass, "", "", "", "", "", "", "", "", "", "", "", ""])

print(f"\n🎉 Digestion complete. Peptides saved to: {output_csv}")
# Out:
# Detected columns: ['MS2 Id,Peptide Sequence,XCorr Score,Precursor MZ,PPM Error,Rt,Corrected Ook0,Protein Group Name,Charge,Delta CN Score,Confidence Score,Calculated MH,Matched Ions,Predicted Ook0,TIMScore,Is Unique']
# ✅ Using column: MS2 Id,Peptide Sequence,XCorr Score,Precursor MZ,PPM Error,Rt,Corrected Ook0,Protein Group Name,Charge,Delta CN Score,Confidence Score,Calculated MH,Matched Ions,Predicted Ook0,TIMScore,Is Unique to extract UniProt IDs
# ✅ Fetched: Q80WW9
# ✅ Fetched: Q3TW96
# ✅ Fetched: O35226
# ✅ Fetched: P0C7N9
# ✅ Fetched: Q3UJB9
# ✅ Fetched: Q3UWL8
# ✅ Fetched: Q6NV83
# ✅ Fetched: Q9R1T4
# ✅ Fetched: P97807
# ✅ Fetched: P26039
# ✅ Fetched: P08882
# ✅ Fetched: Q62009
# ✅ Fetched: O70423
# ✅ Fetched: Q5NCR9
# ✅ Fetched: G5E8K5
# ✅ Fetched: Q61140
# ✅ Fetched: Q8VH51
# ✅ Fetched: Q9CRB9
# ✅ Fetched: Q9D8N0
# ✅ Fetched: Q13608
# ✅ Fetched: Q9JJY4
# ✅ Fetched: Q9JIF7
# ✅ Fetched: Q8C1B7
# ✅ Fetched: Q7TSG2
# ✅ Fetched: Q9EPU4
# ✅ Fetched: E9Q1P8
# ✅ Fetched: P28667
# ✅ Fetched: Q7M753
# ✅ Fetched: Q9CR00
# ✅ Fetched: Q8VDJ3
# ✅ Fetched: O08759
# ✅ Fetched: P21107
# ✅ Fetched: Q9ERK4
# ✅ Fetched: Q60931
# ✅ Fetched: Q91Z40
# ✅ Fetched: Q61107
# ✅ Fetched: Q8BTS3
# ✅ Fetched: A0A0G2JDV3
# ✅ Fetched: Q000W5
# ✅ Fetched: Q9JLI6
# ✅ Fetched: Q9Z2G6
# ✅ Fetched: Q3UMT1
# ✅ Fetched: P62960
# ✅ Fetched: F6ZDS4
# ✅ Fetched: P52480
# ✅ Fetched: Q3UFK8
# ✅ Fetched: P14873
# ✅ Fetched: O70133
# ✅ Fetched: Q08211
# ✅ Fetched: Q62383
# ✅ Fetched: P28660
# ✅ Fetched: P28867
# ✅ Fetched: Q80TV8
# ✅ Fetched: Q9QZV9
# ✅ Fetched: Q9ESV0
# ✅ Fetched: Q80VD1
# ✅ Fetched: Q9JMH9
# ✅ Fetched: Q92614
# ✅ Fetched: O70591
# ✅ Fetched: F8VPK0
# ✅ Fetched: Q91WT4
# ✅ Fetched: P67778
# ✅ Fetched: P30416
# ✅ Fetched: P27546
# ✅ Fetched: O55029
# ✅ Fetched: Q9CXI0
# ✅ Fetched: Q8R1F5
# ✅ Fetched: P61163
# ✅ Fetched: Q8R5C5
# ✅ Fetched: Q9Z0H8
# ✅ Fetched: Q6PB93
# ✅ Fetched: Q8CFQ3
# ✅ Fetched: B2RQC6
# ✅ Fetched: P62258
# ✅ Fetched: A6H584
# ✅ Fetched: Q9D0F3
# ✅ Fetched: Q8BTI8
# ✅ Fetched: Q9UQ35
# ✅ Fetched: Q8K2B3
# ✅ Fetched: Q9JIH2
# ✅ Fetched: Q62470
# ✅ Fetched: Q8R3N1
# ✅ Fetched: Q9ET54
# ✅ Fetched: Q9D8X2
# ✅ Fetched: Q64674
# ✅ Fetched: Q8BK67
# ✅ Fetched: P25799
# ✅ Fetched: P16330
# ✅ Fetched: Q810B6
# ✅ Fetched: Q99MN1
# ✅ Fetched: P97351
# ✅ Fetched: Q9JL35
# ✅ Fetched: P57746
# ✅ Fetched: P48678
# ✅ Fetched: P54822
# ✅ Fetched: Q61249
# ✅ Fetched: Q9QYR6
# ✅ Fetched: Q9D0K2
# ✅ Fetched: P47955
# ✅ Fetched: Q9WTM5
# ✅ Fetched: Q9CQ43
# ✅ Fetched: Q64324
# ✅ Fetched: P50580
# ✅ Fetched: P80314
# ✅ Fetched: O08599
# ✅ Fetched: Q9CR57
# ✅ Fetched: Q2TAY7
# ✅ Fetched: P56959
# ✅ Fetched: Q8CIG8
# ✅ Fetched: Q9JIK5
# ✅ Fetched: Q8R3P6
# ✅ Fetched: O08553
# ✅ Fetched: Q9QXS1
# ✅ Fetched: O75533
# ✅ Fetched: Q8BVI4
# ✅ Fetched: Q9CZN7
# ✅ Fetched: Q9Z0H4
# ✅ Fetched: P28659
# ✅ Fetched: Q64345
# ✅ Fetched: Q08509
# ✅ Fetched: Q9DBR1
# ✅ Fetched: P19001
# ✅ Fetched: Q8CIG9
# ✅ Fetched: Q6P4T2
# ✅ Fetched: O75643
# ✅ Fetched: Q61179
# ✅ Fetched: O08784
# ✅ Fetched: Q8K182
# ✅ Fetched: P41227
# ✅ Fetched: B9EJR8
# ✅ Fetched: Q6ZPJ3
# ✅ Fetched: E9PVA8
# ✅ Fetched: Q6P9Q4
# ✅ Fetched: P03975
# ✅ Fetched: Q9QY93
# ✅ Fetched: P62851
# ✅ Fetched: Q6PB66
# ✅ Fetched: Q91ZX7
# ✅ Fetched: Q07954
# ✅ Fetched: Q922F4
# ✅ Fetched: Q9BUF5
# ✅ Fetched: Q9DBG3
# ✅ Fetched: O35643
# ✅ Fetched: P19096
# ✅ Fetched: Q8K3G9
# ✅ Fetched: Q6P542
# ✅ Fetched: Q4VAA2
# ✅ Fetched: Q8BWT1
# ✅ Fetched: Q64727
# ✅ Fetched: Q9D0M3
# ✅ Fetched: Q9JKR6
# ✅ Fetched: Q99KH8
# ✅ Fetched: P34056
# ✅ Fetched: O35969
# ✅ Fetched: Q9JIX8
# ✅ Fetched: Q80U93
# ✅ Fetched: Q921S7
# ✅ Fetched: Q922H2
# ✅ Fetched: Q5SSI6
# ✅ Fetched: Q9D1B1
# ✅ Fetched: P47199
# ✅ Fetched: P05064
# ✅ Fetched: Q921G7
# ✅ Fetched: O08528
# ✅ Fetched: P19367
# ✅ Fetched: P17710
# ✅ Fetched: Q3TRM8
# ✅ Fetched: Q99P31
# ✅ Fetched: Q6PAM1
# ✅ Fetched: Q6PB44
# ✅ Fetched: P53986
# ✅ Fetched: Q9JKP5
# ✅ Fetched: Q8BYA0
# ✅ Fetched: Q9QZQ8
# ✅ Fetched: Q80X85
# ✅ Fetched: P31323
# ✅ Fetched: Q9CQ60
# ✅ Fetched: Q9DC50
# ✅ Fetched: Q9EPL2
# ✅ Fetched: P97429
# ✅ Fetched: Q8VCW8
# ✅ Fetched: O70305
# ✅ Fetched: A4UUI3
# ✅ Fetched: Q8K382
# ✅ Fetched: Q6ZPF4
# ✅ Fetched: P51949
# ✅ Fetched: P97820
# ✅ Fetched: P70202
# ✅ Fetched: P97927
# ✅ Fetched: Q9Z1Z2
# ✅ Fetched: P81117
# ✅ Fetched: Q8C4B4
# ✅ Fetched: Q61687
# ✅ Fetched: Q3ULD5
# ✅ Fetched: P12367
# ✅ Fetched: Q9D6T0
# ✅ Fetched: Q9DCC4
# ✅ Fetched: Q0VBL3
# ✅ Fetched: Q01405
# ✅ Fetched: P82198
# ✅ Fetched: Q02053
# ✅ Fetched: Q9WV70
# ✅ Fetched: Q99LC5
# ✅ Fetched: Q9D2G2
# ✅ Fetched: P63038
# ✅ Fetched: P10809
# ✅ Fetched: Q91YR7
# ✅ Fetched: P70168
# ✅ Fetched: Q3TXS7
# ✅ Fetched: P01027
# ✅ Fetched: O08583
# ✅ Fetched: Q8R1U1
# ✅ Fetched: Q6P9B9
# ✅ Fetched: Q61702
# ✅ Fetched: Q9Z1Q9
# ✅ Fetched: P17182
# ✅ Fetched: P21550
# ✅ Fetched: P13929
# ✅ Fetched: P17183
# ✅ Fetched: P09411
# ✅ Fetched: P00558
# ✅ Fetched: P49769
# ✅ Fetched: Q3UPH7
# ✅ Fetched: Q6PE01
# ✅ Fetched: P16332
# ✅ Fetched: O88325
# ✅ Fetched: P47791
# ✅ Fetched: Q99PW4
# ✅ Fetched: Q9ULV0
# ✅ Fetched: P97386
# ✅ Fetched: P70697
# ✅ Fetched: P01942
# ✅ Fetched: Q9CQW1
# ✅ Fetched: P51881
# ✅ Fetched: P48962
# ✅ Fetched: P12236
# ✅ Fetched: Q924W5
# ✅ Fetched: Q60770
# ✅ Fetched: Q6PDQ2
# ✅ Fetched: P10107
# ✅ Fetched: Q9D0I9
# ✅ Fetched: O70310
# ✅ Fetched: P62873
# ✅ Fetched: Q9Z2D8
# ✅ Fetched: Q9EQH3
# ✅ Fetched: Q3TZZ7
# ✅ Fetched: A0FGR8
# ✅ Fetched: P62879
# ✅ Fetched: Q99KC8
# ✅ Fetched: G5E895
# ✅ Fetched: P56380
# ✅ Fetched: Q62465
# ✅ Fetched: E9Q4Y4
# ✅ Fetched: P98083
# ✅ Fetched: Q8CG76
# ✅ Fetched: Q80X90
# ✅ Fetched: P35998
# ✅ Fetched: Q7TPR4
# ✅ Fetched: P12814
# ✅ Fetched: P57780
# ✅ Fetched: P13439
# ✅ Fetched: P25322
# ✅ Fetched: Q80TM9
# ✅ Fetched: Q91XB0
# ✅ Fetched: Q8CI51
# ✅ Fetched: Q8VDN2
# ✅ Fetched: P50993
# ✅ Fetched: Q9Z183
# ✅ Fetched: Q9D071
# ✅ Fetched: P48036
# ✅ Fetched: Q9CPX6
# ✅ Fetched: P63024
# ✅ Fetched: P63027
# ✅ Fetched: Q8VE99
# ✅ Fetched: E9QAT4
# ✅ Fetched: Q8BK64
# ✅ Fetched: O95433
# ✅ Fetched: Q8BFR5
# ✅ Fetched: A6X935
# ✅ Fetched: P20491
# ✅ Fetched: P28033
# ✅ Fetched: A2AKX3
# ✅ Fetched: P04075
# ✅ Fetched: P39061
# ✅ Fetched: Q2VLH6
# ✅ Fetched: Q9Z315
# ✅ Fetched: Q3UDE2
# ✅ Fetched: Q68FD5
# ✅ Fetched: Q921I2
# ✅ Fetched: Q8K363
# ✅ Fetched: Q63829
# ✅ Fetched: P53811
# ✅ Fetched: P61970
# ✅ Fetched: Q8R5F7
# ✅ Fetched: Q9Z0P4
# ✅ Fetched: Q05920
# ✅ Fetched: Q8VDD5
# ✅ Fetched: P35579
# ✅ Fetched: Q61879
# ✅ Fetched: O35465
# ✅ Fetched: Q9D1H9
# ✅ Fetched: Q9ERU9
# ✅ Fetched: Q6PDH0
# ✅ Fetched: Q9CW46
# ✅ Fetched: Q8BKG3
# ✅ Fetched: O08749
# ✅ Fetched: Q3V009
# ✅ Fetched: P62241
# ✅ Fetched: P62333
# ✅ Fetched: P11499
# ✅ Fetched: P08865
# ✅ Fetched: Q8K2Q7
# ✅ Fetched: O75369
# ✅ Fetched: Q6ZWX6
# ✅ Fetched: Q6ZQ73
# ✅ Fetched: P61221
# ✅ Fetched: Q3TRM4
# ✅ Fetched: Q8VE22
# ✅ Fetched: Q5SSZ5
# ✅ Fetched: P10649
# ✅ Fetched: A0A087WS16
# ✅ Fetched: P12111
# ✅ Fetched: Q60847
# ✅ Fetched: Q99715
# ✅ Fetched: Q6P9R2
# ✅ Fetched: P56480
# ✅ Fetched: P68036
# ✅ Fetched: E9Q616
# ✅ Fetched: Q09666
# ✅ Fetched: P13645
# ✅ Fetched: Q5XG71
# ✅ Fetched: O75691
# ✅ Fetched: P62897
# ✅ Fetched: P07901
# ✅ Fetched: P07900
# ✅ Fetched: Q9D8Y0
# ✅ Fetched: Q62230
# ✅ Fetched: Q8C3I8
# ✅ Fetched: Q9JJ28
# ✅ Fetched: Q99LC8
# ✅ Fetched: Q6P5E4
# ✅ Fetched: Q06335
# ✅ Fetched: Q9D0R2
# ✅ Fetched: Q9CPY7
# ✅ Fetched: Q8BH64
# ✅ Fetched: Q8BMS1
# ✅ Fetched: Q9NYU2
# ✅ Fetched: Q9D0F9
# ✅ Fetched: Q64514
# ✅ Fetched: Q6PDG5
# ✅ Fetched: D0QMC3
# ✅ Fetched: Q9CQ36
# ✅ Fetched: Q9Z1F9
# ✅ Fetched: Q78ZA7
# ✅ Fetched: Q96KP1
# ✅ Fetched: Q9Z1X4
# ✅ Fetched: Q9DB05
# ✅ Fetched: Q91YJ5
# ✅ Fetched: O89053
# ✅ Fetched: Q9HAV0
# ✅ Fetched: Q9WVK4
# ✅ Fetched: Q9QXY6
# ✅ Fetched: Q9NZN3
# ✅ Fetched: Q16594
# ✅ Fetched: Q9EQP2
# ✅ Fetched: P63321
# ✅ Fetched: P62263
# ✅ Fetched: O55137
# ✅ Fetched: Q9Z331
# ✅ Fetched: P35240
# ✅ Fetched: Q9CWY8
# ✅ Fetched: P84089
# ✅ Fetched: Q9JL15
# ✅ Fetched: O00214
# ✅ Fetched: Q6ZQ38
# ✅ Fetched: Q9WUA2
# ✅ Fetched: Q08943
# ✅ Fetched: Q61211
# ✅ Fetched: Q9Z0E6
# ✅ Fetched: P50516
# ✅ Fetched: Q8VEE4
# ✅ Fetched: Q8BND5
# ✅ Fetched: O08529
# ✅ Fetched: Q8K4G1
# ✅ Fetched: O54941
# ✅ Fetched: P04264
# ✅ Fetched: P11679
# ✅ Fetched: Q8JZY2
# ✅ Fetched: P46783
# ✅ Fetched: P97765
# ✅ Fetched: Q9CXL3
# ✅ Fetched: Q6PGL7
# ✅ Fetched: Q62311
# ✅ Fetched: Q8R3F5
# ✅ Fetched: Q8R151
# ✅ Fetched: Q8BZR9
# ✅ Fetched: Q8CJF7
# ✅ Fetched: Q9CU65
# ✅ Fetched: Q9DB34
# ✅ Fetched: Q8JZQ9
# ✅ Fetched: E9Q6R7
# ✅ Fetched: Q6R891
# ✅ Fetched: Q8VDM6
# ✅ Fetched: Q9BUJ2
# ✅ Fetched: Q61233
# ✅ Fetched: P13796
# ✅ Fetched: Q6GQT9
# ✅ Fetched: Q0GNC1
# ✅ Fetched: Q61147
# ✅ Fetched: P08107
# ✅ Fetched: Q60710
# ✅ Fetched: P07356
# ✅ Fetched: P07355
# ✅ Fetched: Q69ZN7
# ✅ Fetched: Q9NZM1
# ✅ Fetched: P17918
# ✅ Fetched: P12004
# ✅ Fetched: Q9D7E4
# ✅ Fetched: P97300
# ✅ Fetched: Q99K30
# ✅ Fetched: Q61699
# ✅ Fetched: P09055
# ✅ Fetched: O15031
# ✅ Fetched: P37889
# ✅ Fetched: Q60715
# ✅ Fetched: Q62418
# ✅ Fetched: Q9CPQ3
# ✅ Fetched: E9Q7L1
# ✅ Fetched: Q6PIP5
# ✅ Fetched: Q9CXW4
# ✅ Fetched: P25976
# ✅ Fetched: Q8BGQ1
# ✅ Fetched: Q91WC0
# ✅ Fetched: Q921H8
# ✅ Fetched: Q8BP92
# ✅ Fetched: Q569Z6
# ✅ Fetched: Q61033
# ✅ Fetched: E9PZM7
# ✅ Fetched: Q9JIW9
# ✅ Fetched: Q99PT1
# ✅ Fetched: P41317
# ✅ Fetched: Q8VCT3
# ✅ Fetched: Q6P0Q8
# ✅ Fetched: O15021
# ✅ Fetched: P59017
# ✅ Fetched: Q91XV3
# ✅ Fetched: Q6IRU2
# ✅ Fetched: Q61646
# ✅ Fetched: P28658
# ✅ Fetched: Q8VE97
# ✅ Fetched: Q9EPX2
# ✅ Fetched: A2AJ72
# ✅ Fetched: P04186
# ✅ Fetched: P14618
# ✅ Fetched: Q8VBT6
# ✅ Fetched: Q86WX3
# ✅ Fetched: Q9D906
# ✅ Fetched: Q9DBE9
# ✅ Fetched: Q60676
# ✅ Fetched: P53041
# ✅ Fetched: P14733
# ✅ Fetched: Q8BJS4
# ✅ Fetched: Q9R0N0
# ✅ Fetched: Q8VHX6
# ✅ Fetched: Q3V3R1
# ✅ Fetched: Q8BH97
# ✅ Fetched: P49717
# ✅ Fetched: Q9CWJ9
# ✅ Fetched: Q8BKT7
# ✅ Fetched: P42567
# ✅ Fetched: P20226
# ✅ Fetched: Q924T7
# ✅ Fetched: Q8VDM4
# ✅ Fetched: Q8VIJ6
# ✅ Fetched: Q15149
# ✅ Fetched: Q924Z6
# ✅ Fetched: Q91YP2
# ✅ Fetched: Q9BYT8
# ✅ Fetched: P58044
# ✅ Fetched: Q9QXG4
# ✅ Fetched: Q9CW03
# ✅ Fetched: Q6P5H2
# ✅ Fetched: Q9D853
# ✅ Fetched: D4AFX7
# ✅ Fetched: Q68FL6
# ✅ Fetched: Q9Z0H1
# ✅ Fetched: P02469
# ✅ Fetched: Q99J85
# ✅ Fetched: Q05793
# ✅ Fetched: P62908
# ✅ Fetched: Q91YI0
# ✅ Fetched: Q9R0E2
# ✅ Fetched: O00231
# ✅ Fetched: Q9D3E6
# ✅ Fetched: Q60520
# ✅ Fetched: P54729
# ✅ Fetched: Q61335
# ✅ Fetched: P59998
# ✅ Fetched: P18653
# ✅ Fetched: P18654
# ✅ Fetched: Q8VHI3
# ✅ Fetched: Q8R409
# ✅ Fetched: E9PV24
# ✅ Fetched: Q99PL5
# ✅ Fetched: Q7TPV4
# ✅ Fetched: P61158
# ✅ Fetched: Q91YX5
# ✅ Fetched: Q9D1P4
# ✅ Fetched: P63244
# ✅ Fetched: Q9JLZ8
# ✅ Fetched: Q6IA17
# ✅ Fetched: Q64726
# ✅ Fetched: D3YZP9
# ✅ Fetched: O00160
# ✅ Fetched: E9Q634
# ✅ Fetched: P70248
# ✅ Fetched: Q3UMY5
# ✅ Fetched: Q60597
# ✅ Fetched: Q99JB2
# ✅ Fetched: P39447
# ✅ Fetched: Q61292
# ✅ Fetched: Q9R1C7
# ✅ Fetched: Q9JHR7
# ✅ Fetched: P02468
# ✅ Fetched: P08032
# ✅ Fetched: Q14683
# ✅ Fetched: O08788
# ✅ Fetched: Q14203
# ✅ Fetched: Q3UQN2
# ✅ Fetched: Q99L43
# ✅ Fetched: P07724
# ✅ Fetched: Q80YX1
# ✅ Fetched: Q8R2U0
# ✅ Fetched: Q00547
# ✅ Fetched: Q80Y17
# ✅ Fetched: Q8VE88
# ✅ Fetched: Q9DBK7
# ✅ Fetched: P60670
# ✅ Fetched: P16879
# ✅ Fetched: Q9Y2X7
# ✅ Fetched: Q9JHU4
# ✅ Fetched: Q9D1H7
# ✅ Fetched: Q91W18
# ✅ Fetched: Q6DFW4
# ✅ Fetched: Q8VEK3
# ✅ Fetched: Q15393
# ✅ Fetched: P09622
# ✅ Fetched: Q8VDP4
# ✅ Fetched: Q9UHD8
# ✅ Fetched: P26231
# ✅ Fetched: P08030
# ✅ Fetched: Q5U430
# ✅ Fetched: Q8K2M0
# ✅ Fetched: Q8BKX6
# ✅ Fetched: Q14012
# ✅ Fetched: Q8BW96
# ✅ Fetched: Q9DCL9
# ✅ Fetched: Q9DCD2
# ✅ Fetched: Q99JI4
# ✅ Fetched: Q8JZR0
# ✅ Fetched: Q8BHF7
# ✅ Fetched: Q6PDY2
# ✅ Fetched: P80316
# ✅ Fetched: P48643
# ✅ Fetched: P80315
# ✅ Fetched: Q61733
# ✅ Fetched: P61803
# ✅ Fetched: Q921F2
# ✅ Fetched: P45952
# ✅ Fetched: Q64737
# ✅ Fetched: P22102
# ✅ Fetched: Q9BXJ9
# ✅ Fetched: Q91VM9
# ✅ Fetched: Q8VBV7
# ✅ Fetched: O88322
# ✅ Fetched: Q8BIJ6
# ✅ Fetched: Q61838
# ✅ Fetched: O95373
# ✅ Fetched: P41245
# ✅ Fetched: Q91WQ3
# ✅ Fetched: Q9ERI6
# ✅ Fetched: Q99MN9
# ✅ Fetched: Q8R1I1
# ✅ Fetched: P40142
# ✅ Fetched: P29401
# ✅ Fetched: Q91V92
# ✅ Fetched: Q8BX90
# ✅ Fetched: Q9CZ30
# ✅ Fetched: Q9EPJ9
# ✅ Fetched: P55072
# ✅ Fetched: Q91WM3
# ✅ Fetched: Q61503
# ✅ Fetched: O70435
# ✅ Fetched: O70252
# ✅ Fetched: Q6PD26
# ✅ Fetched: Q11011
# ✅ Fetched: Q6Q899
# ✅ Fetched: Q62083
# ✅ Fetched: O88712
# ✅ Fetched: Q7TQI3
# ✅ Fetched: Q99J99
# ✅ Fetched: P04184
# ✅ Fetched: P98078
# ✅ Fetched: P84103
# ✅ Fetched: Q5SUR0
# ✅ Fetched: P11983
# ✅ Fetched: Q9D1J1
# ✅ Fetched: Q8BML9
# ✅ Fetched: P51863
# ✅ Fetched: O08810
# ✅ Fetched: Q9D0E1
# ✅ Fetched: Q8BUV3
# ✅ Fetched: P14869
# ✅ Fetched: Q8BWM0
# ✅ Fetched: Q61210
# ✅ Fetched: Q9DBH0
# ✅ Fetched: P32261
# ✅ Fetched: Q99K70
# ✅ Fetched: Q9CY97
# ✅ Fetched: P49207
# ✅ Fetched: Q91ZV0
# ✅ Fetched: O35206
# ✅ Fetched: P61026
# ✅ Fetched: Q9EQ20
# ✅ Fetched: Q6P5D3
# ✅ Fetched: Q8BXQ2
# ✅ Fetched: Q3UW53
# ✅ Fetched: P17047
# ✅ Fetched: P59708
# ✅ Fetched: Q9NZT1
# ✅ Fetched: Q8BNU0
# ✅ Fetched: Q61316
# ✅ Fetched: Q04323
# ✅ Fetched: Q9R0P3
# ✅ Fetched: O35239
# ✅ Fetched: Q8CB77
# ✅ Fetched: Q8BHG1
# ✅ Fetched: Q9JJ78
# ✅ Fetched: P31939
# ✅ Fetched: P35505
# ✅ Fetched: P25444
# ✅ Fetched: O70503
# ✅ Fetched: Q9CYR6
# ✅ Fetched: Q6PAJ1
# ✅ Fetched: P51174
# ✅ Fetched: A2ADY9
# ✅ Fetched: Q8BH60
# ✅ Fetched: O35658
# ✅ Fetched: Q60854
# ✅ Fetched: Q8CIH5
# ✅ Fetched: P68373
# ✅ Fetched: P05213
# ✅ Fetched: P68369
# ✅ Fetched: P68366
# ✅ Fetched: A2AT37
# ✅ Fetched: Q4LDD4
# ✅ Fetched: Q6P1B1
# ✅ Fetched: Q8R2R3
# ✅ Fetched: P97372
# ✅ Fetched: P29758
# ✅ Fetched: Q3U5Q7
# ✅ Fetched: Q8CIE4
# ✅ Fetched: Q9WTK5
# ✅ Fetched: Q91VN6
# ✅ Fetched: P10518
# ✅ Fetched: Q6Y7W8
# ✅ Fetched: Q3U0V2
# ✅ Fetched: Q9CXS4
# ✅ Fetched: P08249
# ✅ Fetched: P16858
# ✅ Fetched: S4R1W1
# ✅ Fetched: P23780
# ✅ Fetched: P58871
# ✅ Fetched: Q6PHZ2
# ✅ Fetched: O08808
# ✅ Fetched: Q9WVG6
# ✅ Fetched: O15514
# ✅ Fetched: P51859
# ✅ Fetched: O08539
# ✅ Fetched: E9PVZ8
# ✅ Fetched: Q8K2I4
# ✅ Fetched: P70297
# ✅ Fetched: Q8C6B2
# ✅ Fetched: Q61703
# ✅ Fetched: P62269
# ✅ Fetched: Q99J08
# ✅ Fetched: Q6PDI5
# ✅ Fetched: E9Q7G0
# ✅ Fetched: Q15233
# ✅ Fetched: P60709
# ✅ Fetched: P68032
# ✅ Fetched: Q6S8J3
# ✅ Fetched: P0CG38
# ✅ Fetched: P0CG39
# ✅ Fetched: A5A3E0
# ✅ Fetched: Q99JW2
# ✅ Fetched: Q93009
# ✅ Fetched: Q9CQF9
# ✅ Fetched: Q9CY21
# ✅ Fetched: P29351
# ✅ Fetched: Q8BRT1
# ✅ Fetched: Q924C1
# ✅ Fetched: Q8K1R7
# ✅ Fetched: Q9D1C9
# ✅ Fetched: Q61635
# ✅ Fetched: O09061
# ✅ Fetched: A2AJL3
# ✅ Fetched: Q920A5
# ✅ Fetched: P51397
# ✅ Fetched: Q9QX47
# ✅ Fetched: Q04857
# ✅ Fetched: P42768
# ✅ Fetched: P98195
# ✅ Fetched: Q61458
# ✅ Fetched: Q61414
# ✅ Fetched: Q99JX3
# ✅ Fetched: Q9R1X4
# ✅ Fetched: Q91YR5
# ✅ Fetched: Q8K2V6
# ✅ Fetched: Q99KK7
# ✅ Fetched: P52825
# ✅ Fetched: P59016
# ✅ Fetched: Q5U458
# ✅ Fetched: Q3U487
# ✅ Fetched: C0HKE1
# ✅ Fetched: P20671
# ✅ Fetched: Q93077
# ✅ Fetched: Q6FI13
# ✅ Fetched: P0C0S8
# ✅ Fetched: Q64522
# ✅ Fetched: Q8IUE6
# ✅ Fetched: P16104
# ✅ Fetched: P0C0S5
# ✅ Fetched: Q96QV6
# ✅ Fetched: Q9JHF5
# ✅ Fetched: E9Q3L2
# ✅ Fetched: Q61235
# ✅ Fetched: Q8R502
# ✅ Fetched: Q91VE0
# ✅ Fetched: P27659
# ✅ Fetched: Q91ZU6
# ✅ Fetched: O54988
# ✅ Fetched: Q9JI11
# ✅ Fetched: Q5F2E8
# ✅ Fetched: Q9H2K8
# ✅ Fetched: Q8BYC6
# ✅ Fetched: P35268
# ✅ Fetched: O55098
# ✅ Fetched: P35821
# ✅ Fetched: Q61508
# ✅ Fetched: O60506
# ✅ Fetched: O43390
# ✅ Fetched: P05480
# ✅ Fetched: Q61001
# ✅ Fetched: P47968
# ✅ Fetched: Q08093
# ✅ Fetched: Q9JLQ2
# ✅ Fetched: Q9EQC5
# ✅ Fetched: Q9Z0R6
# ✅ Fetched: Q9NZM3
# ✅ Fetched: Q8BI84
# ✅ Fetched: Q01514
# ✅ Fetched: Q8BH59
# ✅ Fetched: Q9QYB1
# ✅ Fetched: Q9QXZ0
# ✅ Fetched: P83436
# ✅ Fetched: E9Q6J5
# ✅ Fetched: Q58A65
# ✅ Fetched: P11088
# ✅ Fetched: Q9JL26
# ✅ Fetched: Q9JHW2
# ✅ Fetched: Q9Z277
# ✅ Fetched: Q61753
# ✅ Fetched: P35441
# ✅ Fetched: Q924Z4
# ✅ Fetched: O35350
# ✅ Fetched: Q6P4S8
# ✅ Fetched: Q91V61
# ✅ Fetched: Q8BGW1
# ✅ Fetched: P12815
# ✅ Fetched: P12970
# ✅ Fetched: O00487
# ✅ Fetched: Q61749
# ✅ Fetched: Q8BP48
# ✅ Fetched: Q8CAY6
# ✅ Fetched: Q9D662
# ✅ Fetched: Q15437
# ✅ Fetched: Q80TE0
# ✅ Fetched: Q8BX02
# ✅ Fetched: Q9WVR4
# ✅ Fetched: P47962
# ✅ Fetched: O08915
# ✅ Fetched: Q923B6
# ✅ Fetched: Q8BHN3
# ✅ Fetched: Q4VA53
# ✅ Fetched: O88342
# ✅ Fetched: P42932
# ✅ Fetched: Q8BTM8
# ✅ Fetched: Q99JX7
# ✅ Fetched: P35585
# ✅ Fetched: Q8VBZ0
# ✅ Fetched: P02463
# ✅ Fetched: P46664
# ✅ Fetched: P46939
# ✅ Fetched: P06795
# ✅ Fetched: P62266
# ✅ Fetched: Q8CI95
# ✅ Fetched: Q5SUA5
# ✅ Fetched: Q9DAR7
# ✅ Fetched: P62253
# ✅ Fetched: P97384
# ✅ Fetched: Q7TMR0
# ✅ Fetched: P08122
# ✅ Fetched: P11352
# ✅ Fetched: Q9CQ75
# ✅ Fetched: P62308
# ✅ Fetched: Q3TDN2
# ✅ Fetched: Q9CQR6
# ✅ Fetched: P63330
# ✅ Fetched: P62714
# ✅ Fetched: Q8CAQ8
# ✅ Fetched: O09044
# ✅ Fetched: P63087
# ✅ Fetched: P62140
# ✅ Fetched: P97930
# ✅ Fetched: P62717
# ✅ Fetched: Q91W50
# ✅ Fetched: P61201
# ✅ Fetched: Q9Y6Y8
# ✅ Fetched: Q6P5D8
# ✅ Fetched: O08736
# ✅ Fetched: P01897
# ✅ Fetched: P06339
# ✅ Fetched: P14427
# ✅ Fetched: P14430
# ✅ Fetched: O19441
# ✅ Fetched: Q8K0E8
# ✅ Fetched: Q9CYD3
# ✅ Fetched: P14152
# ✅ Fetched: Q8VC03
# ✅ Fetched: Q9Z1D1
# ✅ Fetched: Q6PNC0
# ✅ Fetched: P56389
# ✅ Fetched: B2RRE7
# ✅ Fetched: P47857
# ✅ Fetched: P08237
# ✅ Fetched: P28063
# ✅ Fetched: Q9D7N3
# ✅ Fetched: Q8BFQ8
# ✅ Fetched: Q99L47
# ✅ Fetched: Q8CFD4
# ✅ Fetched: O14672
# ✅ Fetched: Q5SXY1
# ✅ Fetched: O08692
# ✅ Fetched: D3YXK2
# ✅ Fetched: Q3TKT4
# ✅ Fetched: P16949
# ✅ Fetched: P54227
# ✅ Fetched: Q05CL8
# ✅ Fetched: Q4G0J3
# ✅ Fetched: Q9D0C4
# ✅ Fetched: Q80UM3
# ✅ Fetched: F8VQC1
# ✅ Fetched: Q8BJU0
# ✅ Fetched: Q3UJU9
# ✅ Fetched: O15294
# ✅ Fetched: Q3UM45
# ✅ Fetched: Q8CI32
# ✅ Fetched: P61966
# ✅ Fetched: P12270
# ✅ Fetched: Q8VDK1
# ✅ Fetched: Q8BSY0
# ✅ Fetched: Q9CQA9
# ✅ Fetched: P06801
# ✅ Fetched: Q6NS46
# ✅ Fetched: O54774
# ✅ Fetched: Q9ULV4
# ✅ Fetched: Q60973
# ✅ Fetched: P18242
# ✅ Fetched: Q61074
# ✅ Fetched: Q9R0I7
# ✅ Fetched: P49750
# ✅ Fetched: P52293
# ✅ Fetched: P28066
# ✅ Fetched: Q9Z1J3
# ✅ Fetched: Q8BKC5
# ✅ Fetched: Q9WUA3
# ✅ Fetched: P12382
# ✅ Fetched: B2RY04
# ✅ Fetched: P05202
# ✅ Fetched: P99026
# ✅ Fetched: P28070
# ✅ Fetched: Q8C4J7
# ✅ Fetched: Q99N87
# ✅ Fetched: Q2EMV9
# ✅ Fetched: E9PWG6
# ✅ Fetched: Q6NZJ6
# ✅ Fetched: P62081
# ✅ Fetched: Q3THK7
# ✅ Fetched: Q05D44
# ✅ Fetched: P41216
# ✅ Fetched: E9Q555
# ✅ Fetched: Q9NQH7
# ✅ Fetched: Q8C8U0
# ✅ Fetched: Q9WTX8
# ✅ Fetched: P24527
# ✅ Fetched: P09470
# ✅ Fetched: Q91VU7
# ✅ Fetched: Q9CRA8
# ✅ Fetched: Q9CZ42
# ✅ Fetched: P07437
# ✅ Fetched: Q13885
# ✅ Fetched: Q13509
# ✅ Fetched: O08917
# ✅ Fetched: Q99MU3
# ✅ Fetched: Q61584
# ✅ Fetched: Q91VX2
# ✅ Fetched: Q9QUM9
# ✅ Fetched: Q3U0V1
# ✅ Fetched: Q6P8X1
# ✅ Fetched: Q80X50
# ✅ Fetched: P27612
# ✅ Fetched: Q99LN9
# ✅ Fetched: Q9UID3
# ✅ Fetched: Q9ES52
# ✅ Fetched: O88544
# ✅ Fetched: Q61188
# ✅ Fetched: Q8VCM7
# ✅ Fetched: O35855
# ✅ Fetched: Q99PV0
# ✅ Fetched: Q921I1
# ✅ Fetched: Q8VCT4
# ✅ Fetched: Q62384
# ✅ Fetched: P41091
# ✅ Fetched: Q76MZ3
# ✅ Fetched: O88532
# ✅ Fetched: Q6NZN0
# ✅ Fetched: Q5SFM8
# ✅ Fetched: O75367
# ✅ Fetched: P70372
# ✅ Fetched: Q8BVF2
# ✅ Fetched: Q7Z739
# ✅ Fetched: P83731
# ✅ Fetched: Q8R081
# ✅ Fetched: Q61990
# ✅ Fetched: Q15366
# ✅ Fetched: P60335
# ✅ Fetched: Q62188
# ✅ Fetched: Q9Z2U0
# ✅ Fetched: O14818
# ✅ Fetched: Q9D819
# ✅ Fetched: Q9QXK3
# ✅ Fetched: Q8JZZ7
# ✅ Fetched: Q8VCN9
# ✅ Fetched: O15066
# ✅ Fetched: Q99MR6
# ✅ Fetched: Q9BXP5
# ✅ Fetched: A0A5F8MPH8
# ✅ Fetched: P09671
# ✅ Fetched: Q9D8W5
# ✅ Fetched: Q8K0D5
# ✅ Fetched: Q96RP9
# ✅ Fetched: Q60749
# ✅ Fetched: P26638
# ✅ Fetched: P20029
# ✅ Fetched: Q5SNZ0
# ✅ Fetched: P27635
# ✅ Fetched: P63001
# ✅ Fetched: Q9DAK9
# ✅ Fetched: P43277
# ✅ Fetched: P43274
# ✅ Fetched: Q07133
# ✅ Fetched: Q91XU0
# ✅ Fetched: P16401
# ✅ Fetched: Q91YN5
# ✅ Fetched: P08240
# ✅ Fetched: Q9DBG7
# ✅ Fetched: Q99LP6
# ✅ Fetched: Q8C1A5
# ✅ Fetched: P52888
# ✅ Fetched: A2BDX3
# ✅ Fetched: P61225
# ✅ Fetched: Q8K1X4
# ✅ Fetched: Q7TMY8
# ✅ Fetched: Q15382
# ✅ Fetched: A2RTL5
# ✅ Fetched: O55106
# ✅ Fetched: Q9ERG2
# ✅ Fetched: Q93092
# ✅ Fetched: Q64311
# ✅ Fetched: Q80YS6
# ✅ Fetched: Q3TLP5
# ✅ Fetched: Q8TER5
# ✅ Fetched: Q7TNG8
# ✅ Fetched: Q3TMP1
# ✅ Fetched: Q91W90
# ✅ Fetched: Q8BU31
# ✅ Fetched: Q3UHA3
# ✅ Fetched: Q9EQN3
# ✅ Fetched: Q91YH5
# ✅ Fetched: E9QAM5
# ✅ Fetched: E0CZ22
# ✅ Fetched: Q9BPX5
# ✅ Fetched: Q921I9
# ✅ Fetched: O70475
# ✅ Fetched: Q9CYG7
# ✅ Fetched: Q9EQK5
# ✅ Fetched: Q9QZE5
# ✅ Fetched: G3X9B1
# ✅ Fetched: O70481
# ✅ Fetched: Q60953
# ✅ Fetched: P0DPD9
# ✅ Fetched: P12265
# ✅ Fetched: P50247
# ✅ Fetched: Q922R8
# ✅ Fetched: Q15084
# ✅ Fetched: Q8BIG7
# ✅ Fetched: P63085
# ✅ Fetched: O88986
# ✅ Fetched: Q9CV28
# ✅ Fetched: P52431
# ✅ Fetched: G3X8U3
# ✅ Fetched: Q922P9
# ✅ Fetched: P29341
# ✅ Fetched: Q13310
# ✅ Fetched: Q9D4E6
# ✅ Fetched: Q6PHQ9
# ✅ Fetched: P70302
# ✅ Fetched: P23506
# ✅ Fetched: Q3TMH2
# ✅ Fetched: Q8K1H1
# ✅ Fetched: Q8R146
# ✅ Fetched: P68400
# ✅ Fetched: P35492
# ✅ Fetched: O88844
# ✅ Fetched: P62046
# ✅ Fetched: Q8BVU0
# ✅ Fetched: P02533
# ✅ Fetched: P19012
# ✅ Fetched: P13646
# ✅ Fetched: P08779
# ✅ Fetched: Q61781
# ✅ Fetched: Q04695
# ✅ Fetched: Q921G6
# ✅ Fetched: P02535
# ✅ Fetched: Q9QYI3
# ✅ Fetched: P70698
# ✅ Fetched: P70303
# ✅ Fetched: O08638
# ✅ Fetched: P35749
# ✅ Fetched: P43247
# ✅ Fetched: Q91Z92
# ✅ Fetched: P26041
# ✅ Fetched: P26043
# ✅ Fetched: Q9D6N5
# ✅ Fetched: O35286
# ✅ Fetched: P09405
# ✅ Fetched: P19338
# ✅ Fetched: P62495
# ✅ Fetched: P55194
# ✅ Fetched: Q99K51
# ✅ Fetched: Q8BGC0
# ✅ Fetched: P27773
# ✅ Fetched: Q9CX34
# ✅ Fetched: Q9JKF1
# ✅ Fetched: P60122
# ✅ Fetched: P28741
# ✅ Fetched: Q5JQF8
# ✅ Fetched: P01786
# ✅ Fetched: Q8K268
# ✅ Fetched: Q9CZU3
# ✅ Fetched: Q64010
# ✅ Fetched: Q64331
# ✅ Fetched: Q9CPY1
# ✅ Fetched: Q9JM52
# ✅ Fetched: O35127
# ✅ Fetched: Q80YP0
# ✅ Fetched: O54692
# ✅ Fetched: Q9CWD8
# ✅ Fetched: Q9DAW6
# ✅ Fetched: Q5VTL8
# ✅ Fetched: P54728
# ✅ Fetched: P54726
# ✅ Fetched: Q91WM2
# ✅ Fetched: P08074
# ✅ Fetched: P22437
# ✅ Fetched: Q9DBB9
# ✅ Fetched: Q5SUQ9
# ✅ Fetched: E9Q912
# ✅ Fetched: P36916
# ✅ Fetched: Q8VI94
# ✅ Fetched: P28352
# ✅ Fetched: P11440
# ✅ Fetched: P06493
# ✅ Fetched: Q8VDP3
# ✅ Fetched: Q3TFD2
# ✅ Fetched: Q9CQ18
# ✅ Fetched: Q8K297
# ✅ Fetched: Q9D8T7
# ✅ Fetched: Q922B2
# ✅ Fetched: P16675
# ✅ Fetched: Q811D0
# ✅ Fetched: Q15345
# ✅ Fetched: Q61205
# ✅ Fetched: O95372
# ✅ Fetched: Q8K411
# ✅ Fetched: Q8CBW3
# ✅ Fetched: Q9WV85
# ✅ Fetched: Q9CR62
# ✅ Fetched: P16546
# ✅ Fetched: P97823
# ✅ Fetched: Q99LD4
# ✅ Fetched: Q8BJ71
# ✅ Fetched: Q8K0Y7
# ✅ Fetched: P97819
# ✅ Fetched: Q3UIX4
# ✅ Fetched: P70670
# ✅ Fetched: O88448
# ✅ Fetched: P40124
# ✅ Fetched: Q8BVY0
# ✅ Fetched: Q9CYI4
# ✅ Fetched: Q6KCD5
# ✅ Fetched: P58252
# ✅ Fetched: Q9ER72
# ✅ Fetched: Q99KB8
# ✅ Fetched: Q8BHC9
# ✅ Fetched: Q8K298
# ✅ Fetched: P23249
# ✅ Fetched: Q8R180
# ✅ Fetched: P02452
# ✅ Fetched: P11087
# ✅ Fetched: P17427
# ✅ Fetched: P17426
# ✅ Fetched: Q9EQI8
# ✅ Fetched: Q920Q4
# ✅ Fetched: Q3ZK22
# ✅ Fetched: Q8CC12
# ✅ Fetched: Q00PI9
# ✅ Fetched: Q99MR3
# ✅ Fetched: P39054
# ✅ Fetched: P50570
# ✅ Fetched: Q8BMA6
# ✅ Fetched: Q99PU8
# ✅ Fetched: Q3UPL0
# ✅ Fetched: Q9JKX4
# ✅ Fetched: Q6DFZ1
# ✅ Fetched: Q8CG48
# ✅ Fetched: Q6NWW9
# ✅ Fetched: Q8C5H8
# ✅ Fetched: Q148V7
# ✅ Fetched: O95347
# ✅ Fetched: Q7TMB8
# ✅ Fetched: Q91YP3
# ✅ Fetched: P35123
# ✅ Fetched: Q9Y4A5
# ✅ Fetched: P99029
# ✅ Fetched: Q99LG4
# ✅ Fetched: P18669
# ✅ Fetched: Q8BRH0
# ✅ Fetched: Q5FWH2
# ✅ Fetched: Q3TEA8
# ✅ Fetched: Q99K01
# ✅ Fetched: Q9DBE0
# ✅ Fetched: Q8K4L0
# ✅ Fetched: Q9UBI9
# ✅ Fetched: Q9BRG1
# ✅ Fetched: Q64282
# ✅ Fetched: Q91W67
# ✅ Fetched: Q9QZF2
# ✅ Fetched: Q99KP6
# ✅ Fetched: Q8VDS4
# ✅ Fetched: Q9CSU0
# ✅ Fetched: Q7TT50
# ✅ Fetched: E9Q414
# ✅ Fetched: P08775
# ✅ Fetched: P80317
# ✅ Fetched: Q8BX10
# ✅ Fetched: Q9DCE9
# ✅ Fetched: Q8K1M6
# ✅ Fetched: Q8VCF0
# ✅ Fetched: Q8BUY9
# ✅ Fetched: P42125
# ✅ Fetched: P97471
# ✅ Fetched: Q9Z160
# ✅ Fetched: Q8VHR5
# ✅ Fetched: Q91VH2
# ✅ Fetched: Q8BJY1
# ✅ Fetched: Q60864
# ✅ Fetched: P30999
# ✅ Fetched: Q60963
# ✅ Fetched: P50431
# ✅ Fetched: P05063
# ✅ Fetched: P09972
# ✅ Fetched: O88536
# ✅ Fetched: Q91VD9
# ✅ Fetched: O88487
# ✅ Fetched: Q8K2H2
# ✅ Fetched: Q8BGZ4
# ✅ Fetched: Q6PFD9
# ✅ Fetched: Q9NRR5
# ✅ Fetched: Q8R317
# ✅ Fetched: Q99NB8
# ✅ Fetched: P27005
# ✅ Fetched: Q9WVH4
# ✅ Fetched: P57716
# ✅ Fetched: Q8BM55
# ✅ Fetched: Q6P5B0
# ✅ Fetched: Q9CWK8
# ✅ Fetched: Q9WV80
# ✅ Fetched: Q91VI7
# ✅ Fetched: Q9JLI8
# ✅ Fetched: Q9EQ06
# ✅ Fetched: Q8CH18
# ✅ Fetched: Q8IX12
# ✅ Fetched: Q3U7R1
# ✅ Fetched: Q8CHU3
# ✅ Fetched: Q91W69
# ✅ Fetched: P70398
# ✅ Fetched: Q93008
# ✅ Fetched: Q9DBZ5
# ✅ Fetched: Q8K124
# ✅ Fetched: Q8K0G5
# ✅ Fetched: O35682
# ✅ Fetched: Q99KE1
# ✅ Fetched: P68371
# ✅ Fetched: P43024
# ✅ Fetched: Q9JKP8
# ✅ Fetched: Q62261
# ✅ Fetched: Q9QXT0
# ✅ Fetched: Q9D6S7
# ✅ Fetched: Q9EPK7
# ✅ Fetched: P06684
# ✅ Fetched: P11103
# ✅ Fetched: Q9D6M3
# ✅ Fetched: Q8BFY9
# ✅ Fetched: Q99LG2
# ✅ Fetched: P06728
# ✅ Fetched: P70700
# ✅ Fetched: Q9DCS3
# ✅ Fetched: Q9R0L6
# ✅ Fetched: O89100
# ✅ Fetched: Q62419
# ✅ Fetched: Q99JB8
# ✅ Fetched: Q9WVE8
# ✅ Fetched: Q920E5
# ✅ Fetched: Q80U95
# ✅ Fetched: Q15386
# ✅ Fetched: Q14691
# ✅ Fetched: Q8CIN4
# ✅ Fetched: O88643
# ✅ Fetched: Q01730
# ✅ Fetched: P22907
# ✅ Fetched: Q5I2A0
# ✅ Fetched: P07759
# ✅ Fetched: Q05769
# ✅ Fetched: Q8VEM8
# ✅ Fetched: Q6PFY1
# ✅ Fetched: P97298
# ✅ Fetched: Q16531
# ✅ Fetched: Q60996
# ✅ Fetched: Q7TNL5
# ✅ Fetched: P54116
# ✅ Fetched: P49817
# ✅ Fetched: Q9QY24
# ✅ Fetched: P14901
# ✅ Fetched: P98160
# ✅ Fetched: Q5JTH9
# ✅ Fetched: Q9JK81
# ✅ Fetched: Q9UNS2
# ✅ Fetched: Q99JY0
# ✅ Fetched: Q8QZZ7
# ✅ Fetched: Q6ZQM8
# ✅ Fetched: Q3TIR3
# ✅ Fetched: P47964
# ✅ Fetched: P22892
# ✅ Fetched: O88685
# ✅ Fetched: Q922E4
# ✅ Fetched: Q8CI59
# ✅ Fetched: Q91UZ1
# ✅ Fetched: P10853
# ✅ Fetched: P10854
# ✅ Fetched: P23527
# ✅ Fetched: P57053
# ✅ Fetched: Q8CGP0
# ✅ Fetched: P08752
# ✅ Fetched: P59325
# ✅ Fetched: O55143
# ✅ Fetched: Q7TNC4
# ✅ Fetched: Q9Z2G9
# ✅ Fetched: P83940
# ✅ Fetched: Q9EPE9
# ✅ Fetched: P24547
# ✅ Fetched: O89086
# ✅ Fetched: Q9QXC1
# ✅ Fetched: Q9QY76
# ✅ Fetched: P26369
# ✅ Fetched: Q9D0B6
# ✅ Fetched: Q8C5W4
# ✅ Fetched: P70696
# ✅ Fetched: P70227
# ✅ Fetched: Q60866
# ✅ Fetched: P80318
# ✅ Fetched: B2RXS4
# ✅ Fetched: Q9WTP6
# ✅ Fetched: Q9D1M4
# ✅ Fetched: Q3UZ39
# ✅ Fetched: Q9Y608
# ✅ Fetched: Q9Z2I0
# ✅ Fetched: Q810A7
# ✅ Fetched: O88967
# ✅ Fetched: P22087
# ✅ Fetched: Q9CXF4
# ✅ Fetched: Q9JLJ2
# ✅ Fetched: Q3TIX9
# ✅ Fetched: Q80X73
# ✅ Fetched: Q3TRR0
# ✅ Fetched: Q61176
# ✅ Fetched: Q9EPU0
# ✅ Fetched: Q9D824
# ✅ Fetched: Q3UQ28
# ✅ Fetched: Q0VGY8
# ✅ Fetched: Q8BMJ2
# ✅ Fetched: P61254
# ✅ Fetched: Q8VHZ7
# ✅ Fetched: P23492
# ✅ Fetched: Q62189
# ✅ Fetched: P55258
# ✅ Fetched: Q8BHN5
# ✅ Fetched: Q8C129
# ✅ Fetched: Q9DBR3
# ✅ Fetched: Q8BIJ7
# ✅ Fetched: Q9NS87
# ✅ Fetched: Q9ESJ0
# ✅ Fetched: Q7TNG5
# ✅ Fetched: F7BJB9
# ✅ Fetched: Q9D0R4
# ✅ Fetched: Q3UYV9
# ✅ Fetched: P62996
# ✅ Fetched: Q13595
# ✅ Fetched: Q9CQV5
# ✅ Fetched: O75787
# ✅ Fetched: Q9CRA5
# ✅ Fetched: Q61191
# ✅ Fetched: A0A7N9VSG0
# ✅ Fetched: Q9R099
# ✅ Fetched: P28271
# ✅ Fetched: P52760
# ✅ Fetched: P63154
# ✅ Fetched: Q9CQN7
# ✅ Fetched: Q8BJM3
# ✅ Fetched: Q9DCN2
# ✅ Fetched: Q8R2Y8
# ✅ Fetched: Q91YQ5
# ✅ Fetched: P04843
# ✅ Fetched: P26040
# ✅ Fetched: Q9D1E6
# ✅ Fetched: Q91VR5
# ✅ Fetched: Q9CQG2
# ✅ Fetched: P23953
# ✅ Fetched: D3Z5G7
# ✅ Fetched: Q8R2Y2
# ✅ Fetched: Q63844
# ✅ Fetched: P97789
# ✅ Fetched: Q03147
# ✅ Fetched: Q9UQ88
# ✅ Fetched: P24788
# ✅ Fetched: Q8K2J0
# ✅ Fetched: Q3UHJ0
# ✅ Fetched: Q91ZR2
# ✅ Fetched: Q8WUU5
# ✅ Fetched: Q9WTU6
# ✅ Fetched: Q9UN86
# ✅ Fetched: P97379
# ✅ Fetched: Q58FF7
# ✅ Fetched: Q9WUQ2
# ✅ Fetched: Q920B9
# ✅ Fetched: Q69ZR2
# ✅ Fetched: Q91WD5
# ✅ Fetched: Q9WU56
# ✅ Fetched: P35980
# ✅ Fetched: Q9CXV9
# ✅ Fetched: Q3UTJ2
# ✅ Fetched: P97783
# ✅ Fetched: Q9DBE8
# ✅ Fetched: Q61656
# ✅ Fetched: Q92841
# ✅ Fetched: Q9D6R2
# ✅ Fetched: P11276
# ✅ Fetched: Q8BH86
# ✅ Fetched: Q64152
# ✅ Fetched: P97371
# ✅ Fetched: E9Q512
# ✅ Fetched: Q9DBT3
# ✅ Fetched: Q0GUM3
# ✅ Fetched: Q91V76
# ✅ Fetched: Q9JHU9
# ✅ Fetched: Q9JJA4
# ✅ Fetched: Q80UG5
# ✅ Fetched: Q61941
# ✅ Fetched: Q8VEB4
# ✅ Fetched: P41223
# ✅ Fetched: Q9Z0G0
# ✅ Fetched: Q9D7S9
# ✅ Fetched: P12246
# ✅ Fetched: Q8BYH7
# ✅ Fetched: Q9D937
# ✅ Fetched: Q8VDL4
# ✅ Fetched: P62191
# ✅ Fetched: Q6NXI6
# ✅ Fetched: P51943
# ✅ Fetched: P01867
# ✅ Fetched: P01863
# ✅ Fetched: O35988
# ✅ Fetched: P13864
# ✅ Fetched: Q8BT60
# ✅ Fetched: Q9CPQ8
# ✅ Fetched: P31725
# ✅ Fetched: Q9D2V7
# ✅ Fetched: Q8CHC4
# ✅ Fetched: Q9DCI9
# ✅ Fetched: P23927
# ✅ Fetched: P31001
# ✅ Fetched: A2AN08
# ✅ Fetched: Q9ESZ8
# ✅ Fetched: Q80YR5
# ✅ Fetched: Q8C9B9
# ✅ Fetched: Q8VHE0
# ✅ Fetched: Q6PGF3
# ✅ Fetched: P11157
# ✅ Fetched: Q61152
# ✅ Fetched: P54751
# ✅ Fetched: Q8K2K6
# ✅ Fetched: Q8BX70
# ✅ Fetched: Q9EQQ9
# ✅ Fetched: Q13685
# ✅ Fetched: Q9WV91
# ✅ Fetched: Q61142
# ✅ Fetched: P22682
# ✅ Fetched: P35564
# ✅ Fetched: Q91W92
# ✅ Fetched: Q8K1E0
# ✅ Fetched: Q91YD3
# ✅ Fetched: Q8HWB2
# ✅ Fetched: Q4KN81
# ✅ Fetched: P01898
# ✅ Fetched: Q6PAR5
# ✅ Fetched: P17225
# ✅ Fetched: Q8BHD7
# ✅ Fetched: O70572
# ✅ Fetched: Q9JHS3
# ✅ Fetched: P47915
# ✅ Fetched: Q8CGK3
# ✅ Fetched: Q6A068
# ✅ Fetched: Q6PEB6
# ✅ Fetched: G5E829
# ✅ Fetched: P20020
# ✅ Fetched: Q9JHQ5
# ✅ Fetched: Q12905
# ✅ Fetched: Q9QWH1
# ✅ Fetched: Q9JHI5
# ✅ Fetched: Q5SSH7
# ✅ Fetched: Q8BHG2
# ✅ Fetched: Q9DBG5
# ✅ Fetched: Q02809
# ✅ Fetched: P38647
# ✅ Fetched: P38646
# ✅ Fetched: Q8BH95
# ✅ Fetched: O00443
# ✅ Fetched: Q99M87
# ✅ Fetched: Q62193
# ✅ Fetched: B9EJ54
# ✅ Fetched: P05784
# ✅ Fetched: P17879
# ✅ Fetched: P37913
# ✅ Fetched: P97449
# ✅ Fetched: Q8R0G9
# ✅ Fetched: O35345
# ✅ Fetched: D3Z6Q9
# ✅ Fetched: P62491
# ✅ Fetched: P46638
# ✅ Fetched: Q6P9N1
# ✅ Fetched: Q8VDV3
# ✅ Fetched: Q9CQN1
# ✅ Fetched: P62917
# ✅ Fetched: Q61550
# ✅ Fetched: Q923D5
# ✅ Fetched: Q8VHY0
# ✅ Fetched: Q9QWR8
# ✅ Fetched: P29699
# ✅ Fetched: O00505
# ✅ Fetched: O35344
# ✅ Fetched: E9PVX6
# ✅ Fetched: Q9R1P4
# ✅ Fetched: Q8CJG0
# ✅ Fetched: Q08024
# ✅ Fetched: O35609
# ✅ Fetched: Q8C570
# ✅ Fetched: Q9D3D9
# ✅ Fetched: Q8BXN9
# ✅ Fetched: P15508
# ✅ Fetched: Q3UEB3
# ✅ Fetched: P70280
# ✅ Fetched: Q810D6
# ✅ Fetched: Q8K2T1
# ✅ Fetched: P70349
# ✅ Fetched: Q8K2V1
# ✅ Fetched: P24452
# ✅ Fetched: Q61133
# ✅ Fetched: P13020
# ✅ Fetched: P50428
# ✅ Fetched: P05787
# ✅ Fetched: Q922U2
# ✅ Fetched: Q8BGZ7
# ✅ Fetched: O95678
# ✅ Fetched: Q3UV17
# ✅ Fetched: Q9DCV7
# ✅ Fetched: P63017
# ✅ Fetched: P54652
# ✅ Fetched: Q8K1B8
# ✅ Fetched: P21981
# ✅ Fetched: Q9DAS9
# ✅ Fetched: Q60598
# ✅ Fetched: P01029
# ✅ Fetched: A0AAQ4VMX2
# ✅ Fetched: P54823
# ✅ Fetched: Q9CYL5
# ✅ Fetched: Q9ES74
# ✅ Fetched: P0DOV2
# ✅ Fetched: Q6PIU9
# ✅ Fetched: Q05186
# ✅ Fetched: O09159
# ✅ Fetched: Q9R111
# ✅ Fetched: Q8K157
# ✅ Fetched: Q96C23
# ✅ Fetched: O88545
# ✅ Fetched: P32921
# ✅ Fetched: Q6NSR8
# ✅ Fetched: Q01768
# ✅ Fetched: P11274
# ✅ Fetched: Q8BGQ7
# ✅ Fetched: Q9QXX4
# ✅ Fetched: O55135
# ✅ Fetched: Q9JLT4
# ✅ Fetched: Q6P2B1
# ✅ Fetched: Q8CFX1
# ✅ Fetched: Q8K224
# ✅ Fetched: Q9JMA1
# ✅ Fetched: P56960
# ✅ Fetched: Q06890
# ✅ Fetched: Q922J3
# ✅ Fetched: Q99K41
# ✅ Fetched: P83093
# ✅ Fetched: Q8BNV1
# ✅ Fetched: Q99JR1
# ✅ Fetched: P54310
# ✅ Fetched: Q08AF3
# ✅ Fetched: Q61739
# ✅ Fetched: Q7SIG6
# ✅ Fetched: Q8K2H4
# ✅ Fetched: P42208
# ✅ Fetched: Q91WK2
# ✅ Fetched: Q99LJ0
# ✅ Fetched: Q9DBG6
# ✅ Fetched: Q99N69
# ✅ Fetched: Q9EQH2
# ✅ Fetched: Q8VHK9
# ✅ Fetched: Q8C0T5
# ✅ Fetched: Q6P5G6
# ✅ Fetched: P07205
# ✅ Fetched: Q99K85
# ✅ Fetched: Q9Z1G4
# ✅ Fetched: P51125
# ✅ Fetched: Q9Y3Y2
# ✅ Fetched: Q15022
# ✅ Fetched: Q8CIE6
# ✅ Fetched: P53621
# ✅ Fetched: Q80X41
# ✅ Fetched: Q8R1K1
# ✅ Fetched: Q9ET22
# ✅ Fetched: Q8K0H5
# ✅ Fetched: Q9CZW5
# ✅ Fetched: P22670
# ✅ Fetched: Q99KN9
# ✅ Fetched: Q3URQ0
# ✅ Fetched: Q6ZQH8
# ✅ Fetched: Q8R574
# ✅ Fetched: Q9D0M1
# ✅ Fetched: Q9DCM0
# ✅ Fetched: Q9D6K9
# ✅ Fetched: Q5SWD9
# ✅ Fetched: Q8K1R3
# ✅ Fetched: Q922D8
# ✅ Fetched: Q3UPF5
# ✅ Fetched: Q9Z2Q5
# ✅ Fetched: Q6PR54
# ✅ Fetched: A2AAY5
# ✅ Fetched: Q91W86
# ✅ Fetched: Q9WV32
# ✅ Fetched: Q8BWW9
# ✅ Fetched: A6H6A9
# ✅ Fetched: Q9CZ44
# ✅ Fetched: Q5VT52
# ✅ Fetched: Q9DCT8
# ✅ Fetched: Q69Z38
# ✅ Fetched: Q8R4R6
# ✅ Fetched: Q9D0L8
# ✅ Fetched: Q9BVK8
# ✅ Fetched: P34884
# ✅ Fetched: Q8TEA8
# ✅ Fetched: P28654
# ✅ Fetched: Q8C2Q3
# ✅ Fetched: Q60631
# ✅ Fetched: O88738
# ✅ Fetched: P16627
# ✅ Fetched: P17066
# ✅ Fetched: P57776
# ✅ Fetched: Q99L04
# ✅ Fetched: Q8BVK9
# ✅ Fetched: P35700
# ✅ Fetched: Q06830
# ✅ Fetched: P25789
# ✅ Fetched: P58771
# ✅ Fetched: P07951
# ✅ Fetched: Q6NXL1
# ✅ Fetched: Q9D7X3
# ✅ Fetched: Q6ZPE2
# ✅ Fetched: Q9ER00
# ✅ Fetched: P97310
# ✅ Fetched: O54724
# ✅ Fetched: P70195
# ✅ Fetched: P34914
# ✅ Fetched: D3YWT1
# ✅ Fetched: P70333
# ✅ Fetched: O35737
# ✅ Fetched: Q9Z2X1
# ✅ Fetched: Q8VI75
# ✅ Fetched: Q8K3K7
# ✅ Fetched: Q61599
# ✅ Fetched: Q8CDM1
# ✅ Fetched: P46940
# ✅ Fetched: Q14978
# ✅ Fetched: Q8C7Q4
# ✅ Fetched: P69566
# ✅ Fetched: Q6VN19
# ✅ Fetched: P51149
# ✅ Fetched: O08739
# ✅ Fetched: Q6R0H7
# ✅ Fetched: Q3TNL8
# ✅ Fetched: Q8BI72
# ✅ Fetched: Q9QYR9
# ✅ Fetched: Q3TBD2
# ✅ Fetched: P52196
# ✅ Fetched: Q9D0I8
# ✅ Fetched: Q99MD9
# ✅ Fetched: Q91V12
# ✅ Fetched: O00154
# ✅ Fetched: Q9JIF0
# ✅ Fetched: Q07076
# ✅ Fetched: O35955
# ✅ Fetched: Q14677
# ✅ Fetched: Q76LS9
# ✅ Fetched: P26323
# ✅ Fetched: Q99ME2
# ✅ Fetched: O14950
# ✅ Fetched: P24844
# ✅ Fetched: Q8CIM8
# ✅ Fetched: Q6PAL7
# ✅ Fetched: Q7M6Y3
# ✅ Fetched: Q9R0A0
# ✅ Fetched: Q9D753
# ✅ Fetched: O14910
# ✅ Fetched: P0C872
# ✅ Fetched: Q9CQ71
# ✅ Fetched: Q9CQA0
# ✅ Fetched: P70460
# ✅ Fetched: P61981
# ✅ Fetched: P55065
# ✅ Fetched: Q9DCA2
# ✅ Fetched: O14981
# ✅ Fetched: P50136
# ✅ Fetched: Q9D964
# ✅ Fetched: Q99LD9
# ✅ Fetched: P62195
# ✅ Fetched: Q8VCR7
# ✅ Fetched: Q3UMC0
# ✅ Fetched: Q9DB77
# ✅ Fetched: Q505D1
# ✅ Fetched: A6H611
# ✅ Fetched: P46467
# ✅ Fetched: Q99LB2
# ✅ Fetched: Q8BJW6
# ✅ Fetched: P51437
# ✅ Fetched: P62906
# ✅ Fetched: P47911
# ✅ Fetched: P70441
# ✅ Fetched: Q9QY81
# ✅ Fetched: Q07797
# ✅ Fetched: Q9JHP7
# ✅ Fetched: P56399
# ✅ Fetched: Q8VHL1
# ✅ Fetched: Q9CX11
# ✅ Fetched: E9Q1F5
# ✅ Fetched: Q8C547
# ✅ Fetched: Q8R3C0
# ✅ Fetched: A2A863
# ✅ Fetched: P23116
# ✅ Fetched: P35278
# ✅ Fetched: Q9DBR0
# ✅ Fetched: Q3UDK1
# ✅ Fetched: Q6ZQ08
# ✅ Fetched: Q80TL7
# ✅ Fetched: Q7Z3U7
# ✅ Fetched: P51855
# ✅ Fetched: Q9R0C0
# ✅ Fetched: Q9CXT8
# ✅ Fetched: P32020
# ✅ Fetched: Q3UPY5
# ✅ Fetched: Q99LM2
# ✅ Fetched: Q9D7A6
# ✅ Fetched: P56812
# ✅ Fetched: Q7TSH6
# ✅ Fetched: P58281
# ✅ Fetched: O35250
# ✅ Fetched: P47856
# ✅ Fetched: Q99J45
# ✅ Fetched: P58854
# ✅ Fetched: Q9CPT3
# ✅ Fetched: Q00519
# ✅ Fetched: Q3UMB9
# ✅ Fetched: Q9D1A2
# ✅ Fetched: Q3TIU4
# ✅ Fetched: Q53EL6
# ✅ Fetched: A6H5Y3
# ✅ Fetched: Q3V1T4
# ✅ Fetched: P61513
# ✅ Fetched: Q60960
# ✅ Fetched: O35343
# ✅ Fetched: Q5SQX6
# ✅ Fetched: Q5SW19
# ✅ Fetched: Q3U898
# ✅ Fetched: Q9CSH3
# ✅ Fetched: Q8C7V3
# ✅ Fetched: P54707
# ✅ Fetched: Q9CVB6
# ✅ Fetched: Q8BWU5
# ✅ Fetched: Q9D1M7
# ✅ Fetched: G3X972
# ✅ Fetched: Q8R1G2
# ✅ Fetched: Q8CCP0
# ✅ Fetched: O60524
# ✅ Fetched: P59108
# ✅ Fetched: Q8C052
# ✅ Fetched: P82664
# ✅ Fetched: Q03734
# ✅ Fetched: Q91WP6
# ✅ Fetched: Q99LB6
# ✅ Fetched: P18760
# ✅ Fetched: P06745
# ✅ Fetched: Q9QXG2
# ✅ Fetched: P83887
# ✅ Fetched: Q9NRH3
# ✅ Fetched: Q9Z0P5
# ✅ Fetched: Q8C0D5
# ✅ Fetched: Q99LB0
# ✅ Fetched: P22599
# ✅ Fetched: Q00896
# ✅ Fetched: P60487
# ✅ Fetched: Q8BFP9
# ✅ Fetched: Q8BH61
# ✅ Fetched: Q61578
# ✅ Fetched: Q6ZPU9
# ✅ Fetched: O35892
# ✅ Fetched: Q99747
# ✅ Fetched: P00920
# ✅ Fetched: Q6NVF9
# ✅ Fetched: Q8BFV2
# ✅ Fetched: Q8BTV2
# ✅ Fetched: P70362
# ✅ Fetched: Q3UZA1
# ✅ Fetched: Q9D4H8
# ✅ Fetched: Q8VE18
# ✅ Fetched: Q9D710
# ✅ Fetched: P68510
# ✅ Fetched: Q04917
# ✅ Fetched: P68254
# ✅ Fetched: Q9CQV8
# ✅ Fetched: Q9CRB6
# ✅ Fetched: E9Q557
# ✅ Fetched: P15924
# ✅ Fetched: Q921F4
# ✅ Fetched: Q60590
# ✅ Fetched: P07361
# ✅ Fetched: Q52KI8
# ✅ Fetched: A1Z198
# ✅ Fetched: Q6UXN9
# ✅ Fetched: Q08879
# ✅ Fetched: P14602
# ✅ Fetched: Q9QZE7
# ✅ Fetched: F8VPN4
# ✅ Fetched: P47758
# ✅ Fetched: O54974
# ✅ Fetched: P62814
# ✅ Fetched: Q922V4
# ✅ Fetched: Q8CHP8
# ✅ Fetched: Q9D708
# ✅ Fetched: E9Q236
# ✅ Fetched: O08911
# ✅ Fetched: O88587
# ✅ Fetched: B2RX12
# ✅ Fetched: Q9D1R2
# ✅ Fetched: O75915
# ✅ Fetched: Q8BHB4
# ✅ Fetched: Q571I9
# ✅ Fetched: Q60967
# ✅ Fetched: Q69ZX6
# ✅ Fetched: Q8BTX9
# ✅ Fetched: O14874
# ✅ Fetched: Q61598
# ✅ Fetched: Q8K4L3
# ✅ Fetched: Q8CCJ3
# ✅ Fetched: Q9DCS9
# ✅ Fetched: Q9WTP7
# ✅ Fetched: O35640
# ✅ Fetched: Q9CX56
# ✅ Fetched: Q8CGA0
# ✅ Fetched: Q3V0K9
# ✅ Fetched: A0A1Y7VJE9
# ✅ Fetched: J3QNT6
# ✅ Fetched: P47813
# ✅ Fetched: Q8BTU1
# ✅ Fetched: Q8C147
# ✅ Fetched: Q8R1A4
# ✅ Fetched: Q64213
# ✅ Fetched: Q99LT0
# ✅ Fetched: Q8BH74
# ✅ Fetched: Q99P72
# ✅ Fetched: Q80X82
# ✅ Fetched: P70671
# ✅ Fetched: P97363
# ✅ Fetched: P55769
# ✅ Fetched: B2RQG2
# ✅ Fetched: Q8CEC0
# ✅ Fetched: P35831
# ✅ Fetched: Q8CGC7
# ✅ Fetched: Q8BGS0
# ✅ Fetched: Q8TBZ6
# ✅ Fetched: O54962
# ✅ Fetched: P28653
# ✅ Fetched: Q8VEE0
# ✅ Fetched: Q9ERE7
# ✅ Fetched: P06800
# ✅ Fetched: Q9DCH2
# ✅ Fetched: P50429
# ✅ Fetched: Q91VH6
# ✅ Fetched: Q4KML4
# ✅ Fetched: P08071
# ✅ Fetched: O75874
# ✅ Fetched: E9Q137
# ✅ Fetched: O55142
# ✅ Fetched: Q7TNB8
# ✅ Fetched: Q04750
# ✅ Fetched: P11387
# ✅ Fetched: Q99JW4
# ✅ Fetched: P61224
# ✅ Fetched: O95716
# ✅ Fetched: Q8BFZ3
# ✅ Fetched: Q562R1
# ✅ Fetched: Q9Z2I9
# ✅ Fetched: Q91W59
# ✅ Fetched: P19253
# ✅ Fetched: O70194
# ✅ Fetched: A2AWA9
# ✅ Fetched: Q9Y3P9
# ✅ Fetched: Q9CX86
# ✅ Fetched: Q99KF1
# ✅ Fetched: Q8R1V4
# ✅ Fetched: Q8R016
# ✅ Fetched: Q8BM96
# ✅ Fetched: P67936
# ✅ Fetched: P62633
# ✅ Fetched: P31266
# ✅ Fetched: O08573
# ✅ Fetched: Q9R0K7
# ✅ Fetched: P60510
# ✅ Fetched: Q9CQA3
# ✅ Fetched: P62244
# ✅ Fetched: P28862
# ✅ Fetched: Q9Z1N5
# ✅ Fetched: P31949
# ✅ Fetched: P70663
# ✅ Fetched: Q91V83
# ✅ Fetched: Q9QZB7
# ✅ Fetched: Q86US8
# ✅ Fetched: Q8BVU5
# ✅ Fetched: Q9CZ04
# ✅ Fetched: Q14980
# ✅ Fetched: Q9R0P5
# ✅ Fetched: P70336
# ✅ Fetched: Q8CC35
# ✅ Fetched: P19639
# ✅ Fetched: Q8R1B4
# ✅ Fetched: P17751
# ✅ Fetched: O70492
# ✅ Fetched: Q91YU8
# ✅ Fetched: D3Z2H9
# ✅ Fetched: Q6P5F9
# ✅ Fetched: P97452
# ✅ Fetched: Q6P069
# ✅ Fetched: Q923D2
# ✅ Fetched: Q3UGS4
# ✅ Fetched: Q99N92
# ✅ Fetched: Q8VDW0
# ✅ Fetched: O00148
# ✅ Fetched: P10639
# ✅ Fetched: Q922Q4
# ✅ Fetched: Q922W5
# ✅ Fetched: Q7Z406
# ✅ Fetched: Q5SX39
# ✅ Fetched: Q9UKX3
# ✅ Fetched: A2AQP0
# ✅ Fetched: Q8BU30
# ✅ Fetched: P62306
# ✅ Fetched: Q91ZW3
# ✅ Fetched: Q8R1Q8
# ✅ Fetched: Q6PDL0
# ✅ Fetched: Q3UE37
# ✅ Fetched: P62280
# ✅ Fetched: Q8VDD9
# ✅ Fetched: Q09014
# ✅ Fetched: Q8C0E3
# ✅ Fetched: P11117
# ✅ Fetched: Q99JR5
# ✅ Fetched: P97822
# ✅ Fetched: Q13185
# ✅ Fetched: P45973
# ✅ Fetched: P83916
# ✅ Fetched: Q3UFY7
# ✅ Fetched: P46460
# ✅ Fetched: Q61554
# ✅ Fetched: Q8K4P0
# ✅ Fetched: Q91WJ8
# ✅ Fetched: Q3ULW8
# ✅ Fetched: Q8C7R4
# ✅ Fetched: P21619
# ✅ Fetched: Q9D2C2
# ✅ Fetched: Q9WU78
# ✅ Fetched: Q13526
# ✅ Fetched: Q9JL16
# ✅ Fetched: Q69ZA1
# ✅ Fetched: P52624
# ✅ Fetched: P07742
# ✅ Fetched: Q91X72
# ✅ Fetched: P21291
# ✅ Fetched: P36552
# ✅ Fetched: Q9BTC8
# ✅ Fetched: Q924K8
# ✅ Fetched: Q15654
# ✅ Fetched: Q9CZD3
# ✅ Fetched: Q8R1G6
# ✅ Fetched: Q9R190
# ✅ Fetched: Q8K4B0
# ✅ Fetched: Q922D4
# ✅ Fetched: P30050
# ✅ Fetched: Q80ZX0
# ✅ Fetched: O95486
# ✅ Fetched: Q3U2P1
# ✅ Fetched: Q99KI0
# ✅ Fetched: Q6WVG3
# ✅ Fetched: Q9CZN8
# ✅ Fetched: O09106
# ✅ Fetched: Q15024
# ✅ Fetched: Q9WVA3
# ✅ Fetched: Q9WV55
# ✅ Fetched: Q9P0L0
# ✅ Fetched: P26443
# ✅ Fetched: Q9Z0S1
# ✅ Fetched: Q922Q1
# ✅ Fetched: Q8CD92
# ✅ Fetched: Q6P3X3
# ✅ Fetched: P60766
# ✅ Fetched: P84095
# ✅ Fetched: P15153
# ✅ Fetched: Q8C0C7
# ✅ Fetched: P62962
# ✅ Fetched: Q1HFZ0
# ✅ Fetched: Q08J23
# ✅ Fetched: Q9ESD7
# ✅ Fetched: Q8VDQ8
# ✅ Fetched: Q8CBY8
# ✅ Fetched: Q8VBW6
# ✅ Fetched: A2AGT5
# ✅ Fetched: Q8NBU5
# ✅ Fetched: Q9R269
# ✅ Fetched: P46061
# ✅ Fetched: O88447
# ✅ Fetched: P58021
# ✅ Fetched: O35326
# ✅ Fetched: P23591
# ✅ Fetched: Q8CC86
# ✅ Fetched: Q9CWQ0
# ✅ Fetched: Q9R0U0
# ✅ Fetched: Q01130
# ✅ Fetched: Q921M7
# ✅ Fetched: Q91W61
# ✅ Fetched: P40201
# ✅ Fetched: O14646
# ✅ Fetched: Q9DCD0
# ✅ Fetched: Q9ER38
# ✅ Fetched: P14824
# ✅ Fetched: P46977
# ✅ Fetched: Q9BTA9
# ✅ Fetched: Q9JII6
# ✅ Fetched: O35218
# ✅ Fetched: Q60591
# ✅ Fetched: P16474
# ✅ Fetched: Q4FK66
# ✅ Fetched: O55126
# ✅ Fetched: O75323
# ✅ Fetched: O55125
# ✅ Fetched: Q13107
# ✅ Fetched: Q9CWX4
# ✅ Fetched: Q8QZV7
# ✅ Fetched: Q61239
# ✅ Fetched: P62330
# ✅ Fetched: Q9EPB4
# ✅ Fetched: P24270
# ✅ Fetched: Q8BHZ0
# ✅ Fetched: P25189
# ✅ Fetched: Q6ZWR6
# ✅ Fetched: Q571H0
# ✅ Fetched: P23949
# ✅ Fetched: Q9DCJ9
# ✅ Fetched: P03987
# ✅ Fetched: Q8CG19
# ✅ Fetched: Q86W92
# ✅ Fetched: O35459
# ✅ Fetched: Q925B0
# ✅ Fetched: P62701
# ✅ Fetched: P22090
# ✅ Fetched: Q8BYW1
# ✅ Fetched: Q8BW10
# ✅ Fetched: O35639
# ✅ Fetched: Q3TC93
# ✅ Fetched: Q99L45
# ✅ Fetched: O35075
# ✅ Fetched: Q8BIK4
# ✅ Fetched: P58929
# ✅ Fetched: P84084
# ✅ Fetched: P61204
# ✅ Fetched: P48453
# ✅ Fetched: Q9R1P1
# ✅ Fetched: Q61595
# ✅ Fetched: Q86UP2
# ✅ Fetched: P62805
# ✅ Fetched: Q9UEW8
# ✅ Fetched: O35841
# ✅ Fetched: O55234
# ✅ Fetched: Q9QUH0
# ✅ Fetched: Q8K2Y9
# ✅ Fetched: Q9EPL9
# ✅ Fetched: O88512
# ✅ Fetched: Q9R0E1
# ✅ Fetched: Q9R059
# ✅ Fetched: P35442
# ✅ Fetched: P27641
# ✅ Fetched: P14211
# ✅ Fetched: P46935
# ✅ Fetched: Q7TSI3
# ✅ Fetched: Q9WVA4
# ✅ Fetched: Q9CQI6
# ✅ Fetched: P01904
# ✅ Fetched: O55201
# ✅ Fetched: G3UYY4
# ✅ Fetched: Q9D1K2
# ✅ Fetched: Q8BXZ1
# ✅ Fetched: Q9H3S7
# ✅ Fetched: P51432
# ✅ Fetched: P50518
# ✅ Fetched: Q6ZQL4
# ✅ Fetched: O08709
# ✅ Fetched: Q8K3G5
# ✅ Fetched: Q8K310
# ✅ Fetched: Q9ERI5
# ✅ Fetched: Q8VEK0
# ✅ Fetched: Q9D1Q6
# ✅ Fetched: Q9D855
# ✅ Fetched: Q80TZ9
# ✅ Fetched: B2RXC1
# ✅ Fetched: P29391
# ✅ Fetched: A2ALS5
# ✅ Fetched: P09528
# ✅ Fetched: P26645
# ✅ Fetched: Q921T2
# ✅ Fetched: Q60692
# ✅ Fetched: Q8VBV3
# ✅ Fetched: O54931
# ✅ Fetched: P33609
# ✅ Fetched: P19324
# ✅ Fetched: Q9QY06
# ✅ Fetched: Q8BH04
# ✅ Fetched: Q6P9Q6
# ✅ Fetched: Q8R361
# ✅ Fetched: Q60972
# ✅ Fetched: Q8VHC3
# ✅ Fetched: Q61553
# ✅ Fetched: Q61937
# ✅ Fetched: P51410
# ✅ Fetched: P70257
# ✅ Fetched: D3YU81
# ✅ Fetched: Q4FJU9
# ✅ Fetched: Q9ES00
# ✅ Fetched: Q8CI75
# ✅ Fetched: Q5SWU9
# ✅ Fetched: A2A6A1
# ✅ Fetched: P46938
# ✅ Fetched: Q9DCE5
# ✅ Fetched: Q8C5N3
# ✅ Fetched: Q80Y81
# ✅ Fetched: A2BH40
# ✅ Fetched: P47757
# ✅ Fetched: Q6A065
# ✅ Fetched: P49591
# ✅ Fetched: Q9CQ49
# ✅ Fetched: P56589
# ✅ Fetched: Q6AXC6
# ✅ Fetched: Q99LD8
# ✅ Fetched: Q9D666
# ✅ Fetched: P08103
# ✅ Fetched: Q02788
# ✅ Fetched: Q62178
# ✅ Fetched: Q60875
# ✅ Fetched: Q8R0X7
# ✅ Fetched: Q7TT37
# ✅ Fetched: Q61247
# ✅ Fetched: P97855
# ✅ Fetched: Q8BK72
# ✅ Fetched: P21956
# ✅ Fetched: Q3UVK0
# ✅ Fetched: Q9D2N9
# ✅ Fetched: P29452
# ✅ Fetched: Q7L2H7
# ✅ Fetched: O88379
# ✅ Fetched: Q8R3V5
# ✅ Fetched: Q4VAE3
# ✅ Fetched: Q99MJ9
# ✅ Fetched: Q9UHD2
# ✅ Fetched: A2ASQ1
# ✅ Fetched: Q62167
# ✅ Fetched: Q9H2M9
# ✅ Fetched: Q8VDS8
# ✅ Fetched: P14685
# ✅ Fetched: Q9CPU0
# ✅ Fetched: P63173
# ✅ Fetched: P49290
# ✅ Fetched: O43447
# ✅ Fetched: Q9D0W5
# ✅ Fetched: Q99JR8
# ✅ Fetched: Q8CI94
# ✅ Fetched: Q9R118
# ✅ Fetched: P08003
# ✅ Fetched: Q9DCT2
# ✅ Fetched: Q9JK53
# ✅ Fetched: Q8CFE3
# ✅ Fetched: C0HKD8
# ✅ Fetched: O35129
# ✅ Fetched: Q99L13
# ✅ Fetched: Q9D5V5
# ✅ Fetched: P70699
# ✅ Fetched: Q91XI1
# ✅ Fetched: P02089
# ✅ Fetched: P02088
# ✅ Fetched: Q8BMK4
# ✅ Fetched: P10630
# ✅ Fetched: P60842
# ✅ Fetched: Q3TVI8
# ✅ Fetched: Q9EPQ7
# ✅ Fetched: P28776
# ✅ Fetched: Q60767
# ✅ Fetched: Q9WUR2
# ✅ Fetched: Q00623
# ✅ Fetched: P47740
# ✅ Fetched: Q99KV1
# ✅ Fetched: P97311
# ✅ Fetched: P37040
# ✅ Fetched: P30876
# ✅ Fetched: Q9WVL3
# ✅ Fetched: Q6PF93
# ✅ Fetched: P04117
# ✅ Fetched: Q99MS7
# ✅ Fetched: P30101
# ✅ Fetched: Q8C092
# ✅ Fetched: Q15542
# ✅ Fetched: P58242
# ✅ Fetched: Q9Z0X1
# ✅ Fetched: P54923
# ✅ Fetched: Q3UBZ5
# ✅ Fetched: Q68FL4
# ✅ Fetched: Q8R3W5
# ✅ Fetched: Q8C1D8
# ✅ Fetched: Q9D0R9
# ✅ Fetched: Q9R1P3
# ✅ Fetched: Q9WTI7
# ✅ Fetched: Q15417
# ✅ Fetched: Q80VP1
# ✅ Fetched: Q9H254
# ✅ Fetched: E9PX29
# ✅ Fetched: Q3UGR5
# ✅ Fetched: Q8BZW8
# ✅ Fetched: Q00612
# ✅ Fetched: Q9CZU6
# ✅ Fetched: Q53QV2
# ✅ Fetched: Q9D0B0
# ✅ Fetched: Q9D967
# ✅ Fetched: O60884
# ✅ Fetched: P0DP26
# ✅ Fetched: Q61655
# ✅ Fetched: P08121
# ✅ Fetched: Q99LE6
# ✅ Fetched: P36371
# ✅ Fetched: Q07113
# ✅ Fetched: P20152
# ✅ Fetched: Q9ESE1
# ✅ Fetched: P10126
# ✅ Fetched: Q9CR16
# ✅ Fetched: Q08752
# ✅ Fetched: P61964
# ✅ Fetched: Q80TR8
# ✅ Fetched: P28076
# ✅ Fetched: Q8K3X4
# ✅ Fetched: Q8R0F6
# ✅ Fetched: Q9JJL8
# ✅ Fetched: P70677
# ✅ Fetched: P28665
# ✅ Fetched: P83741
# ✅ Fetched: Q8VCM8
# ✅ Fetched: Q60772
# ✅ Fetched: P39654
# ✅ Fetched: Q8BH57
# ✅ Fetched: P08228
# ✅ Fetched: P62829
# ✅ Fetched: Q8CBA2
# ✅ Fetched: P58137
# ✅ Fetched: Q9JKB3
# ✅ Fetched: Q7TSV4
# ✅ Fetched: P62826
# ✅ Fetched: Q61820
# ✅ Fetched: Q9CQR2
# ✅ Fetched: P63037
# ✅ Fetched: Q9CPP0
# ✅ Fetched: Q9DBH5
# ✅ Fetched: P09103
# ✅ Fetched: Q8BP47
# ✅ Fetched: O43776
# ✅ Fetched: Q80U44
# ✅ Fetched: Q3TLH4
# ✅ Fetched: Q9BRJ7
# ✅ Fetched: E9Q9G1
# ✅ Fetched: Q6P3D0
# ✅ Fetched: P11247
# ✅ Fetched: P05164
# ✅ Fetched: Q99M28
# ✅ Fetched: P33610
# ✅ Fetched: Q9CWS0
# ✅ Fetched: Q3UVG3
# ✅ Fetched: Q62446
# ✅ Fetched: Q9DBS5
# ✅ Fetched: P63279
# ✅ Fetched: P25206
# ✅ Fetched: Q62318
# ✅ Fetched: O60238
# ✅ Fetched: P32233
# ✅ Fetched: Q91YK2
# ✅ Fetched: Q61830
# ✅ Fetched: Q8VDG3
# ✅ Fetched: Q6PGH2
# ✅ Fetched: Q9Z2X2
# ✅ Fetched: P47753
# ✅ Fetched: P63167
# ✅ Fetched: Q9JJU8
# ✅ Fetched: Q9D554
# ✅ Fetched: Q9CWG9
# ✅ Fetched: P23229
# ✅ Fetched: P70399
# ✅ Fetched: Q8C8N2
# ✅ Fetched: P97369
# ✅ Fetched: Q5SWW4
# ✅ Fetched: P63101
# ✅ Fetched: P51553
# ✅ Fetched: Q13503
# ✅ Fetched: Q9WUD1
# ✅ Fetched: Q9D6J6
# ✅ Fetched: Q3UMF0
# ✅ Fetched: P35527
# ✅ Fetched: P38919
# ✅ Fetched: Q3T9E4
# ✅ Fetched: Q91X20
# ✅ Fetched: Q9D8U0
# ✅ Fetched: Q6A026
# ✅ Fetched: Q29RF7
# ✅ Fetched: P54071
# ✅ Fetched: P48735
# ✅ Fetched: P33240
# ✅ Fetched: Q8BIQ5
# ✅ Fetched: Q8C7E9
# ✅ Fetched: Q3V3R4
# ✅ Fetched: Q9D3U0
# ✅ Fetched: Q8BHL5
# ✅ Fetched: Q8BPU7
# ✅ Fetched: Q96JJ3
# ✅ Fetched: G5E897
# ✅ Fetched: P16015
# ✅ Fetched: Q8N752
# ✅ Fetched: Q8R3I3
# ✅ Fetched: G5E8Q8
# ✅ Fetched: Q99M31
# ✅ Fetched: Q8VE38
# ✅ Fetched: A2A5R2
# ✅ Fetched: Q60759
# ✅ Fetched: Q9DBN5
# ✅ Fetched: P14131
# ✅ Fetched: Q9D8Y7
# ✅ Fetched: O08848
# ✅ Fetched: Q9BDB7
# ✅ Fetched: Q9CXR1
# ✅ Fetched: P49902
# ✅ Fetched: Q8BQM4
# ✅ Fetched: P62753
# ✅ Fetched: Q9Z247
# ✅ Fetched: Q9CZX0
# ✅ Fetched: Q9CQC8
# ✅ Fetched: P47754
# ✅ Fetched: Q8CG47
# ✅ Fetched: Q8CI11
# ✅ Fetched: P62854
# ✅ Fetched: Q13573
# ✅ Fetched: P08113
# ✅ Fetched: Q92598
# ✅ Fetched: P48722
# ✅ Fetched: P15105
# ✅ Fetched: Q62422
# ✅ Fetched: O14556
# ✅ Fetched: A0A075B5N9
# ✅ Fetched: Q64518
# ✅ Fetched: Q8R429
# ✅ Fetched: O75131
# ✅ Fetched: Q86YQ8
# ✅ Fetched: Q07235
# ✅ Fetched: O35887
# ✅ Fetched: Q9Y2H0
# ✅ Fetched: Q78PY7
# ✅ Fetched: Q8BPM2
# ✅ Fetched: E9PYG6
# ✅ Fetched: O88879
# ✅ Fetched: P06151
# ✅ Fetched: Q9EPC1
# ✅ Fetched: Q8VC57
# ✅ Fetched: Q61768
# ✅ Fetched: Q80UM7
# ✅ Fetched: Q06770
# ✅ Fetched: Q02819
# ✅ Fetched: Q6ZQK5
# ✅ Fetched: P56546
# ✅ Fetched: Q922K7
# ✅ Fetched: Q3THG9
# ✅ Fetched: Q8K2Z4
# ✅ Fetched: Q9EQ61
# ✅ Fetched: P70122
# ✅ Fetched: Q6ZQI3
# ✅ Fetched: A2AHR2
# ✅ Fetched: Q3UIR3
# ✅ Fetched: Q8BWZ3
# ✅ Fetched: Q8C7I4
# ✅ Fetched: Q6ZWQ0
# ✅ Fetched: Q8K0F1
# ✅ Fetched: Q99LF4
# ✅ Fetched: Q93034
# ✅ Fetched: P97864
# ✅ Fetched: P42345
# ✅ Fetched: Q14C51
# ✅ Fetched: P50851
# ✅ Fetched: Q91Z53
# ✅ Fetched: Q8C863
# ✅ Fetched: P53995
# ✅ Fetched: Q15555
# ✅ Fetched: Q80WQ2
# ✅ Fetched: Q4VBE8
# ✅ Fetched: Q04447
# ✅ Fetched: Q9CQH8
# ✅ Fetched: Q9HCJ1
# ✅ Fetched: Q8C0I1
# ✅ Fetched: Q8BYY4
# ✅ Fetched: P26516
# ✅ Fetched: Q91W39
# ✅ Fetched: Q8VEH5
# ✅ Fetched: Q9CQT1
# ✅ Fetched: P01872
# ✅ Fetched: Q91W96
# ✅ Fetched: Q14185
# ✅ Fetched: Q8C3J5
# ✅ Fetched: Q9QZN4
# ✅ Fetched: O76031
# ✅ Fetched: P63028
# ✅ Fetched: Q15349
# ✅ Fetched: P05132
# ✅ Fetched: Q9Z0L0
# ✅ Fetched: P08758
# ✅ Fetched: A3KMH1
# ✅ Fetched: Q6ZWY3
# ✅ Fetched: P42677
# ✅ Fetched: P47811
# ✅ Fetched: Q9Z0W3
# ✅ Fetched: Q9JIG7
# ✅ Fetched: P49615
# ✅ Fetched: P56565
# ✅ Fetched: Q8R322
# ✅ Fetched: Q3UMR5
# ✅ Fetched: Q86UA1
# ✅ Fetched: Q9D1D4
# ✅ Fetched: Q8NHV1
# ✅ Fetched: B2RUP2
# ✅ Fetched: P13707
# ✅ Fetched: P61160
# ✅ Fetched: Q8C4Q6
# ✅ Fetched: P00492
# ✅ Fetched: Q8K2D3
# ✅ Fetched: Q9CQV4
# ✅ Fetched: Q9JKF7
# ✅ Fetched: Q9BPZ3
# ✅ Fetched: Q3U308
# ✅ Fetched: Q9CRT8
# ✅ Fetched: E1U8D0
# ✅ Fetched: O08547
# ✅ Fetched: O88492
# ✅ Fetched: Q99JY3
# ✅ Fetched: O09012
# ✅ Fetched: A2RTH5
# ✅ Fetched: Q99PG2
# ✅ Fetched: Q6N069
# ✅ Fetched: Q6PGG2
# ✅ Fetched: Q689Z5
# ✅ Fetched: Q8K2Q0
# ✅ Fetched: Q8CAS9
# ✅ Fetched: A0A140LIF8
# ✅ Fetched: Q9QZH6
# ✅ Fetched: Q6PFD6
# ✅ Fetched: P05555
# ✅ Fetched: Q6VNB8
# ✅ Fetched: Q8CG70
# ✅ Fetched: Q8C522
# ✅ Fetched: P70665
# ✅ Fetched: Q9WVM3
# ✅ Fetched: Q569Z5
# ✅ Fetched: P07607
# ✅ Fetched: Q9D024
# ✅ Fetched: Q91VA7
# ✅ Fetched: Q62351
# ✅ Fetched: Q8QZY1
# ✅ Fetched: P62841
# ✅ Fetched: Q8BWF0
# ✅ Fetched: Q8BV66
# ✅ Fetched: Q3TBT3
# ✅ Fetched: Q64105
# ✅ Fetched: Q64261
# ✅ Fetched: O88428
# ✅ Fetched: Q9JLV5
# ✅ Fetched: Q13347
# ✅ Fetched: Q9D083
# ✅ Fetched: Q9ERA6
# ✅ Fetched: P54103
# ✅ Fetched: Q7TSS2
# ✅ Fetched: Q4PZA2
# ✅ Fetched: Q03265
# ✅ Fetched: Q64151
# ✅ Fetched: P06797
# ✅ Fetched: Q9CQW2
# ✅ Fetched: P06683
# ✅ Fetched: P60228
# ✅ Fetched: P31532
# ✅ Fetched: Q9ERS5
# ✅ Fetched: Q62048
# ✅ Fetched: Q8R2U4
# ✅ Fetched: Q8VE37
# ✅ Fetched: Q9NVW2
# ✅ Fetched: Q9D051
# ✅ Fetched: P0DOV1
# ✅ Fetched: P01831
# ✅ Fetched: Q9D020
# ✅ Fetched: Q63918
# ✅ Fetched: O70378
# ✅ Fetched: Q99KJ8
# ✅ Fetched: Q9CYH6
# ✅ Fetched: L7N257
# ✅ Fetched: P08708
# ✅ Fetched: Q5U5M8
# ✅ Fetched: Q80TN4
# ✅ Fetched: Q6UXI9
# ✅ Fetched: Q91V88
# ✅ Fetched: Q8BKS9
# ✅ Fetched: Q8TB40
# ✅ Fetched: O35074
# ✅ Fetched: O54946
# ✅ Fetched: Q6A009
# ✅ Fetched: Q9JLM4
# ✅ Fetched: Q9CY64
# ✅ Fetched: P09874
# ✅ Fetched: Q8BRF7
# ✅ Fetched: Q62376
# ✅ Fetched: Q61263
# ✅ Fetched: Q8BHL8
# ✅ Fetched: P97494
# ✅ Fetched: P48163
# ✅ Fetched: Q61189
# ✅ Fetched: Q9Z2D1
# ✅ Fetched: Q9R1T2
# ✅ Fetched: Q04207
# ✅ Fetched: Q99P88
# ✅ Fetched: Q9CR68
# ✅ Fetched: Q9JLV1
# ✅ Fetched: O54782
# ✅ Fetched: Q9JJF3
# ✅ Fetched: O35382
# ✅ Fetched: Q91Z38
# ✅ Fetched: Q6P3A8
# ✅ Fetched: Q9CYN2
# ✅ Fetched: O08602
# ✅ Fetched: Q99P30
# ✅ Fetched: Q68FM7
# ✅ Fetched: Q99KQ4
# ✅ Fetched: Q8JZX4
# ✅ Fetched: Q71LX4
# ✅ Fetched: P97821
# ✅ Fetched: Q9D6J5
# ✅ Fetched: Q99J95
# ✅ Fetched: A6H5X4
# ✅ Fetched: Q62036
# ✅ Fetched: Q5PSV9
# ✅ Fetched: P14069
# ✅ Fetched: P06703
# ✅ Fetched: P08134
# ✅ Fetched: P61586
# ✅ Fetched: P61758
# ✅ Fetched: P10605
# ✅ Fetched: O88697
# ✅ Fetched: Q9Y285
# ✅ Fetched: O54786
# ✅ Fetched: P97370
# ✅ Fetched: P08680
# ✅ Fetched: Q9JKK1
# ✅ Fetched: Q8CIB5
# ✅ Fetched: P33611
# ✅ Fetched: P55937
# ✅ Fetched: Q99KY4
# ✅ Fetched: P07758
# ✅ Fetched: Q00898
# ✅ Fetched: Q5SF07
# ✅ Fetched: Q9Y6M1
# ✅ Fetched: A2A654
# ✅ Fetched: P42225
# ✅ Fetched: Q9CXI5
# ✅ Fetched: Q8C3R1
# ✅ Fetched: Q61193
# ✅ Fetched: Q9ESX5
# ✅ Fetched: O35134
# ✅ Fetched: O95602
# ✅ Fetched: Q9QUR6
# ✅ Fetched: Q9Z280
# ✅ Fetched: P28574
# ✅ Fetched: A6NHR9
# ✅ Fetched: Q3TAQ9
# ✅ Fetched: Q8K0Q5
# ✅ Fetched: Q6NSQ9
# ✅ Fetched: O70145
# ✅ Fetched: P62277
# ✅ Fetched: P35922
# ✅ Fetched: Q96NC0
# ✅ Fetched: Q3V1V3
# ✅ Fetched: Q9Z0U1
# ✅ Fetched: A3KGB4
# ✅ Fetched: Q8R015
# ✅ Fetched: P70388
# ✅ Fetched: Q68FG2
# ✅ Fetched: P35282
# ✅ Fetched: P16045
# ✅ Fetched: Q8K4Z5
# ✅ Fetched: Q8C4Y3
# ✅ Fetched: D3Z7P3
# ✅ Fetched: Q925H1
# ✅ Fetched: Q9ESB3
# ✅ Fetched: O08992
# ✅ Fetched: Q921E6
# ✅ Fetched: Q6DFV1
# ✅ Fetched: Q9JM96
# ✅ Fetched: Q99020
# ✅ Fetched: P47941
# ✅ Fetched: Q99KW3
# ✅ Fetched: O70456
# ✅ Fetched: Q16828
# ✅ Fetched: P61294
# ✅ Fetched: P20340
# ✅ Fetched: P01837
# ✅ Fetched: P27046
# ✅ Fetched: Q9NQT8
# ✅ Fetched: O35071
# ✅ Fetched: B1AVY7
# ✅ Fetched: Q9P2P6
# ✅ Fetched: Q80TF6
# ✅ Fetched: Q8R404
# ✅ Fetched: Q9CZR2
# ✅ Fetched: Q91VM5
# ✅ Fetched: Q9R0X4
# ✅ Fetched: P09803
# ✅ Fetched: O15145
# ✅ Fetched: Q62203
# ✅ Fetched: Q8K019
# ✅ Fetched: Q9NYF8
# ✅ Fetched: P53994
# ✅ Fetched: P60866
# ✅ Fetched: O54734
# ✅ Fetched: Q91VK1
# ✅ Fetched: P24369
# ✅ Fetched: P32067
# ✅ Fetched: Q8NF91
# ✅ Fetched: Q9CX97
# ✅ Fetched: Q640N1
# ✅ Fetched: Q8BHX1
# ✅ Fetched: Q9JMF7
# ✅ Fetched: P70318
# ✅ Fetched: Q0P678
# ✅ Fetched: Q99JN2
# ✅ Fetched: Q9DCS2
# ✅ Fetched: Q6WKZ4
# ✅ Fetched: Q9D0S9
# ✅ Fetched: Q06138
# ✅ Fetched: Q9H3W5
# ✅ Fetched: Q9D1M0
# ✅ Fetched: Q9R207
# ✅ Fetched: Q3U1Y4
# ✅ Fetched: Q9D945
# ✅ Fetched: P10852
# ...
# ✅ Fetched: Q3UPH1
# ✅ Fetched: O00425
# ✅ Fetched: Q9CPP6
# ✅ Fetched: P33173
# ✅ Fetched: Q91VJ2
# ✅ Fetched: Q9EP97
# ✅ Fetched: Q91XL1
# ✅ Fetched: Q99P69
# ✅ Fetched: Q9EQ80
# ✅ Fetched: P51655
# ✅ Fetched: Q80VA0
# ✅ Fetched: Q8BXV2
# ✅ Fetched: Q6DT37
# ✅ Fetched: Q09XV5
# ✅ Fetched: Q9D7N9
# ✅ Fetched: Q01658
# ✅ Fetched: Q91YJ3
# ✅ Fetched: Q8K0B2
# ✅ Fetched: Q64442
# ✅ Fetched: D3Z286
# ✅ Fetched: P14106
# ✅ Fetched: Q8BG95
# ✅ Fetched: Q61301
# ✅ Fetched: Q9JIS8
# ✅ Fetched: Q921U8
# ✅ Fetched: P70389
# ✅ Fetched: E9Q5C9
# ✅ Fetched: Q61333
# ✅ Fetched: Q9BZF1
# ✅ Fetched: P61081
# ✅ Fetched: Q9JKV1
# ✅ Fetched: Q8BM39
# ✅ Fetched: O89023
# ✅ Fetched: Q8C0D4
# ✅ Fetched: O43809
# ✅ Fetched: Q91XE4
# ✅ Fetched: Q3THF9
# ✅ Fetched: Q6PAL0
# ✅ Fetched: Q9DB30
# ✅ Fetched: Q9DB85
# ✅ Fetched: Q8R2N2
# ✅ Fetched: Q5SSK3
# ✅ Fetched: Q811S7
# ✅ Fetched: Q91VY9
# ✅ Fetched: Q810S1
# ✅ Fetched: P42859
# ✅ Fetched: O88456
# ✅ Fetched: Q8BSK8
# ✅ Fetched: Q61425
# ✅ Fetched: P70288
# ✅ Fetched: Q9CPW2
# ✅ Fetched: Q86UY6
# ✅ Fetched: O88845
# ✅ Fetched: Q8K0D0
# ✅ Fetched: Q9Z1R9
# ✅ Fetched: P56135
# ✅ Fetched: P12110
# ✅ Fetched: B9EKI3
# ✅ Fetched: Q9CPR5
# ✅ Fetched: P37804
# ✅ Fetched: O08997
# ✅ Fetched: P21271
# ✅ Fetched: Q68FH4
# ✅ Fetched: O43790
# ✅ Fetched: Q9NSB2
# ✅ Fetched: P10155
# ✅ Fetched: Q6ZPY7
# ✅ Fetched: Q8BGA7
# ✅ Fetched: Q91WA6
# ✅ Fetched: Q8BMZ5
# ✅ Fetched: P49282
# ✅ Fetched: Q05048
# ✅ Fetched: Q6GV12
# ✅ Fetched: Q9NQX4
# ✅ Fetched: Q8CFE4
# ✅ Fetched: P28843
# ✅ Fetched: Q80YC5
# ✅ Fetched: Q99LC3
# ✅ Fetched: P09021
# ✅ Fetched: Q9D1P0
# ✅ Fetched: Q9ESP1
# ✅ Fetched: Q99470
# ✅ Fetched: P41236
# ✅ Fetched: Q5T0B9
# ✅ Fetched: Q922J9
# ✅ Fetched: P53564
# ✅ Fetched: O43617
# ✅ Fetched: Q3TWW8
# ✅ Fetched: Q7TS74
# ✅ Fetched: Q9CVD2
# ✅ Fetched: P60059
# ✅ Fetched: Q9JMD0
# ✅ Fetched: Q3TNH5
# ✅ Fetched: P15066
# ✅ Fetched: O14957
# ✅ Fetched: P53350
# ✅ Fetched: E9PZJ8
# ✅ Fetched: Q2UY11
# ✅ Fetched: Q3TYS2
# ✅ Fetched: Q80ZV0
# ✅ Fetched: P31786
# ✅ Fetched: O95870
# ✅ Fetched: Q80V94
# ✅ Fetched: Q99LS3
# ✅ Fetched: O15155
# ✅ Fetched: Q6A028
# ✅ Fetched: Q8R0Y8
# ✅ Fetched: Q3U3R4
# ✅ Fetched: Q8VDT9
# ✅ Fetched: Q13523
# ✅ Fetched: Q9JK92
# ✅ Fetched: O75063
# ✅ Fetched: Q4FZC9
# ✅ Fetched: Q8VCH8
# ✅ Fetched: Q8BX57
# ✅ Fetched: Q8CIV8
# ✅ Fetched: Q9Z1A1
# ✅ Fetched: Q9DBS9
# ✅ Fetched: Q9DBJ3
# ✅ Fetched: Q3UM29
# ✅ Fetched: P22366
# ✅ Fetched: O35864
# ✅ Fetched: Q921M4
# ✅ Fetched: Q61543
# ✅ Fetched: Q3UFY8
# ✅ Fetched: O88842
# ✅ Fetched: Q9CZU4
# ✅ Fetched: Q64362
# ✅ Fetched: Q922Q9
# ✅ Fetched: Q99KK9
# ✅ Fetched: Q9DB16
# ✅ Fetched: Q66JV4
# ✅ Fetched: Q8VCL2
# ✅ Fetched: Q9D0D4
# ✅ Fetched: Q9JHJ3
# ✅ Fetched: Q921V5
# ✅ Fetched: A0A075B666
# ✅ Fetched: Q8CIV2
# ✅ Fetched: A0A087WPM2
# ✅ Fetched: Q16763
# ✅ Fetched: P70188
# ✅ Fetched: Q8BTJ4
# ✅ Fetched: Q8K114
# ✅ Fetched: O43156
# ✅ Fetched: Q80YQ8
# ✅ Fetched: P52875
# ✅ Fetched: Q9D7Z3
# ✅ Fetched: Q80U38
# ✅ Fetched: Q8R2K1
# ✅ Fetched: Q8BHK9
# ✅ Fetched: B1AVZ0
# ✅ Fetched: P62324
# ✅ Fetched: Q09PK2
# ✅ Fetched: P47802
# ✅ Fetched: Q8BIW1
# ✅ Fetched: Q921C5
# ✅ Fetched: Q91WS7
# ✅ Fetched: Q9DBZ1
# ✅ Fetched: Q9CQA5
# ✅ Fetched: Q8VDM1
# ✅ Fetched: Q9D1K7
# ✅ Fetched: Q9JM14
# ✅ Fetched: Q9Z100
# ✅ Fetched: P04202
# ✅ Fetched: Q9QYS9
# ✅ Fetched: Q8BFT2
# ✅ Fetched: Q91YD9
# ✅ Fetched: Q8K2A7
# ✅ Fetched: Q15427
# ✅ Fetched: Q91VZ6
# ✅ Fetched: P41240
# ✅ Fetched: Q9CR21
# ✅ Fetched: Q9Z1Z0
# ✅ Fetched: Q05816
# ✅ Fetched: Q8VBX6
# ✅ Fetched: Q9WU79
# ✅ Fetched: P35288
# ✅ Fetched: Q8CEC6
# ✅ Fetched: A6NHN6
# ✅ Fetched: Q9CT10
# ✅ Fetched: O00178
# ✅ Fetched: Q8CI08
# ✅ Fetched: Q8CA72
# ✅ Fetched: B2RT14
# ✅ Fetched: Q504N7
# ✅ Fetched: Q62084
# ✅ Fetched: Q3UM18
# ✅ Fetched: Q5I1X5
# ✅ Fetched: Q8BTZ4
# ✅ Fetched: P11047
# ✅ Fetched: Q9D9K3
# ✅ Fetched: Q969P6
# ✅ Fetched: P97499
# ✅ Fetched: Q8JZK9
# ✅ Fetched: Q9CWN7
# ✅ Fetched: Q8QZR4
# ✅ Fetched: P52623
# ✅ Fetched: Q9WTX2
# ✅ Fetched: Q9CQT5
# ✅ Fetched: P43883
# ✅ Fetched: Q80Y44
# ✅ Fetched: Q9H6F5
# ✅ Fetched: Q3UD01
# ✅ Fetched: Q6QI06
# ✅ Fetched: Q9JJ89
# ✅ Fetched: P70295
# ✅ Fetched: Q9D7N6
# ✅ Fetched: D3Z2R5
# ✅ Fetched: Q61510
# ✅ Fetched: Q8K3W0
# ✅ Fetched: O54950
# ✅ Fetched: Q8BYU6
# ✅ Fetched: P97770
# ✅ Fetched: Q91WG2
# ✅ Fetched: P47930
# ✅ Fetched: Q62388
# ✅ Fetched: Q3TLI0
# ✅ Fetched: P49356
# ✅ Fetched: Q13546
# ✅ Fetched: Q9QYE6
# ✅ Fetched: O89079
# ✅ Fetched: Q9Z0R4
# ✅ Fetched: Q8C1E7
# ✅ Fetched: Q3UFB2
# ✅ Fetched: Q9NWK9
# ✅ Fetched: Q9Z2E1
# ✅ Fetched: O70251
# ✅ Fetched: Q8CHI8
# ✅ Fetched: Q9CQL5
# ✅ Fetched: P63208
# ✅ Fetched: Q8R2E9
# ✅ Fetched: P40818
# ✅ Fetched: Q08857
# ✅ Fetched: Q99KP3
# ✅ Fetched: Q8CF89
# ✅ Fetched: Q9WU40
# ✅ Fetched: P08508
# ✅ Fetched: Q91XX1
# ✅ Fetched: O00762
# ✅ Fetched: Q62000
# ✅ Fetched: O95573
# ✅ Fetched: Q8BQ30
# ✅ Fetched: P49840
# ✅ Fetched: Q9JK23
# ✅ Fetched: Q8CCH2
# ✅ Fetched: Q0P5X1
# ✅ Fetched: Q8VCB1
# ✅ Fetched: Q8BTY8
# ✅ Fetched: P62482
# ✅ Fetched: Q03347
# ✅ Fetched: Q8BYZ7
# ✅ Fetched: Q9D8S3
# ✅ Fetched: Q5NCE8
# ✅ Fetched: P01910
# ✅ Fetched: O88907
# ✅ Fetched: Q8K2Q9
# ✅ Fetched: O88665
# ✅ Fetched: Q7TQK5
# ✅ Fetched: Q9QUM0
# ✅ Fetched: Q8K1E6
# ✅ Fetched: Q8BVI5
# ✅ Fetched: Q8N1P7
# ✅ Fetched: Q8K3C3
# ✅ Fetched: Q3B7Z2
# ✅ Fetched: P62072
# ✅ Fetched: Q60930
# ✅ Fetched: P45880
# ✅ Fetched: Q9Y276
# ✅ Fetched: Q8K2C7
# ✅ Fetched: P49915
# ✅ Fetched: Q5S006
# ✅ Fetched: P04441
# ✅ Fetched: P97477
# ✅ Fetched: P97814
# ✅ Fetched: O35678
# ✅ Fetched: Q8BP27
# ✅ Fetched: Q9QZI8
# ✅ Fetched: P46782
# ✅ Fetched: O75460
# ✅ Fetched: Q99KI3
# ✅ Fetched: P17433
# ✅ Fetched: Q9D385
# ✅ Fetched: Q922S4
# ✅ Fetched: Q8R366
# ✅ Fetched: Q9WVF7
# ✅ Fetched: P28347
# ✅ Fetched: O95989
# ✅ Fetched: Q5Y5T1
# ✅ Fetched: Q99N16
# ✅ Fetched: Q8BG81
# ✅ Fetched: P50452
# ✅ Fetched: Q8BGS2
# ✅ Fetched: Q61846
# ✅ Fetched: Q9DB96
# ✅ Fetched: Q53FT3
# ✅ Fetched: P02689
# ✅ Fetched: Q8R3H7
# ✅ Fetched: Q3UDP0
# ✅ Fetched: Q61464
# ✅ Fetched: Q9D009
# ✅ Fetched: Q9NU22
# ✅ Fetched: Q9CQI3
# ✅ Fetched: Q2TBE6
# ✅ Fetched: P01111
# ✅ Fetched: Q99L85
# ✅ Fetched: Q9Y2D5
# ✅ Fetched: Q9JI19
# ✅ Fetched: O55033
# ✅ Fetched: P14115
# ✅ Fetched: Q02388
# ✅ Fetched: Q8WWM9
# ✅ Fetched: Q68CQ4
# ✅ Fetched: Q3UZZ4
# ✅ Fetched: Q7TN29
# ✅ Fetched: Q921N7
# ✅ Fetched: Q9DB27
# ✅ Fetched: Q9CZ83
# ✅ Fetched: Q9JJA7
# ✅ Fetched: A2ACQ1
# ✅ Fetched: Q2YDW2
# ✅ Fetched: Q9D9I4
# ✅ Fetched: P35237
# ✅ Fetched: Q810V0
# ✅ Fetched: Q99598
# ✅ Fetched: Q791T5
# ✅ Fetched: Q9CXF7
# ✅ Fetched: Q96HQ2
# ✅ Fetched: Q6T4R5
# ✅ Fetched: Q8TDP1
# ✅ Fetched: O88630
# ✅ Fetched: Q8BV49
# ✅ Fetched: G3UZV2
# ✅ Fetched: P56528
# ✅ Fetched: Q9CZH3
# ✅ Fetched: Q9D773
# ✅ Fetched: Q9EQX4
# ✅ Fetched: Q96BN2
# ✅ Fetched: O35900
# ✅ Fetched: P21460
# ✅ Fetched: O75208
# ✅ Fetched: Q15007
# ✅ Fetched: P62875
# ✅ Fetched: Q923D4
# ✅ Fetched: O88351
# ✅ Fetched: Q3URQ4
# ✅ Fetched: Q8BJ37
# ✅ Fetched: P15121
# ✅ Fetched: P51912
# ✅ Fetched: Q9JJX7
# ✅ Fetched: Q6NSQ5
# ✅ Fetched: Q13206
# ✅ Fetched: O94915
# ✅ Fetched: Q9D2Y4
# ✅ Fetched: Q91WK5
# ✅ Fetched: P25098
# ✅ Fetched: Q99J93
# ✅ Fetched: Q9R062
# ✅ Fetched: Q8K0C1
# ✅ Fetched: Q80YQ2
# ✅ Fetched: Q6P3E7
# ✅ Fetched: A0A338P7C9
# ✅ Fetched: F6PZL4
# ✅ Fetched: O70139
# ✅ Fetched: P41105
# ✅ Fetched: Q3TFQ1
# ✅ Fetched: F8VQ05
# ✅ Fetched: P78318
# ✅ Fetched: Q9CQ26
# ✅ Fetched: Q9JM13
# ✅ Fetched: P83876
# ✅ Fetched: P17439
# ✅ Fetched: Q05D32
# ✅ Fetched: Q9BVS4
# ✅ Fetched: Q8BHS3
# ✅ Fetched: Q92618
# ✅ Fetched: Q9CQZ1
# ✅ Fetched: Q8R4Y4
# ✅ Fetched: Q8CHG7
# ✅ Fetched: P06702
# ✅ Fetched: Q9CR20
# ✅ Fetched: P15531
# ✅ Fetched: Q8VCA8
# ✅ Fetched: Q8CHS8
# ✅ Fetched: Q5T1M5
# ✅ Fetched: Q9EQ08
# ✅ Fetched: Q9Z1N2
# ✅ Fetched: Q8VED5
# ✅ Fetched: P23475
# ✅ Fetched: Q8NCM8
# ✅ Fetched: Q91Z69
# ✅ Fetched: P46414
# ✅ Fetched: Q9D8U8
# ✅ Fetched: Q3UND0
# ✅ Fetched: P57105
# ✅ Fetched: Q3TBW2
# ✅ Fetched: Q7TMC8
# ✅ Fetched: Q8VBZ3
# ✅ Fetched: Q8BHN0
# ✅ Fetched: Q8R570
# ✅ Fetched: O70422
# ✅ Fetched: Q8K2Y7
# ✅ Fetched: P70347
# ✅ Fetched: P19221
# ✅ Fetched: O15347
# ✅ Fetched: Q6PCM2
# ✅ Fetched: Q99LI8
# ✅ Fetched: Q5NCF2
# ✅ Fetched: O88974
# ✅ Fetched: Q8BL97
# ✅ Fetched: Q01081
# ✅ Fetched: Q04837
# ✅ Fetched: Q9CYR0
# ✅ Fetched: Q9DAM7
# ✅ Fetched: Q8CI70
# ✅ Fetched: Q64462
# ✅ Fetched: P05412
# ✅ Fetched: Q8BND3
# ✅ Fetched: Q9CWY3
# ✅ Fetched: Q9JJA2
# ✅ Fetched: Q3UH60
# ✅ Fetched: P63313
# ✅ Fetched: Q5EBL4
# ✅ Fetched: P11032
# ✅ Fetched: Q9D7P6
# ✅ Fetched: Q9WV84
# ✅ Fetched: Q99LL5
# ✅ Fetched: Q8K057
# ✅ Fetched: Q9Z2A9
# ✅ Fetched: Q9CQ06
# ✅ Fetched: Q6PAC3
# ✅ Fetched: Q8BHC7
# ✅ Fetched: O35972
# ✅ Fetched: Q8BP40
# ✅ Fetched: P11688
# ✅ Fetched: Q64449
# ✅ Fetched: Q9CQC7
# ✅ Fetched: P35174
# ✅ Fetched: O88413
# ✅ Fetched: Q96FS4
# ✅ Fetched: P07141
# ✅ Fetched: Q6NVF4
# ✅ Fetched: A2RUB1
# ✅ Fetched: A6NF83
# ✅ Fetched: Q8BW75
# ✅ Fetched: Q9Z2E2
# ✅ Fetched: P07091
# ✅ Fetched: Q3V300
# ✅ Fetched: Q8WZB0
# ✅ Fetched: Q9UPN6
# ✅ Fetched: E9Q6J6
# ✅ Fetched: Q8K183
# ✅ Fetched: Q6PD21
# ✅ Fetched: Q6R327
# ✅ Fetched: Q9CQY5
# ✅ Fetched: O35954
# ✅ Fetched: Q99K28
# ✅ Fetched: O96028
# ✅ Fetched: P51175
# ✅ Fetched: P23242
# ✅ Fetched: P17302
# ✅ Fetched: P97450
# ✅ Fetched: Q6P9J9
# ✅ Fetched: Q91WG4
# ✅ Fetched: Q8C079
# ✅ Fetched: Q6PAV2
# ✅ Fetched: O15234
# ✅ Fetched: Q9CQJ6
# ✅ Fetched: Q60716
# ✅ Fetched: Q3LR78
# ✅ Fetched: P35762
# ✅ Fetched: Q3TLS3
# ✅ Fetched: Q3TWF6
# ✅ Fetched: O14531
# ✅ Fetched: O88939
# ✅ Fetched: Q2VPQ9
# ✅ Fetched: Q9CWU6
# ✅ Fetched: Q9CR26
# ✅ Fetched: Q91VS7
# ✅ Fetched: Q8BWB6
# ✅ Fetched: Q8BKZ9
# ✅ Fetched: Q3TN34
# ✅ Fetched: Q9CQJ8
# ✅ Fetched: O75937
# ✅ Fetched: Q9DB25
# ✅ Fetched: Q02384
# ✅ Fetched: P11609
# ✅ Fetched: P15586
# ✅ Fetched: P50637
# ✅ Fetched: Q9D1C8
# ✅ Fetched: A2A6Q5
# ✅ Fetched: Q2VIS4
# ✅ Fetched: Q8WUH2
# ✅ Fetched: P59235
# ✅ Fetched: P15535
# ✅ Fetched: Q9BTT4
# ✅ Fetched: Q9D4F8
# ✅ Fetched: Q91VC4
# ✅ Fetched: Q9DCF9
# ✅ Fetched: Q9Z2X8
# ✅ Fetched: Q9HAU0
# ✅ Fetched: Q8VBT9
# ✅ Fetched: Q8BH43
# ✅ Fetched: Q9D142
# ✅ Fetched: Q9JHS9
# ✅ Fetched: Q9BXD5
# ✅ Fetched: Q8WVC6
# ✅ Fetched: Q8QZR5
# ✅ Fetched: P53798
# ✅ Fetched: O94808
# ✅ Fetched: Q9CZ28
# ✅ Fetched: Q3U7U3
# ✅ Fetched: P70429
# ✅ Fetched: P11169
# ✅ Fetched: O55242
# ✅ Fetched: P58404
# ✅ Fetched: E9Q6B2
# ✅ Fetched: Q60876
# ✅ Fetched: Q9D2Z4
# ✅ Fetched: Q9UMX1
# ✅ Fetched: Q64459
# ✅ Fetched: O94898
# ✅ Fetched: A2AIL4
# ✅ Fetched: Q9WU62
# ✅ Fetched: Q8C569
# ✅ Fetched: F8VQB6
# ✅ Fetched: Q8BX17
# ✅ Fetched: P09813
# ✅ Fetched: Q5XJY4
# ✅ Fetched: Q8C7D2
# ✅ Fetched: Q8VCD5
# ✅ Fetched: Q6ZQK0
# ✅ Fetched: Q5SNT6
# ✅ Fetched: Q9WTQ5
# ✅ Fetched: P18572
# ✅ Fetched: Q78IK4
# ✅ Fetched: P26151
# ✅ Fetched: P98182
# ✅ Fetched: Q62371
# ✅ Fetched: Q8BGV0
# ✅ Fetched: Q9DC63
# ✅ Fetched: Q3UI43
# ✅ Fetched: Q640M1
# ✅ Fetched: Q80WQ6
# ✅ Fetched: P97390
# ✅ Fetched: Q91V09
# ✅ Fetched: Q6PB70
# ✅ Fetched: Q9WVC3
# ✅ Fetched: O08804
# ✅ Fetched: Q9D1B9
# ✅ Fetched: Q80WG5
# ✅ Fetched: O75223
# ✅ Fetched: Q9WVJ9
# ✅ Fetched: Q91YE3
# ✅ Fetched: Q9D8X0
# ✅ Fetched: Q6P8I4
# ✅ Fetched: Q9JHE7
# ✅ Fetched: P15954
# ✅ Fetched: O15116
# ✅ Fetched: Q922Y2
# ✅ Fetched: Q8QZS1
# ✅ Fetched: P61599
# ✅ Fetched: Q4V339
# ✅ Fetched: Q8BZ20
# ✅ Fetched: Q9CQA6
# ✅ Fetched: O89112
# ✅ Fetched: Q8BGU5
# ✅ Fetched: Q9Z2A5
# ✅ Fetched: Q8BUH8
# ✅ Fetched: Q9Z2C5
# ✅ Fetched: Q923L6
# ✅ Fetched: P11672
# ✅ Fetched: Q925J9
# ✅ Fetched: Q9D1F4
# ✅ Fetched: Q9D2E2
# ✅ Fetched: Q60648
# ✅ Fetched: Q3U4L8
# ✅ Fetched: Q9WU84
# ✅ Fetched: P31152
# ✅ Fetched: Q99N57
# ✅ Fetched: Q8K1T1
# ✅ Fetched: Q99LE1
# ✅ Fetched: Q922P8
# ✅ Fetched: Q9D0K0
# ✅ Fetched: Q80V24
# ✅ Fetched: Q8JZP9
# ✅ Fetched: Q7TPE5
# ✅ Fetched: Q8BUE4
# ✅ Fetched: Q8R0F3
# ✅ Fetched: P59242
# ✅ Fetched: Q9Z2A0
# ✅ Fetched: Q6ZQA6
# ✅ Fetched: A2AJI0
# ✅ Fetched: Q05020
# ✅ Fetched: O35387
# ✅ Fetched: Q8CDG3
# ✅ Fetched: Q99LJ7
# ✅ Fetched: Q6PGF7
# ✅ Fetched: Q5SRX1
# ✅ Fetched: A6X919
# ✅ Fetched: Q9CQ13
# ✅ Fetched: P16254
# ✅ Fetched: Q0HA38
# ✅ Fetched: Q8BK75
# ✅ Fetched: Q8R0F8
# ✅ Fetched: O35711
# ✅ Fetched: Q9D0J8
# ✅ Fetched: Q9DC33
# ✅ Fetched: Q9QZ23
# ✅ Fetched: Q92831
# ✅ Fetched: Q9WTK3
# ✅ Fetched: P52655
# ✅ Fetched: P06240
# ✅ Fetched: P99025
# ✅ Fetched: Q9UBX5
# ✅ Fetched: Q3UP87
# ✅ Fetched: B1AQJ2
# ✅ Fetched: Q9QYF9
# ✅ Fetched: Q5D862
# ✅ Fetched: O09164
# ✅ Fetched: Q91ZW2
# ✅ Fetched: Q9CQM5
# ✅ Fetched: Q3TP92
# ✅ Fetched: Q61362
# ✅ Fetched: A2A7S8
# ✅ Fetched: O08600
# ✅ Fetched: Q78PG9
# ✅ Fetched: Q9WV34
# ✅ Fetched: O08811
# ✅ Fetched: Q8K2G4
# ✅ Fetched: Q9NSE4
# ✅ Fetched: O43505
# ✅ Fetched: P97304
# ✅ Fetched: Q6NZL6
# ✅ Fetched: P60330
# ✅ Fetched: Q3TAP4
# ✅ Fetched: Q6IAA8
# ✅ Fetched: Q9EP72
# ✅ Fetched: Q8BYB9
# ✅ Fetched: P05204
# ✅ Fetched: O70325
# ✅ Fetched: Q8CBY3
# ✅ Fetched: Q64695
# ✅ Fetched: Q8CG72
# ✅ Fetched: Q61592
# ✅ Fetched: E9Q735
# ✅ Fetched: Q924D0
# ✅ Fetched: Q9R0L7
# ✅ Fetched: Q7Z6K5
# ✅ Fetched: O35083
# ✅ Fetched: P24390
# ✅ Fetched: Q8TBQ9
# ✅ Fetched: Q8K1N4
# ✅ Fetched: Q9JJG9
# ✅ Fetched: Q91WC1
# ✅ Fetched: Q8K2R5
# ✅ Fetched: Q9JKC8
# ✅ Fetched: Q8C156
# ✅ Fetched: Q5QJE6
# ✅ Fetched: Q792Z1
# ✅ Fetched: Q9WUP4
# ✅ Fetched: Q08122
# ✅ Fetched: Q9ULJ7
# ✅ Fetched: Q8VEG4
# ✅ Fetched: Q9JKP7
# ✅ Fetched: Q9UM07
# ✅ Fetched: Q8VE80
# ✅ Fetched: Q8C142
# ✅ Fetched: Q69ZI1
# ✅ Fetched: Q96HR3
# ✅ Fetched: Q60949
# ✅ Fetched: Q08775
# ✅ Fetched: Q9CRW3
# ✅ Fetched: Q8R1K4
# ✅ Fetched: O95376
# ✅ Fetched: Q9JI44
# ✅ Fetched: Q9CQ40
# ✅ Fetched: P59759
# ✅ Fetched: O70279
# ✅ Fetched: O60831
# ✅ Fetched: Q9JKN1
# ✅ Fetched: Q99496
# ✅ Fetched: O75356
# ✅ Fetched: Q9ES97
# ✅ Fetched: O89050
# ✅ Fetched: Q9CQL7
# ✅ Fetched: Q922E6
# ✅ Fetched: Q9NYU1
# ✅ Fetched: Q9D1G2
# ✅ Fetched: Q9JLB0
# ✅ Fetched: P43346
# ✅ Fetched: Q9D1N9
# ✅ Fetched: Q6ZPR6
# ✅ Fetched: Q8C6E0
# ✅ Fetched: Q9H6L2
# ✅ Fetched: A2AKG8
# ✅ Fetched: Q9ESD6
# ✅ Fetched: Q8CHY6
# ✅ Fetched: P81069
# ✅ Fetched: Q8BVW0
# ✅ Fetched: Q3UJP5
# ✅ Fetched: Q78IS1
# ✅ Fetched: Q3UJ81
# ✅ Fetched: Q6ZPZ3
# ✅ Fetched: P58059
# ✅ Fetched: Q99PL7
# ✅ Fetched: P33622
# ✅ Fetched: Q8K021
# ✅ Fetched: P30355
# ✅ Fetched: Q8VDQ9
# ✅ Fetched: Q9D8N2
# ✅ Fetched: Q8VCH5
# ✅ Fetched: Q9CQ54
# ✅ Fetched: Q922H9
# ✅ Fetched: Q14AX6
# ✅ Fetched: Q8CHK3
# ✅ Fetched: Q9BZG1
# ✅ Fetched: P30837
# ✅ Fetched: P08069
# ✅ Fetched: Q9D7J9
# ✅ Fetched: P05156
# ✅ Fetched: O88968
# ✅ Fetched: P31428
# ✅ Fetched: Q923L7
# ✅ Fetched: Q64471
# ✅ Fetched: Q80U28
# ✅ Fetched: Q9QYC7
# ✅ Fetched: Q6SKR2
# ✅ Fetched: O15258
# ✅ Fetched: P20664
# ✅ Fetched: Q91V98
# ✅ Fetched: Q9D786
# ✅ Fetched: Q7TSZ8
# ✅ Fetched: Q9CS74
# ✅ Fetched: Q9WUH1
# ✅ Fetched: Q9DCV4
# ✅ Fetched: O08688
# ✅ Fetched: Q9D2P4
# ✅ Fetched: P32507
# ✅ Fetched: Q92665
# ✅ Fetched: Q8K2C9
# ✅ Fetched: P70340
# ✅ Fetched: Q8BUN5
# ✅ Fetched: Q9D7H3
# ✅ Fetched: Q8K1L5
# ✅ Fetched: Q5U462
# ✅ Fetched: F2Z461
# ✅ Fetched: Q9EQC1
# ✅ Fetched: Q8R5A3
# ✅ Fetched: Q6ZPY2
# ✅ Fetched: P10810
# ✅ Fetched: Q99P65
# ✅ Fetched: Q8BLK9
# ✅ Fetched: F8VPP8
# ✅ Fetched: Q4PJX1
# ✅ Fetched: Q9R112
# ✅ Fetched: O08734
# ✅ Fetched: Q810J8
# ✅ Fetched: Q9DCT6
# ✅ Fetched: P10922
# ✅ Fetched: Q76KJ5
# ✅ Fetched: Q9CQN6
# ✅ Fetched: Q8BJU9
# ✅ Fetched: Q9CWS4
# ✅ Fetched: O75995
# ✅ Fetched: Q08481
# ✅ Fetched: Q9D6L8
# ✅ Fetched: Q14527
# ✅ Fetched: P20918
# ✅ Fetched: Q9DB29
# ✅ Fetched: Q8VCX5
# ✅ Fetched: Q9D7E3
# ✅ Fetched: Q921W4
# ✅ Fetched: P50427
# ✅ Fetched: Q8K305
# ✅ Fetched: P58058
# ✅ Fetched: Q3TMV7
# ✅ Fetched: A3KMP2
# ✅ Fetched: Q5JWR5
# ✅ Fetched: Q9JJ66
# ✅ Fetched: Q80T85
# ✅ Fetched: Q9QZD8
# ✅ Fetched: P62838
# ✅ Fetched: P97480
# ✅ Fetched: P70387
# ✅ Fetched: P18052
# ✅ Fetched: Q9CXD9
# ✅ Fetched: Q9CQL4
# ✅ Fetched: P09925
# ✅ Fetched: Q99J47
# ✅ Fetched: O88895
# ✅ Fetched: Q99JW5
# ✅ Fetched: P26006
# ✅ Fetched: Q9QYC0
# ✅ Fetched: Q8CE96
# ✅ Fetched: P61961
# ✅ Fetched: Q7TPS5
# ✅ Fetched: Q78XF5
# ✅ Fetched: Q80YW0
# ✅ Fetched: Q8C2B3
# ✅ Fetched: E9Q2I4
# ✅ Fetched: Q6NXN1
# ✅ Fetched: Q9JLY7
# ✅ Fetched: Q921C3
# ✅ Fetched: Q91VN4
# ✅ Fetched: Q9QWF0
# ✅ Fetched: Q06180
# ✅ Fetched: D3YXK1
# ✅ Fetched: P62075
# ✅ Fetched: Q8CI15
# ✅ Fetched: O70494
# ✅ Fetched: O14907
# ✅ Fetched: Q64430
# ✅ Fetched: Q8JZV7
# ✅ Fetched: Q8R2Q8
# ✅ Fetched: Q9EQ32
# ✅ Fetched: A0AAA9WW07
# ✅ Fetched: Q91VT4
# ✅ Fetched: Q86TM3
# ✅ Fetched: Q9CQT2
# ✅ Fetched: Q8BHG9
# ✅ Fetched: Q64516
# ✅ Fetched: A2A8L5
# ✅ Fetched: Q69Z61
# ✅ Fetched: Q921Q7
# ✅ Fetched: Q9CY52
# ✅ Fetched: Q80XU3
# ✅ Fetched: O75317
# ✅ Fetched: Q5SVR0
# ✅ Fetched: Q9D787
# ✅ Fetched: Q80X32
# ✅ Fetched: Q6S5J6
# ✅ Fetched: P23611
# ✅ Fetched: Q8R2Q4
# ✅ Fetched: Q811J3
# ✅ Fetched: Q9R0M4
# ✅ Fetched: Q8BIA4
# ✅ Fetched: Q9D2R8
# ✅ Fetched: Q8BXL7
# ✅ Fetched: P38432
# ✅ Fetched: P29972
# ✅ Fetched: Q3TXU5
# ✅ Fetched: Q9P212
# ✅ Fetched: Q91WC9
# ✅ Fetched: Q8BMK1
# ✅ Fetched: Q9D958
# ✅ Fetched: P09234
# ✅ Fetched: Q6NXY1
# ✅ Fetched: Q64302
# ✅ Fetched: O95400
# ✅ Fetched: Q99LW0
# ✅ Fetched: O35166
# ✅ Fetched: Q8CGC4
# ✅ Fetched: Q8K2F8
# ✅ Fetched: P60840
# ✅ Fetched: P61009
# ✅ Fetched: Q08297
# ✅ Fetched: O35566
# ✅ Fetched: Q6NZR2
# ✅ Fetched: Q9CQF8
# ✅ Fetched: Q91VT1
# ✅ Fetched: Q8VC28
# ✅ Fetched: Q60969
# ✅ Fetched: Q9EPA7
# ✅ Fetched: O95166
# ✅ Fetched: O14925
# ✅ Fetched: Q9R020
# ✅ Fetched: Q3UN02
# ✅ Fetched: Q9CQK7
# ✅ Fetched: Q60769
# ✅ Fetched: Q14CH1
# ✅ Fetched: Q8K4F6
# ✅ Fetched: Q78WZ7
# ✅ Fetched: Q61093
# ✅ Fetched: Q9UNP4
# ✅ Fetched: P33215
# ✅ Fetched: Q6NWV3
# ✅ Fetched: P22605
# ✅ Fetched: Q80UK8
# ✅ Fetched: Q8CI33
# ✅ Fetched: P53701
# ✅ Fetched: Q60596
# ✅ Fetched: O88874
# ✅ Fetched: Q99J56
# ✅ Fetched: P12388
#
# 🎉 Digestion complete. Peptides saved to: metaboscape_peptides.csv

# %%
import pandas as pd
import re
import requests
import pyopenms as oms
import csv
import math

# ----------- Step 1: Read LC-MS/MS CSV and Clean Headers -----------
input_csv = "1.csv"
df = pd.read_csv(input_csv, sep="\t")
df.columns = df.columns.str.strip()

print("Detected columns:", df.columns.tolist())

# ----------- Step 2: Detect the Protein Group Column -----------
protein_col = None
for col in df.columns:
    if "protein" in col.lower() and "group" in col.lower():
        protein_col = col
        break

if not protein_col:
    raise KeyError(" Could not find a 'Protein Group Name'-like column in your file.")
print(f" Using column: {protein_col} to extract UniProt IDs")

# ----------- Step 3: Extract UniProt IDs -----------
def extract_uniprot_id(entry):
    match = re.search(r"\|([A-Z0-9]+)\|", str(entry))
    return match.group(1) if match else None

df['UniProt_ID'] = df[protein_col].apply(extract_uniprot_id)
unique_ids = df['UniProt_ID'].dropna().unique()

# ----------- Step 4: Fetch FASTA Sequences from UniProt -----------
fasta_file = "master_proteins.fasta"
base_url = "https://rest.uniprot.org/uniprotkb/{}.fasta"

with open(fasta_file, "w") as fasta_out:
    for uid in unique_ids:
        response = requests.get(base_url.format(uid))
        if response.status_code == 200:
            fasta_out.write(response.text)
            print(f" Fetched: {uid}")
        else:
            print(f" Failed to fetch {uid} (status {response.status_code})")

# ----------- Step 5: Parse FASTA File -----------
def parse_fasta(file_path):
    proteins = []
    with open(file_path, "r") as f:
        lines = f.readlines()
        name, seq = "", ""
        for line in lines:
            line = line.strip()
            if line.startswith(">"):
                if name and seq:
                    proteins.append((name, seq))
                name = line[1:]
                seq = ""
            else:
                seq += line
        if name and seq:
            proteins.append((name, seq))
    return proteins

proteins = parse_fasta(fasta_file)

# ----------- Step 6: Setup Digestion Parameters -----------
digestion = oms.ProteaseDigestion()
digestion.setEnzyme("Trypsin")
digestion.setMissedCleavages(1)
min_len = 6
max_len = 40

modifications = oms.ModifiedPeptideGenerator.getModifications([b"Oxidation (M)"])

# ----------- Step 7: Digest and Buffer All Output Rows -----------
all_rows = []

for protein_name, protein_seq in proteins:
    try:
        aa_seq = oms.AASequence.fromString(protein_seq)
    except Exception as e:
        print(f" Error parsing {protein_name}: {e}")
        continue

    peptides = []
    digestion.digest(aa_seq, peptides, min_len, max_len)

    modified_peptides = []
    for p in peptides:
        oms.ModifiedPeptideGenerator.applyVariableModifications(modifications, p, 1, modified_peptides, False)

    all_peptides = set([p.toString() for p in peptides] + [p.toString() for p in modified_peptides])
    all_peptides = [pep for pep in all_peptides if "X" not in pep]

    for pep_str in all_peptides:
        try:
            seq_obj = oms.AASequence.fromString(pep_str)
            formula = seq_obj.getFormula().toString()
            mass = seq_obj.getMonoWeight()
        except Exception as e:
            formula = f"Error: {e}"
            mass = ""

        name = f"{protein_name}@{pep_str}"
        row = ["", formula, name, mass, "", "", "", "", "", "", "", "", "", "", "", ""]
        all_rows.append(row)

# ----------- Step 8: Write into Chunks of 10,000 for MetaboScape -----------
chunk_size = 50000
total_parts = math.ceil(len(all_rows) / chunk_size)
output_prefix = "metaboscape_peptides_part"

print(f" Writing {len(all_rows)} peptides into {total_parts} MetaboScape-compatible files...")

for i in range(total_parts):
    chunk = all_rows[i * chunk_size:(i + 1) * chunk_size]
    filename = f"{output_prefix}{i + 1}.csv"
    with open(filename, "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow([
            "RT", "Formula", "Name", "Mass", "CCS [M+H]+", "CCS [M+Na]+", "CCS [M-H]-",
            "KEGG", "CAS", "PubChem", "ChemSpider", "HMDB", "BioCyc",
            "Metlin", "LipidMaps", "UserID", "InChI"
        ])
        writer.writerows(chunk)
    print(f" {filename} saved with {len(chunk)} rows")

print("\n Digestion complete. All peptide chunks saved.")
# Out:
# Detected columns: ['MS2 Id,Peptide Sequence,XCorr Score,Precursor MZ,PPM Error,Rt,Corrected Ook0,Protein Group Name,Charge,Delta CN Score,Confidence Score,Calculated MH,Matched Ions,Predicted Ook0,TIMScore,Is Unique']
# ✅ Using column: MS2 Id,Peptide Sequence,XCorr Score,Precursor MZ,PPM Error,Rt,Corrected Ook0,Protein Group Name,Charge,Delta CN Score,Confidence Score,Calculated MH,Matched Ions,Predicted Ook0,TIMScore,Is Unique to extract UniProt IDs
# ✅ Fetched: Q80WW9
# ✅ Fetched: Q3TW96
# ✅ Fetched: O35226
# ✅ Fetched: P0C7N9
# ✅ Fetched: Q3UJB9
# ✅ Fetched: Q3UWL8
# ✅ Fetched: Q6NV83
# ✅ Fetched: Q9R1T4
# ✅ Fetched: P97807
# ✅ Fetched: P26039
# ✅ Fetched: P08882
# ✅ Fetched: Q62009
# ✅ Fetched: O70423
# ✅ Fetched: Q5NCR9
# ✅ Fetched: G5E8K5
# ✅ Fetched: Q61140
# ✅ Fetched: Q8VH51
# ✅ Fetched: Q9CRB9
# ✅ Fetched: Q9D8N0
# ✅ Fetched: Q13608
# ✅ Fetched: Q9JJY4
# ✅ Fetched: Q9JIF7
# ✅ Fetched: Q8C1B7
# ✅ Fetched: Q7TSG2
# ✅ Fetched: Q9EPU4
# ✅ Fetched: E9Q1P8
# ✅ Fetched: P28667
# ✅ Fetched: Q7M753
# ✅ Fetched: Q9CR00
# ✅ Fetched: Q8VDJ3
# ✅ Fetched: O08759
# ✅ Fetched: P21107
# ✅ Fetched: Q9ERK4
# ✅ Fetched: Q60931
# ✅ Fetched: Q91Z40
# ✅ Fetched: Q61107
# ✅ Fetched: Q8BTS3
# ✅ Fetched: A0A0G2JDV3
# ✅ Fetched: Q000W5
# ✅ Fetched: Q9JLI6
# ✅ Fetched: Q9Z2G6
# ✅ Fetched: Q3UMT1
# ✅ Fetched: P62960
# ✅ Fetched: F6ZDS4
# ✅ Fetched: P52480
# ✅ Fetched: Q3UFK8
# ✅ Fetched: P14873
# ✅ Fetched: O70133
# ✅ Fetched: Q08211
# ✅ Fetched: Q62383
# ✅ Fetched: P28660
# ✅ Fetched: P28867
# ✅ Fetched: Q80TV8
# ✅ Fetched: Q9QZV9
# ✅ Fetched: Q9ESV0
# ✅ Fetched: Q80VD1
# ✅ Fetched: Q9JMH9
# ✅ Fetched: Q92614
# ✅ Fetched: O70591
# ✅ Fetched: F8VPK0
# ✅ Fetched: Q91WT4
# ✅ Fetched: P67778
# ✅ Fetched: P30416
# ✅ Fetched: P27546
# ✅ Fetched: O55029
# ✅ Fetched: Q9CXI0
# ✅ Fetched: Q8R1F5
# ✅ Fetched: P61163
# ✅ Fetched: Q8R5C5
# ✅ Fetched: Q9Z0H8
# ✅ Fetched: Q6PB93
# ✅ Fetched: Q8CFQ3
# ✅ Fetched: B2RQC6
# ✅ Fetched: P62258
# ✅ Fetched: A6H584
# ✅ Fetched: Q9D0F3
# ✅ Fetched: Q8BTI8
# ✅ Fetched: Q9UQ35
# ✅ Fetched: Q8K2B3
# ✅ Fetched: Q9JIH2
# ✅ Fetched: Q62470
# ✅ Fetched: Q8R3N1
# ✅ Fetched: Q9ET54
# ✅ Fetched: Q9D8X2
# ✅ Fetched: Q64674
# ✅ Fetched: Q8BK67
# ✅ Fetched: P25799
# ✅ Fetched: P16330
# ✅ Fetched: Q810B6
# ✅ Fetched: Q99MN1
# ✅ Fetched: P97351
# ✅ Fetched: Q9JL35
# ✅ Fetched: P57746
# ✅ Fetched: P48678
# ✅ Fetched: P54822
# ✅ Fetched: Q61249
# ✅ Fetched: Q9QYR6
# ✅ Fetched: Q9D0K2
# ✅ Fetched: P47955
# ✅ Fetched: Q9WTM5
# ✅ Fetched: Q9CQ43
# ✅ Fetched: Q64324
# ✅ Fetched: P50580
# ✅ Fetched: P80314
# ✅ Fetched: O08599
# ✅ Fetched: Q9CR57
# ✅ Fetched: Q2TAY7
# ✅ Fetched: P56959
# ✅ Fetched: Q8CIG8
# ✅ Fetched: Q9JIK5
# ✅ Fetched: Q8R3P6
# ✅ Fetched: O08553
# ✅ Fetched: Q9QXS1
# ✅ Fetched: O75533
# ✅ Fetched: Q8BVI4
# ✅ Fetched: Q9CZN7
# ✅ Fetched: Q9Z0H4
# ✅ Fetched: P28659
# ✅ Fetched: Q64345
# ✅ Fetched: Q08509
# ✅ Fetched: Q9DBR1
# ✅ Fetched: P19001
# ✅ Fetched: Q8CIG9
# ✅ Fetched: Q6P4T2
# ✅ Fetched: O75643
# ✅ Fetched: Q61179
# ✅ Fetched: O08784
# ✅ Fetched: Q8K182
# ✅ Fetched: P41227
# ✅ Fetched: B9EJR8
# ✅ Fetched: Q6ZPJ3
# ✅ Fetched: E9PVA8
# ✅ Fetched: Q6P9Q4
# ✅ Fetched: P03975
# ✅ Fetched: Q9QY93
# ✅ Fetched: P62851
# ✅ Fetched: Q6PB66
# ✅ Fetched: Q91ZX7
# ✅ Fetched: Q07954
# ✅ Fetched: Q922F4
# ✅ Fetched: Q9BUF5
# ✅ Fetched: Q9DBG3
# ✅ Fetched: O35643
# ✅ Fetched: P19096
# ✅ Fetched: Q8K3G9
# ✅ Fetched: Q6P542
# ✅ Fetched: Q4VAA2
# ✅ Fetched: Q8BWT1
# ✅ Fetched: Q64727
# ✅ Fetched: Q9D0M3
# ✅ Fetched: Q9JKR6
# ✅ Fetched: Q99KH8
# ✅ Fetched: P34056
# ✅ Fetched: O35969
# ✅ Fetched: Q9JIX8
# ✅ Fetched: Q80U93
# ✅ Fetched: Q921S7
# ✅ Fetched: Q922H2
# ✅ Fetched: Q5SSI6
# ✅ Fetched: Q9D1B1
# ✅ Fetched: P47199
# ✅ Fetched: P05064
# ✅ Fetched: Q921G7
# ✅ Fetched: O08528
# ✅ Fetched: P19367
# ✅ Fetched: P17710
# ✅ Fetched: Q3TRM8
# ✅ Fetched: Q99P31
# ✅ Fetched: Q6PAM1
# ✅ Fetched: Q6PB44
# ✅ Fetched: P53986
# ✅ Fetched: Q9JKP5
# ✅ Fetched: Q8BYA0
# ✅ Fetched: Q9QZQ8
# ✅ Fetched: Q80X85
# ✅ Fetched: P31323
# ✅ Fetched: Q9CQ60
# ✅ Fetched: Q9DC50
# ✅ Fetched: Q9EPL2
# ✅ Fetched: P97429
# ✅ Fetched: Q8VCW8
# ✅ Fetched: O70305
# ✅ Fetched: A4UUI3
# ✅ Fetched: Q8K382
# ✅ Fetched: Q6ZPF4
# ✅ Fetched: P51949
# ✅ Fetched: P97820
# ✅ Fetched: P70202
# ✅ Fetched: P97927
# ✅ Fetched: Q9Z1Z2
# ✅ Fetched: P81117
# ✅ Fetched: Q8C4B4
# ✅ Fetched: Q61687
# ✅ Fetched: Q3ULD5
# ✅ Fetched: P12367
# ✅ Fetched: Q9D6T0
# ✅ Fetched: Q9DCC4
# ✅ Fetched: Q0VBL3
# ✅ Fetched: Q01405
# ✅ Fetched: P82198
# ✅ Fetched: Q02053
# ✅ Fetched: Q9WV70
# ✅ Fetched: Q99LC5
# ✅ Fetched: Q9D2G2
# ✅ Fetched: P63038
# ✅ Fetched: P10809
# ✅ Fetched: Q91YR7
# ✅ Fetched: P70168
# ✅ Fetched: Q3TXS7
# ✅ Fetched: P01027
# ✅ Fetched: O08583
# ✅ Fetched: Q8R1U1
# ✅ Fetched: Q6P9B9
# ✅ Fetched: Q61702
# ✅ Fetched: Q9Z1Q9
# ✅ Fetched: P17182
# ✅ Fetched: P21550
# ✅ Fetched: P13929
# ✅ Fetched: P17183
# ✅ Fetched: P09411
# ✅ Fetched: P00558
# ✅ Fetched: P49769
# ✅ Fetched: Q3UPH7
# ✅ Fetched: Q6PE01
# ✅ Fetched: P16332
# ✅ Fetched: O88325
# ✅ Fetched: P47791
# ✅ Fetched: Q99PW4
# ✅ Fetched: Q9ULV0
# ✅ Fetched: P97386
# ✅ Fetched: P70697
# ✅ Fetched: P01942
# ✅ Fetched: Q9CQW1
# ✅ Fetched: P51881
# ✅ Fetched: P48962
# ✅ Fetched: P12236
# ✅ Fetched: Q924W5
# ✅ Fetched: Q60770
# ✅ Fetched: Q6PDQ2
# ✅ Fetched: P10107
# ✅ Fetched: Q9D0I9
# ✅ Fetched: O70310
# ✅ Fetched: P62873
# ✅ Fetched: Q9Z2D8
# ✅ Fetched: Q9EQH3
# ✅ Fetched: Q3TZZ7
# ✅ Fetched: A0FGR8
# ✅ Fetched: P62879
# ✅ Fetched: Q99KC8
# ✅ Fetched: G5E895
# ✅ Fetched: P56380
# ✅ Fetched: Q62465
# ✅ Fetched: E9Q4Y4
# ✅ Fetched: P98083
# ✅ Fetched: Q8CG76
# ✅ Fetched: Q80X90
# ✅ Fetched: P35998
# ✅ Fetched: Q7TPR4
# ✅ Fetched: P12814
# ✅ Fetched: P57780
# ✅ Fetched: P13439
# ✅ Fetched: P25322
# ✅ Fetched: Q80TM9
# ✅ Fetched: Q91XB0
# ✅ Fetched: Q8CI51
# ✅ Fetched: Q8VDN2
# ✅ Fetched: P50993
# ✅ Fetched: Q9Z183
# ✅ Fetched: Q9D071
# ✅ Fetched: P48036
# ✅ Fetched: Q9CPX6
# ✅ Fetched: P63024
# ✅ Fetched: P63027
# ✅ Fetched: Q8VE99
# ✅ Fetched: E9QAT4
# ✅ Fetched: Q8BK64
# ✅ Fetched: O95433
# ✅ Fetched: Q8BFR5
# ✅ Fetched: A6X935
# ✅ Fetched: P20491
# ✅ Fetched: P28033
# ✅ Fetched: A2AKX3
# ✅ Fetched: P04075
# ✅ Fetched: P39061
# ✅ Fetched: Q2VLH6
# ✅ Fetched: Q9Z315
# ✅ Fetched: Q3UDE2
# ✅ Fetched: Q68FD5
# ✅ Fetched: Q921I2
# ✅ Fetched: Q8K363
# ✅ Fetched: Q63829
# ✅ Fetched: P53811
# ✅ Fetched: P61970
# ✅ Fetched: Q8R5F7
# ✅ Fetched: Q9Z0P4
# ✅ Fetched: Q05920
# ✅ Fetched: Q8VDD5
# ✅ Fetched: P35579
# ✅ Fetched: Q61879
# ✅ Fetched: O35465
# ✅ Fetched: Q9D1H9
# ✅ Fetched: Q9ERU9
# ✅ Fetched: Q6PDH0
# ✅ Fetched: Q9CW46
# ✅ Fetched: Q8BKG3
# ✅ Fetched: O08749
# ✅ Fetched: Q3V009
# ✅ Fetched: P62241
# ✅ Fetched: P62333
# ✅ Fetched: P11499
# ✅ Fetched: P08865
# ✅ Fetched: Q8K2Q7
# ✅ Fetched: O75369
# ✅ Fetched: Q6ZWX6
# ✅ Fetched: Q6ZQ73
# ✅ Fetched: P61221
# ✅ Fetched: Q3TRM4
# ✅ Fetched: Q8VE22
# ✅ Fetched: Q5SSZ5
# ✅ Fetched: P10649
# ✅ Fetched: A0A087WS16
# ✅ Fetched: P12111
# ✅ Fetched: Q60847
# ✅ Fetched: Q99715
# ✅ Fetched: Q6P9R2
# ✅ Fetched: P56480
# ✅ Fetched: P68036
# ✅ Fetched: E9Q616
# ✅ Fetched: Q09666
# ✅ Fetched: P13645
# ✅ Fetched: Q5XG71
# ✅ Fetched: O75691
# ✅ Fetched: P62897
# ✅ Fetched: P07901
# ✅ Fetched: P07900
# ✅ Fetched: Q9D8Y0
# ✅ Fetched: Q62230
# ✅ Fetched: Q8C3I8
# ✅ Fetched: Q9JJ28
# ✅ Fetched: Q99LC8
# ✅ Fetched: Q6P5E4
# ✅ Fetched: Q06335
# ✅ Fetched: Q9D0R2
# ✅ Fetched: Q9CPY7
# ✅ Fetched: Q8BH64
# ✅ Fetched: Q8BMS1
# ✅ Fetched: Q9NYU2
# ✅ Fetched: Q9D0F9
# ✅ Fetched: Q64514
# ✅ Fetched: Q6PDG5
# ✅ Fetched: D0QMC3
# ✅ Fetched: Q9CQ36
# ✅ Fetched: Q9Z1F9
# ✅ Fetched: Q78ZA7
# ✅ Fetched: Q96KP1
# ✅ Fetched: Q9Z1X4
# ✅ Fetched: Q9DB05
# ✅ Fetched: Q91YJ5
# ✅ Fetched: O89053
# ✅ Fetched: Q9HAV0
# ✅ Fetched: Q9WVK4
# ✅ Fetched: Q9QXY6
# ✅ Fetched: Q9NZN3
# ✅ Fetched: Q16594
# ✅ Fetched: Q9EQP2
# ✅ Fetched: P63321
# ✅ Fetched: P62263
# ✅ Fetched: O55137
# ✅ Fetched: Q9Z331
# ✅ Fetched: P35240
# ✅ Fetched: Q9CWY8
# ✅ Fetched: P84089
# ✅ Fetched: Q9JL15
# ✅ Fetched: O00214
# ✅ Fetched: Q6ZQ38
# ✅ Fetched: Q9WUA2
# ✅ Fetched: Q08943
# ✅ Fetched: Q61211
# ✅ Fetched: Q9Z0E6
# ✅ Fetched: P50516
# ✅ Fetched: Q8VEE4
# ✅ Fetched: Q8BND5
# ✅ Fetched: O08529
# ✅ Fetched: Q8K4G1
# ✅ Fetched: O54941
# ✅ Fetched: P04264
# ✅ Fetched: P11679
# ✅ Fetched: Q8JZY2
# ✅ Fetched: P46783
# ✅ Fetched: P97765
# ✅ Fetched: Q9CXL3
# ✅ Fetched: Q6PGL7
# ✅ Fetched: Q62311
# ✅ Fetched: Q8R3F5
# ✅ Fetched: Q8R151
# ✅ Fetched: Q8BZR9
# ✅ Fetched: Q8CJF7
# ✅ Fetched: Q9CU65
# ✅ Fetched: Q9DB34
# ✅ Fetched: Q8JZQ9
# ✅ Fetched: E9Q6R7
# ✅ Fetched: Q6R891
# ✅ Fetched: Q8VDM6
# ✅ Fetched: Q9BUJ2
# ✅ Fetched: Q61233
# ✅ Fetched: P13796
# ✅ Fetched: Q6GQT9
# ✅ Fetched: Q0GNC1
# ✅ Fetched: Q61147
# ✅ Fetched: P08107
# ✅ Fetched: Q60710
# ✅ Fetched: P07356
# ✅ Fetched: P07355
# ✅ Fetched: Q69ZN7
# ✅ Fetched: Q9NZM1
# ✅ Fetched: P17918
# ✅ Fetched: P12004
# ✅ Fetched: Q9D7E4
# ✅ Fetched: P97300
# ✅ Fetched: Q99K30
# ✅ Fetched: Q61699
# ✅ Fetched: P09055
# ✅ Fetched: O15031
# ✅ Fetched: P37889
# ✅ Fetched: Q60715
# ✅ Fetched: Q62418
# ✅ Fetched: Q9CPQ3
# ✅ Fetched: E9Q7L1
# ✅ Fetched: Q6PIP5
# ✅ Fetched: Q9CXW4
# ✅ Fetched: P25976
# ✅ Fetched: Q8BGQ1
# ✅ Fetched: Q91WC0
# ✅ Fetched: Q921H8
# ✅ Fetched: Q8BP92
# ✅ Fetched: Q569Z6
# ✅ Fetched: Q61033
# ✅ Fetched: E9PZM7
# ✅ Fetched: Q9JIW9
# ✅ Fetched: Q99PT1
# ✅ Fetched: P41317
# ✅ Fetched: Q8VCT3
# ✅ Fetched: Q6P0Q8
# ✅ Fetched: O15021
# ✅ Fetched: P59017
# ✅ Fetched: Q91XV3
# ✅ Fetched: Q6IRU2
# ✅ Fetched: Q61646
# ✅ Fetched: P28658
# ✅ Fetched: Q8VE97
# ✅ Fetched: Q9EPX2
# ✅ Fetched: A2AJ72
# ✅ Fetched: P04186
# ✅ Fetched: P14618
# ✅ Fetched: Q8VBT6
# ✅ Fetched: Q86WX3
# ✅ Fetched: Q9D906
# ✅ Fetched: Q9DBE9
# ✅ Fetched: Q60676
# ✅ Fetched: P53041
# ✅ Fetched: P14733
# ✅ Fetched: Q8BJS4
# ✅ Fetched: Q9R0N0
# ✅ Fetched: Q8VHX6
# ✅ Fetched: Q3V3R1
# ✅ Fetched: Q8BH97
# ✅ Fetched: P49717
# ✅ Fetched: Q9CWJ9
# ✅ Fetched: Q8BKT7
# ✅ Fetched: P42567
# ✅ Fetched: P20226
# ✅ Fetched: Q924T7
# ✅ Fetched: Q8VDM4
# ✅ Fetched: Q8VIJ6
# ✅ Fetched: Q15149
# ✅ Fetched: Q924Z6
# ✅ Fetched: Q91YP2
# ✅ Fetched: Q9BYT8
# ✅ Fetched: P58044
# ✅ Fetched: Q9QXG4
# ✅ Fetched: Q9CW03
# ✅ Fetched: Q6P5H2
# ✅ Fetched: Q9D853
# ✅ Fetched: D4AFX7
# ✅ Fetched: Q68FL6
# ✅ Fetched: Q9Z0H1
# ✅ Fetched: P02469
# ✅ Fetched: Q99J85
# ✅ Fetched: Q05793
# ✅ Fetched: P62908
# ✅ Fetched: Q91YI0
# ✅ Fetched: Q9R0E2
# ✅ Fetched: O00231
# ✅ Fetched: Q9D3E6
# ✅ Fetched: Q60520
# ✅ Fetched: P54729
# ✅ Fetched: Q61335
# ✅ Fetched: P59998
# ✅ Fetched: P18653
# ✅ Fetched: P18654
# ✅ Fetched: Q8VHI3
# ✅ Fetched: Q8R409
# ✅ Fetched: E9PV24
# ✅ Fetched: Q99PL5
# ✅ Fetched: Q7TPV4
# ✅ Fetched: P61158
# ✅ Fetched: Q91YX5
# ✅ Fetched: Q9D1P4
# ✅ Fetched: P63244
# ✅ Fetched: Q9JLZ8
# ✅ Fetched: Q6IA17
# ✅ Fetched: Q64726
# ✅ Fetched: D3YZP9
# ✅ Fetched: O00160
# ✅ Fetched: E9Q634
# ✅ Fetched: P70248
# ✅ Fetched: Q3UMY5
# ✅ Fetched: Q60597
# ✅ Fetched: Q99JB2
# ✅ Fetched: P39447
# ✅ Fetched: Q61292
# ✅ Fetched: Q9R1C7
# ✅ Fetched: Q9JHR7
# ✅ Fetched: P02468
# ✅ Fetched: P08032
# ✅ Fetched: Q14683
# ✅ Fetched: O08788
# ✅ Fetched: Q14203
# ✅ Fetched: Q3UQN2
# ✅ Fetched: Q99L43
# ✅ Fetched: P07724
# ✅ Fetched: Q80YX1
# ✅ Fetched: Q8R2U0
# ✅ Fetched: Q00547
# ✅ Fetched: Q80Y17
# ✅ Fetched: Q8VE88
# ✅ Fetched: Q9DBK7
# ✅ Fetched: P60670
# ✅ Fetched: P16879
# ✅ Fetched: Q9Y2X7
# ✅ Fetched: Q9JHU4
# ✅ Fetched: Q9D1H7
# ✅ Fetched: Q91W18
# ✅ Fetched: Q6DFW4
# ✅ Fetched: Q8VEK3
# ✅ Fetched: Q15393
# ✅ Fetched: P09622
# ✅ Fetched: Q8VDP4
# ✅ Fetched: Q9UHD8
# ✅ Fetched: P26231
# ✅ Fetched: P08030
# ✅ Fetched: Q5U430
# ✅ Fetched: Q8K2M0
# ✅ Fetched: Q8BKX6
# ✅ Fetched: Q14012
# ✅ Fetched: Q8BW96
# ✅ Fetched: Q9DCL9
# ✅ Fetched: Q9DCD2
# ✅ Fetched: Q99JI4
# ✅ Fetched: Q8JZR0
# ✅ Fetched: Q8BHF7
# ✅ Fetched: Q6PDY2
# ✅ Fetched: P80316
# ✅ Fetched: P48643
# ✅ Fetched: P80315
# ✅ Fetched: Q61733
# ✅ Fetched: P61803
# ✅ Fetched: Q921F2
# ✅ Fetched: P45952
# ✅ Fetched: Q64737
# ✅ Fetched: P22102
# ✅ Fetched: Q9BXJ9
# ✅ Fetched: Q91VM9
# ✅ Fetched: Q8VBV7
# ✅ Fetched: O88322
# ✅ Fetched: Q8BIJ6
# ✅ Fetched: Q61838
# ✅ Fetched: O95373
# ✅ Fetched: P41245
# ✅ Fetched: Q91WQ3
# ✅ Fetched: Q9ERI6
# ✅ Fetched: Q99MN9
# ✅ Fetched: Q8R1I1
# ✅ Fetched: P40142
# ✅ Fetched: P29401
# ✅ Fetched: Q91V92
# ✅ Fetched: Q8BX90
# ✅ Fetched: Q9CZ30
# ✅ Fetched: Q9EPJ9
# ✅ Fetched: P55072
# ✅ Fetched: Q91WM3
# ✅ Fetched: Q61503
# ✅ Fetched: O70435
# ✅ Fetched: O70252
# ✅ Fetched: Q6PD26
# ✅ Fetched: Q11011
# ✅ Fetched: Q6Q899
# ✅ Fetched: Q62083
# ✅ Fetched: O88712
# ✅ Fetched: Q7TQI3
# ✅ Fetched: Q99J99
# ✅ Fetched: P04184
# ✅ Fetched: P98078
# ✅ Fetched: P84103
# ✅ Fetched: Q5SUR0
# ✅ Fetched: P11983
# ✅ Fetched: Q9D1J1
# ✅ Fetched: Q8BML9
# ✅ Fetched: P51863
# ✅ Fetched: O08810
# ✅ Fetched: Q9D0E1
# ✅ Fetched: Q8BUV3
# ✅ Fetched: P14869
# ✅ Fetched: Q8BWM0
# ✅ Fetched: Q61210
# ✅ Fetched: Q9DBH0
# ✅ Fetched: P32261
# ✅ Fetched: Q99K70
# ✅ Fetched: Q9CY97
# ✅ Fetched: P49207
# ✅ Fetched: Q91ZV0
# ✅ Fetched: O35206
# ✅ Fetched: P61026
# ✅ Fetched: Q9EQ20
# ✅ Fetched: Q6P5D3
# ✅ Fetched: Q8BXQ2
# ✅ Fetched: Q3UW53
# ✅ Fetched: P17047
# ✅ Fetched: P59708
# ✅ Fetched: Q9NZT1
# ✅ Fetched: Q8BNU0
# ✅ Fetched: Q61316
# ✅ Fetched: Q04323
# ✅ Fetched: Q9R0P3
# ✅ Fetched: O35239
# ✅ Fetched: Q8CB77
# ✅ Fetched: Q8BHG1
# ✅ Fetched: Q9JJ78
# ✅ Fetched: P31939
# ✅ Fetched: P35505
# ✅ Fetched: P25444
# ✅ Fetched: O70503
# ✅ Fetched: Q9CYR6
# ✅ Fetched: Q6PAJ1
# ✅ Fetched: P51174
# ✅ Fetched: A2ADY9
# ✅ Fetched: Q8BH60
# ✅ Fetched: O35658
# ✅ Fetched: Q60854
# ✅ Fetched: Q8CIH5
# ✅ Fetched: P68373
# ✅ Fetched: P05213
# ✅ Fetched: P68369
# ✅ Fetched: P68366
# ✅ Fetched: A2AT37
# ✅ Fetched: Q4LDD4
# ✅ Fetched: Q6P1B1
# ✅ Fetched: Q8R2R3
# ✅ Fetched: P97372
# ✅ Fetched: P29758
# ✅ Fetched: Q3U5Q7
# ✅ Fetched: Q8CIE4
# ✅ Fetched: Q9WTK5
# ✅ Fetched: Q91VN6
# ✅ Fetched: P10518
# ✅ Fetched: Q6Y7W8
# ✅ Fetched: Q3U0V2
# ✅ Fetched: Q9CXS4
# ✅ Fetched: P08249
# ✅ Fetched: P16858
# ✅ Fetched: S4R1W1
# ✅ Fetched: P23780
# ✅ Fetched: P58871
# ✅ Fetched: Q6PHZ2
# ✅ Fetched: O08808
# ✅ Fetched: Q9WVG6
# ✅ Fetched: O15514
# ✅ Fetched: P51859
# ✅ Fetched: O08539
# ✅ Fetched: E9PVZ8
# ✅ Fetched: Q8K2I4
# ✅ Fetched: P70297
# ✅ Fetched: Q8C6B2
# ✅ Fetched: Q61703
# ✅ Fetched: P62269
# ✅ Fetched: Q99J08
# ✅ Fetched: Q6PDI5
# ✅ Fetched: E9Q7G0
# ✅ Fetched: Q15233
# ✅ Fetched: P60709
# ✅ Fetched: P68032
# ✅ Fetched: Q6S8J3
# ✅ Fetched: P0CG38
# ✅ Fetched: P0CG39
# ✅ Fetched: A5A3E0
# ✅ Fetched: Q99JW2
# ✅ Fetched: Q93009
# ✅ Fetched: Q9CQF9
# ✅ Fetched: Q9CY21
# ✅ Fetched: P29351
# ✅ Fetched: Q8BRT1
# ✅ Fetched: Q924C1
# ✅ Fetched: Q8K1R7
# ✅ Fetched: Q9D1C9
# ✅ Fetched: Q61635
# ✅ Fetched: O09061
# ✅ Fetched: A2AJL3
# ✅ Fetched: Q920A5
# ✅ Fetched: P51397
# ✅ Fetched: Q9QX47
# ✅ Fetched: Q04857
# ✅ Fetched: P42768
# ✅ Fetched: P98195
# ✅ Fetched: Q61458
# ✅ Fetched: Q61414
# ✅ Fetched: Q99JX3
# ✅ Fetched: Q9R1X4
# ✅ Fetched: Q91YR5
# ✅ Fetched: Q8K2V6
# ✅ Fetched: Q99KK7
# ✅ Fetched: P52825
# ✅ Fetched: P59016
# ✅ Fetched: Q5U458
# ✅ Fetched: Q3U487
# ✅ Fetched: C0HKE1
# ✅ Fetched: P20671
# ✅ Fetched: Q93077
# ✅ Fetched: Q6FI13
# ✅ Fetched: P0C0S8
# ✅ Fetched: Q64522
# ✅ Fetched: Q8IUE6
# ✅ Fetched: P16104
# ✅ Fetched: P0C0S5
# ✅ Fetched: Q96QV6
# ✅ Fetched: Q9JHF5
# ✅ Fetched: E9Q3L2
# ✅ Fetched: Q61235
# ✅ Fetched: Q8R502
# ✅ Fetched: Q91VE0
# ✅ Fetched: P27659
# ✅ Fetched: Q91ZU6
# ✅ Fetched: O54988
# ✅ Fetched: Q9JI11
# ✅ Fetched: Q5F2E8
# ✅ Fetched: Q9H2K8
# ✅ Fetched: Q8BYC6
# ✅ Fetched: P35268
# ✅ Fetched: O55098
# ✅ Fetched: P35821
# ✅ Fetched: Q61508
# ✅ Fetched: O60506
# ✅ Fetched: O43390
# ✅ Fetched: P05480
# ✅ Fetched: Q61001
# ✅ Fetched: P47968
# ✅ Fetched: Q08093
# ✅ Fetched: Q9JLQ2
# ✅ Fetched: Q9EQC5
# ✅ Fetched: Q9Z0R6
# ✅ Fetched: Q9NZM3
# ✅ Fetched: Q8BI84
# ✅ Fetched: Q01514
# ✅ Fetched: Q8BH59
# ✅ Fetched: Q9QYB1
# ✅ Fetched: Q9QXZ0
# ✅ Fetched: P83436
# ✅ Fetched: E9Q6J5
# ✅ Fetched: Q58A65
# ✅ Fetched: P11088
# ✅ Fetched: Q9JL26
# ✅ Fetched: Q9JHW2
# ✅ Fetched: Q9Z277
# ✅ Fetched: Q61753
# ✅ Fetched: P35441
# ✅ Fetched: Q924Z4
# ✅ Fetched: O35350
# ✅ Fetched: Q6P4S8
# ✅ Fetched: Q91V61
# ✅ Fetched: Q8BGW1
# ✅ Fetched: P12815
# ✅ Fetched: P12970
# ✅ Fetched: O00487
# ✅ Fetched: Q61749
# ✅ Fetched: Q8BP48
# ✅ Fetched: Q8CAY6
# ✅ Fetched: Q9D662
# ✅ Fetched: Q15437
# ✅ Fetched: Q80TE0
# ✅ Fetched: Q8BX02
# ✅ Fetched: Q9WVR4
# ✅ Fetched: P47962
# ✅ Fetched: O08915
# ✅ Fetched: Q923B6
# ✅ Fetched: Q8BHN3
# ✅ Fetched: Q4VA53
# ✅ Fetched: O88342
# ✅ Fetched: P42932
# ✅ Fetched: Q8BTM8
# ✅ Fetched: Q99JX7
# ✅ Fetched: P35585
# ✅ Fetched: Q8VBZ0
# ✅ Fetched: P02463
# ✅ Fetched: P46664
# ✅ Fetched: P46939
# ✅ Fetched: P06795
# ✅ Fetched: P62266
# ✅ Fetched: Q8CI95
# ✅ Fetched: Q5SUA5
# ✅ Fetched: Q9DAR7
# ✅ Fetched: P62253
# ✅ Fetched: P97384
# ✅ Fetched: Q7TMR0
# ✅ Fetched: P08122
# ✅ Fetched: P11352
# ✅ Fetched: Q9CQ75
# ✅ Fetched: P62308
# ✅ Fetched: Q3TDN2
# ✅ Fetched: Q9CQR6
# ✅ Fetched: P63330
# ✅ Fetched: P62714
# ✅ Fetched: Q8CAQ8
# ✅ Fetched: O09044
# ✅ Fetched: P63087
# ✅ Fetched: P62140
# ✅ Fetched: P97930
# ✅ Fetched: P62717
# ✅ Fetched: Q91W50
# ✅ Fetched: P61201
# ✅ Fetched: Q9Y6Y8
# ✅ Fetched: Q6P5D8
# ✅ Fetched: O08736
# ✅ Fetched: P01897
# ✅ Fetched: P06339
# ✅ Fetched: P14427
# ✅ Fetched: P14430
# ✅ Fetched: O19441
# ✅ Fetched: Q8K0E8
# ✅ Fetched: Q9CYD3
# ✅ Fetched: P14152
# ✅ Fetched: Q8VC03
# ✅ Fetched: Q9Z1D1
# ✅ Fetched: Q6PNC0
# ✅ Fetched: P56389
# ✅ Fetched: B2RRE7
# ✅ Fetched: P47857
# ✅ Fetched: P08237
# ✅ Fetched: P28063
# ✅ Fetched: Q9D7N3
# ✅ Fetched: Q8BFQ8
# ✅ Fetched: Q99L47
# ✅ Fetched: Q8CFD4
# ✅ Fetched: O14672
# ✅ Fetched: Q5SXY1
# ✅ Fetched: O08692
# ✅ Fetched: D3YXK2
# ✅ Fetched: Q3TKT4
# ✅ Fetched: P16949
# ✅ Fetched: P54227
# ✅ Fetched: Q05CL8
# ✅ Fetched: Q4G0J3
# ✅ Fetched: Q9D0C4
# ✅ Fetched: Q80UM3
# ✅ Fetched: F8VQC1
# ✅ Fetched: Q8BJU0
# ✅ Fetched: Q3UJU9
# ✅ Fetched: O15294
# ✅ Fetched: Q3UM45
# ✅ Fetched: Q8CI32
# ✅ Fetched: P61966
# ✅ Fetched: P12270
# ✅ Fetched: Q8VDK1
# ✅ Fetched: Q8BSY0
# ✅ Fetched: Q9CQA9
# ✅ Fetched: P06801
# ✅ Fetched: Q6NS46
# ✅ Fetched: O54774
# ✅ Fetched: Q9ULV4
# ✅ Fetched: Q60973
# ✅ Fetched: P18242
# ✅ Fetched: Q61074
# ✅ Fetched: Q9R0I7
# ✅ Fetched: P49750
# ✅ Fetched: P52293
# ✅ Fetched: P28066
# ✅ Fetched: Q9Z1J3
# ✅ Fetched: Q8BKC5
# ✅ Fetched: Q9WUA3
# ✅ Fetched: P12382
# ✅ Fetched: B2RY04
# ✅ Fetched: P05202
# ✅ Fetched: P99026
# ✅ Fetched: P28070
# ✅ Fetched: Q8C4J7
# ✅ Fetched: Q99N87
# ✅ Fetched: Q2EMV9
# ✅ Fetched: E9PWG6
# ✅ Fetched: Q6NZJ6
# ✅ Fetched: P62081
# ✅ Fetched: Q3THK7
# ✅ Fetched: Q05D44
# ✅ Fetched: P41216
# ✅ Fetched: E9Q555
# ✅ Fetched: Q9NQH7
# ✅ Fetched: Q8C8U0
# ✅ Fetched: Q9WTX8
# ✅ Fetched: P24527
# ✅ Fetched: P09470
# ✅ Fetched: Q91VU7
# ✅ Fetched: Q9CRA8
# ✅ Fetched: Q9CZ42
# ✅ Fetched: P07437
# ✅ Fetched: Q13885
# ✅ Fetched: Q13509
# ✅ Fetched: O08917
# ✅ Fetched: Q99MU3
# ✅ Fetched: Q61584
# ✅ Fetched: Q91VX2
# ✅ Fetched: Q9QUM9
# ✅ Fetched: Q3U0V1
# ✅ Fetched: Q6P8X1
# ✅ Fetched: Q80X50
# ✅ Fetched: P27612
# ✅ Fetched: Q99LN9
# ✅ Fetched: Q9UID3
# ✅ Fetched: Q9ES52
# ✅ Fetched: O88544
# ✅ Fetched: Q61188
# ✅ Fetched: Q8VCM7
# ✅ Fetched: O35855
# ✅ Fetched: Q99PV0
# ✅ Fetched: Q921I1
# ✅ Fetched: Q8VCT4
# ✅ Fetched: Q62384
# ✅ Fetched: P41091
# ✅ Fetched: Q76MZ3
# ✅ Fetched: O88532
# ✅ Fetched: Q6NZN0
# ✅ Fetched: Q5SFM8
# ✅ Fetched: O75367
# ✅ Fetched: P70372
# ✅ Fetched: Q8BVF2
# ✅ Fetched: Q7Z739
# ✅ Fetched: P83731
# ✅ Fetched: Q8R081
# ✅ Fetched: Q61990
# ✅ Fetched: Q15366
# ✅ Fetched: P60335
# ✅ Fetched: Q62188
# ✅ Fetched: Q9Z2U0
# ✅ Fetched: O14818
# ✅ Fetched: Q9D819
# ✅ Fetched: Q9QXK3
# ✅ Fetched: Q8JZZ7
# ✅ Fetched: Q8VCN9
# ✅ Fetched: O15066
# ✅ Fetched: Q99MR6
# ✅ Fetched: Q9BXP5
# ✅ Fetched: A0A5F8MPH8
# ✅ Fetched: P09671
# ✅ Fetched: Q9D8W5
# ✅ Fetched: Q8K0D5
# ✅ Fetched: Q96RP9
# ✅ Fetched: Q60749
# ✅ Fetched: P26638
# ✅ Fetched: P20029
# ✅ Fetched: Q5SNZ0
# ✅ Fetched: P27635
# ✅ Fetched: P63001
# ✅ Fetched: Q9DAK9
# ✅ Fetched: P43277
# ✅ Fetched: P43274
# ✅ Fetched: Q07133
# ✅ Fetched: Q91XU0
# ✅ Fetched: P16401
# ✅ Fetched: Q91YN5
# ✅ Fetched: P08240
# ✅ Fetched: Q9DBG7
# ✅ Fetched: Q99LP6
# ✅ Fetched: Q8C1A5
# ✅ Fetched: P52888
# ✅ Fetched: A2BDX3
# ✅ Fetched: P61225
# ✅ Fetched: Q8K1X4
# ✅ Fetched: Q7TMY8
# ✅ Fetched: Q15382
# ✅ Fetched: A2RTL5
# ✅ Fetched: O55106
# ✅ Fetched: Q9ERG2
# ✅ Fetched: Q93092
# ✅ Fetched: Q64311
# ✅ Fetched: Q80YS6
# ✅ Fetched: Q3TLP5
# ✅ Fetched: Q8TER5
# ✅ Fetched: Q7TNG8
# ✅ Fetched: Q3TMP1
# ✅ Fetched: Q91W90
# ✅ Fetched: Q8BU31
# ✅ Fetched: Q3UHA3
# ✅ Fetched: Q9EQN3
# ✅ Fetched: Q91YH5
# ✅ Fetched: E9QAM5
# ✅ Fetched: E0CZ22
# ✅ Fetched: Q9BPX5
# ✅ Fetched: Q921I9
# ✅ Fetched: O70475
# ✅ Fetched: Q9CYG7
# ✅ Fetched: Q9EQK5
# ✅ Fetched: Q9QZE5
# ✅ Fetched: G3X9B1
# ✅ Fetched: O70481
# ✅ Fetched: Q60953
# ✅ Fetched: P0DPD9
# ✅ Fetched: P12265
# ✅ Fetched: P50247
# ✅ Fetched: Q922R8
# ✅ Fetched: Q15084
# ✅ Fetched: Q8BIG7
# ✅ Fetched: P63085
# ✅ Fetched: O88986
# ✅ Fetched: Q9CV28
# ✅ Fetched: P52431
# ✅ Fetched: G3X8U3
# ✅ Fetched: Q922P9
# ✅ Fetched: P29341
# ✅ Fetched: Q13310
# ✅ Fetched: Q9D4E6
# ✅ Fetched: Q6PHQ9
# ✅ Fetched: P70302
# ✅ Fetched: P23506
# ✅ Fetched: Q3TMH2
# ✅ Fetched: Q8K1H1
# ✅ Fetched: Q8R146
# ✅ Fetched: P68400
# ✅ Fetched: P35492
# ✅ Fetched: O88844
# ✅ Fetched: P62046
# ✅ Fetched: Q8BVU0
# ✅ Fetched: P02533
# ✅ Fetched: P19012
# ✅ Fetched: P13646
# ✅ Fetched: P08779
# ✅ Fetched: Q61781
# ✅ Fetched: Q04695
# ✅ Fetched: Q921G6
# ✅ Fetched: P02535
# ✅ Fetched: Q9QYI3
# ✅ Fetched: P70698
# ✅ Fetched: P70303
# ✅ Fetched: O08638
# ✅ Fetched: P35749
# ✅ Fetched: P43247
# ✅ Fetched: Q91Z92
# ✅ Fetched: P26041
# ✅ Fetched: P26043
# ✅ Fetched: Q9D6N5
# ✅ Fetched: O35286
# ✅ Fetched: P09405
# ✅ Fetched: P19338
# ✅ Fetched: P62495
# ✅ Fetched: P55194
# ✅ Fetched: Q99K51
# ✅ Fetched: Q8BGC0
# ✅ Fetched: P27773
# ✅ Fetched: Q9CX34
# ✅ Fetched: Q9JKF1
# ✅ Fetched: P60122
# ✅ Fetched: P28741
# ✅ Fetched: Q5JQF8
# ✅ Fetched: P01786
# ✅ Fetched: Q8K268
# ✅ Fetched: Q9CZU3
# ✅ Fetched: Q64010
# ✅ Fetched: Q64331
# ✅ Fetched: Q9CPY1
# ✅ Fetched: Q9JM52
# ✅ Fetched: O35127
# ✅ Fetched: Q80YP0
# ✅ Fetched: O54692
# ✅ Fetched: Q9CWD8
# ✅ Fetched: Q9DAW6
# ✅ Fetched: Q5VTL8
# ✅ Fetched: P54728
# ✅ Fetched: P54726
# ✅ Fetched: Q91WM2
# ✅ Fetched: P08074
# ✅ Fetched: P22437
# ✅ Fetched: Q9DBB9
# ✅ Fetched: Q5SUQ9
# ✅ Fetched: E9Q912
# ✅ Fetched: P36916
# ✅ Fetched: Q8VI94
# ✅ Fetched: P28352
# ✅ Fetched: P11440
# ✅ Fetched: P06493
# ✅ Fetched: Q8VDP3
# ✅ Fetched: Q3TFD2
# ✅ Fetched: Q9CQ18
# ✅ Fetched: Q8K297
# ✅ Fetched: Q9D8T7
# ✅ Fetched: Q922B2
# ✅ Fetched: P16675
# ✅ Fetched: Q811D0
# ✅ Fetched: Q15345
# ✅ Fetched: Q61205
# ✅ Fetched: O95372
# ✅ Fetched: Q8K411
# ✅ Fetched: Q8CBW3
# ✅ Fetched: Q9WV85
# ✅ Fetched: Q9CR62
# ✅ Fetched: P16546
# ✅ Fetched: P97823
# ✅ Fetched: Q99LD4
# ✅ Fetched: Q8BJ71
# ✅ Fetched: Q8K0Y7
# ✅ Fetched: P97819
# ✅ Fetched: Q3UIX4
# ✅ Fetched: P70670
# ✅ Fetched: O88448
# ✅ Fetched: P40124
# ✅ Fetched: Q8BVY0
# ✅ Fetched: Q9CYI4
# ✅ Fetched: Q6KCD5
# ✅ Fetched: P58252
# ✅ Fetched: Q9ER72
# ✅ Fetched: Q99KB8
# ✅ Fetched: Q8BHC9
# ✅ Fetched: Q8K298
# ✅ Fetched: P23249
# ✅ Fetched: Q8R180
# ✅ Fetched: P02452
# ✅ Fetched: P11087
# ✅ Fetched: P17427
# ✅ Fetched: P17426
# ✅ Fetched: Q9EQI8
# ✅ Fetched: Q920Q4
# ✅ Fetched: Q3ZK22
# ✅ Fetched: Q8CC12
# ✅ Fetched: Q00PI9
# ✅ Fetched: Q99MR3
# ✅ Fetched: P39054
# ✅ Fetched: P50570
# ✅ Fetched: Q8BMA6
# ✅ Fetched: Q99PU8
# ✅ Fetched: Q3UPL0
# ✅ Fetched: Q9JKX4
# ✅ Fetched: Q6DFZ1
# ✅ Fetched: Q8CG48
# ✅ Fetched: Q6NWW9
# ✅ Fetched: Q8C5H8
# ✅ Fetched: Q148V7
# ✅ Fetched: O95347
# ✅ Fetched: Q7TMB8
# ✅ Fetched: Q91YP3
# ✅ Fetched: P35123
# ✅ Fetched: Q9Y4A5
# ✅ Fetched: P99029
# ✅ Fetched: Q99LG4
# ✅ Fetched: P18669
# ✅ Fetched: Q8BRH0
# ✅ Fetched: Q5FWH2
# ✅ Fetched: Q3TEA8
# ✅ Fetched: Q99K01
# ✅ Fetched: Q9DBE0
# ✅ Fetched: Q8K4L0
# ✅ Fetched: Q9UBI9
# ✅ Fetched: Q9BRG1
# ✅ Fetched: Q64282
# ✅ Fetched: Q91W67
# ✅ Fetched: Q9QZF2
# ✅ Fetched: Q99KP6
# ✅ Fetched: Q8VDS4
# ✅ Fetched: Q9CSU0
# ✅ Fetched: Q7TT50
# ✅ Fetched: E9Q414
# ✅ Fetched: P08775
# ✅ Fetched: P80317
# ✅ Fetched: Q8BX10
# ✅ Fetched: Q9DCE9
# ✅ Fetched: Q8K1M6
# ✅ Fetched: Q8VCF0
# ✅ Fetched: Q8BUY9
# ✅ Fetched: P42125
# ✅ Fetched: P97471
# ✅ Fetched: Q9Z160
# ✅ Fetched: Q8VHR5
# ✅ Fetched: Q91VH2
# ✅ Fetched: Q8BJY1
# ✅ Fetched: Q60864
# ✅ Fetched: P30999
# ✅ Fetched: Q60963
# ✅ Fetched: P50431
# ✅ Fetched: P05063
# ✅ Fetched: P09972
# ✅ Fetched: O88536
# ✅ Fetched: Q91VD9
# ✅ Fetched: O88487
# ✅ Fetched: Q8K2H2
# ✅ Fetched: Q8BGZ4
# ✅ Fetched: Q6PFD9
# ✅ Fetched: Q9NRR5
# ✅ Fetched: Q8R317
# ✅ Fetched: Q99NB8
# ✅ Fetched: P27005
# ✅ Fetched: Q9WVH4
# ✅ Fetched: P57716
# ✅ Fetched: Q8BM55
# ✅ Fetched: Q6P5B0
# ✅ Fetched: Q9CWK8
# ✅ Fetched: Q9WV80
# ✅ Fetched: Q91VI7
# ✅ Fetched: Q9JLI8
# ✅ Fetched: Q9EQ06
# ✅ Fetched: Q8CH18
# ✅ Fetched: Q8IX12
# ✅ Fetched: Q3U7R1
# ✅ Fetched: Q8CHU3
# ✅ Fetched: Q91W69
# ✅ Fetched: P70398
# ✅ Fetched: Q93008
# ✅ Fetched: Q9DBZ5
# ✅ Fetched: Q8K124
# ✅ Fetched: Q8K0G5
# ✅ Fetched: O35682
# ✅ Fetched: Q99KE1
# ✅ Fetched: P68371
# ✅ Fetched: P43024
# ✅ Fetched: Q9JKP8
# ✅ Fetched: Q62261
# ✅ Fetched: Q9QXT0
# ✅ Fetched: Q9D6S7
# ✅ Fetched: Q9EPK7
# ✅ Fetched: P06684
# ✅ Fetched: P11103
# ✅ Fetched: Q9D6M3
# ✅ Fetched: Q8BFY9
# ✅ Fetched: Q99LG2
# ✅ Fetched: P06728
# ✅ Fetched: P70700
# ✅ Fetched: Q9DCS3
# ✅ Fetched: Q9R0L6
# ✅ Fetched: O89100
# ✅ Fetched: Q62419
# ✅ Fetched: Q99JB8
# ✅ Fetched: Q9WVE8
# ✅ Fetched: Q920E5
# ✅ Fetched: Q80U95
# ✅ Fetched: Q15386
# ✅ Fetched: Q14691
# ✅ Fetched: Q8CIN4
# ✅ Fetched: O88643
# ✅ Fetched: Q01730
# ✅ Fetched: P22907
# ✅ Fetched: Q5I2A0
# ✅ Fetched: P07759
# ✅ Fetched: Q05769
# ✅ Fetched: Q8VEM8
# ✅ Fetched: Q6PFY1
# ✅ Fetched: P97298
# ✅ Fetched: Q16531
# ✅ Fetched: Q60996
# ✅ Fetched: Q7TNL5
# ✅ Fetched: P54116
# ✅ Fetched: P49817
# ✅ Fetched: Q9QY24
# ✅ Fetched: P14901
# ✅ Fetched: P98160
# ✅ Fetched: Q5JTH9
# ✅ Fetched: Q9JK81
# ✅ Fetched: Q9UNS2
# ✅ Fetched: Q99JY0
# ✅ Fetched: Q8QZZ7
# ✅ Fetched: Q6ZQM8
# ✅ Fetched: Q3TIR3
# ✅ Fetched: P47964
# ✅ Fetched: P22892
# ✅ Fetched: O88685
# ✅ Fetched: Q922E4
# ✅ Fetched: Q8CI59
# ✅ Fetched: Q91UZ1
# ✅ Fetched: P10853
# ✅ Fetched: P10854
# ✅ Fetched: P23527
# ✅ Fetched: P57053
# ✅ Fetched: Q8CGP0
# ✅ Fetched: P08752
# ✅ Fetched: P59325
# ✅ Fetched: O55143
# ✅ Fetched: Q7TNC4
# ✅ Fetched: Q9Z2G9
# ✅ Fetched: P83940
# ✅ Fetched: Q9EPE9
# ✅ Fetched: P24547
# ✅ Fetched: O89086
# ✅ Fetched: Q9QXC1
# ✅ Fetched: Q9QY76
# ✅ Fetched: P26369
# ✅ Fetched: Q9D0B6
# ✅ Fetched: Q8C5W4
# ✅ Fetched: P70696
# ✅ Fetched: P70227
# ✅ Fetched: Q60866
# ✅ Fetched: P80318
# ✅ Fetched: B2RXS4
# ✅ Fetched: Q9WTP6
# ✅ Fetched: Q9D1M4
# ✅ Fetched: Q3UZ39
# ✅ Fetched: Q9Y608
# ✅ Fetched: Q9Z2I0
# ✅ Fetched: Q810A7
# ✅ Fetched: O88967
# ✅ Fetched: P22087
# ✅ Fetched: Q9CXF4
# ✅ Fetched: Q9JLJ2
# ✅ Fetched: Q3TIX9
# ✅ Fetched: Q80X73
# ✅ Fetched: Q3TRR0
# ✅ Fetched: Q61176
# ✅ Fetched: Q9EPU0
# ✅ Fetched: Q9D824
# ✅ Fetched: Q3UQ28
# ✅ Fetched: Q0VGY8
# ✅ Fetched: Q8BMJ2
# ✅ Fetched: P61254
# ✅ Fetched: Q8VHZ7
# ✅ Fetched: P23492
# ✅ Fetched: Q62189
# ✅ Fetched: P55258
# ✅ Fetched: Q8BHN5
# ✅ Fetched: Q8C129
# ✅ Fetched: Q9DBR3
# ✅ Fetched: Q8BIJ7
# ✅ Fetched: Q9NS87
# ✅ Fetched: Q9ESJ0
# ✅ Fetched: Q7TNG5
# ✅ Fetched: F7BJB9
# ✅ Fetched: Q9D0R4
# ✅ Fetched: Q3UYV9
# ✅ Fetched: P62996
# ✅ Fetched: Q13595
# ✅ Fetched: Q9CQV5
# ✅ Fetched: O75787
# ✅ Fetched: Q9CRA5
# ✅ Fetched: Q61191
# ✅ Fetched: A0A7N9VSG0
# ✅ Fetched: Q9R099
# ✅ Fetched: P28271
# ✅ Fetched: P52760
# ✅ Fetched: P63154
# ✅ Fetched: Q9CQN7
# ✅ Fetched: Q8BJM3
# ✅ Fetched: Q9DCN2
# ✅ Fetched: Q8R2Y8
# ✅ Fetched: Q91YQ5
# ✅ Fetched: P04843
# ✅ Fetched: P26040
# ✅ Fetched: Q9D1E6
# ✅ Fetched: Q91VR5
# ✅ Fetched: Q9CQG2
# ✅ Fetched: P23953
# ✅ Fetched: D3Z5G7
# ✅ Fetched: Q8R2Y2
# ✅ Fetched: Q63844
# ✅ Fetched: P97789
# ✅ Fetched: Q03147
# ✅ Fetched: Q9UQ88
# ✅ Fetched: P24788
# ✅ Fetched: Q8K2J0
# ✅ Fetched: Q3UHJ0
# ✅ Fetched: Q91ZR2
# ✅ Fetched: Q8WUU5
# ✅ Fetched: Q9WTU6
# ✅ Fetched: Q9UN86
# ✅ Fetched: P97379
# ✅ Fetched: Q58FF7
# ✅ Fetched: Q9WUQ2
# ✅ Fetched: Q920B9
# ✅ Fetched: Q69ZR2
# ✅ Fetched: Q91WD5
# ✅ Fetched: Q9WU56
# ✅ Fetched: P35980
# ✅ Fetched: Q9CXV9
# ✅ Fetched: Q3UTJ2
# ✅ Fetched: P97783
# ✅ Fetched: Q9DBE8
# ✅ Fetched: Q61656
# ✅ Fetched: Q92841
# ✅ Fetched: Q9D6R2
# ✅ Fetched: P11276
# ✅ Fetched: Q8BH86
# ✅ Fetched: Q64152
# ✅ Fetched: P97371
# ✅ Fetched: E9Q512
# ✅ Fetched: Q9DBT3
# ✅ Fetched: Q0GUM3
# ✅ Fetched: Q91V76
# ✅ Fetched: Q9JHU9
# ✅ Fetched: Q9JJA4
# ✅ Fetched: Q80UG5
# ✅ Fetched: Q61941
# ✅ Fetched: Q8VEB4
# ✅ Fetched: P41223
# ✅ Fetched: Q9Z0G0
# ✅ Fetched: Q9D7S9
# ✅ Fetched: P12246
# ✅ Fetched: Q8BYH7
# ✅ Fetched: Q9D937
# ✅ Fetched: Q8VDL4
# ✅ Fetched: P62191
# ✅ Fetched: Q6NXI6
# ✅ Fetched: P51943
# ✅ Fetched: P01867
# ✅ Fetched: P01863
# ✅ Fetched: O35988
# ✅ Fetched: P13864
# ✅ Fetched: Q8BT60
# ✅ Fetched: Q9CPQ8
# ✅ Fetched: P31725
# ✅ Fetched: Q9D2V7
# ✅ Fetched: Q8CHC4
# ✅ Fetched: Q9DCI9
# ✅ Fetched: P23927
# ✅ Fetched: P31001
# ✅ Fetched: A2AN08
# ✅ Fetched: Q9ESZ8
# ✅ Fetched: Q80YR5
# ✅ Fetched: Q8C9B9
# ✅ Fetched: Q8VHE0
# ✅ Fetched: Q6PGF3
# ✅ Fetched: P11157
# ✅ Fetched: Q61152
# ✅ Fetched: P54751
# ✅ Fetched: Q8K2K6
# ✅ Fetched: Q8BX70
# ✅ Fetched: Q9EQQ9
# ✅ Fetched: Q13685
# ✅ Fetched: Q9WV91
# ✅ Fetched: Q61142
# ✅ Fetched: P22682
# ✅ Fetched: P35564
# ✅ Fetched: Q91W92
# ✅ Fetched: Q8K1E0
# ✅ Fetched: Q91YD3
# ✅ Fetched: Q8HWB2
# ✅ Fetched: Q4KN81
# ✅ Fetched: P01898
# ✅ Fetched: Q6PAR5
# ✅ Fetched: P17225
# ✅ Fetched: Q8BHD7
# ✅ Fetched: O70572
# ✅ Fetched: Q9JHS3
# ✅ Fetched: P47915
# ✅ Fetched: Q8CGK3
# ✅ Fetched: Q6A068
# ✅ Fetched: Q6PEB6
# ✅ Fetched: G5E829
# ✅ Fetched: P20020
# ✅ Fetched: Q9JHQ5
# ✅ Fetched: Q12905
# ✅ Fetched: Q9QWH1
# ✅ Fetched: Q9JHI5
# ✅ Fetched: Q5SSH7
# ✅ Fetched: Q8BHG2
# ✅ Fetched: Q9DBG5
# ✅ Fetched: Q02809
# ✅ Fetched: P38647
# ✅ Fetched: P38646
# ✅ Fetched: Q8BH95
# ✅ Fetched: O00443
# ✅ Fetched: Q99M87
# ✅ Fetched: Q62193
# ✅ Fetched: B9EJ54
# ✅ Fetched: P05784
# ✅ Fetched: P17879
# ✅ Fetched: P37913
# ✅ Fetched: P97449
# ✅ Fetched: Q8R0G9
# ✅ Fetched: O35345
# ✅ Fetched: D3Z6Q9
# ✅ Fetched: P62491
# ✅ Fetched: P46638
# ✅ Fetched: Q6P9N1
# ✅ Fetched: Q8VDV3
# ✅ Fetched: Q9CQN1
# ✅ Fetched: P62917
# ✅ Fetched: Q61550
# ✅ Fetched: Q923D5
# ✅ Fetched: Q8VHY0
# ✅ Fetched: Q9QWR8
# ✅ Fetched: P29699
# ✅ Fetched: O00505
# ✅ Fetched: O35344
# ✅ Fetched: E9PVX6
# ✅ Fetched: Q9R1P4
# ✅ Fetched: Q8CJG0
# ✅ Fetched: Q08024
# ✅ Fetched: O35609
# ✅ Fetched: Q8C570
# ✅ Fetched: Q9D3D9
# ✅ Fetched: Q8BXN9
# ✅ Fetched: P15508
# ✅ Fetched: Q3UEB3
# ✅ Fetched: P70280
# ✅ Fetched: Q810D6
# ✅ Fetched: Q8K2T1
# ✅ Fetched: P70349
# ✅ Fetched: Q8K2V1
# ✅ Fetched: P24452
# ✅ Fetched: Q61133
# ✅ Fetched: P13020
# ✅ Fetched: P50428
# ✅ Fetched: P05787
# ✅ Fetched: Q922U2
# ✅ Fetched: Q8BGZ7
# ✅ Fetched: O95678
# ✅ Fetched: Q3UV17
# ✅ Fetched: Q9DCV7
# ✅ Fetched: P63017
# ✅ Fetched: P54652
# ✅ Fetched: Q8K1B8
# ✅ Fetched: P21981
# ✅ Fetched: Q9DAS9
# ✅ Fetched: Q60598
# ✅ Fetched: P01029
# ✅ Fetched: A0AAQ4VMX2
# ✅ Fetched: P54823
# ✅ Fetched: Q9CYL5
# ✅ Fetched: Q9ES74
# ✅ Fetched: P0DOV2
# ✅ Fetched: Q6PIU9
# ✅ Fetched: Q05186
# ✅ Fetched: O09159
# ✅ Fetched: Q9R111
# ✅ Fetched: Q8K157
# ✅ Fetched: Q96C23
# ✅ Fetched: O88545
# ✅ Fetched: P32921
# ✅ Fetched: Q6NSR8
# ✅ Fetched: Q01768
# ✅ Fetched: P11274
# ✅ Fetched: Q8BGQ7
# ✅ Fetched: Q9QXX4
# ✅ Fetched: O55135
# ✅ Fetched: Q9JLT4
# ✅ Fetched: Q6P2B1
# ✅ Fetched: Q8CFX1
# ✅ Fetched: Q8K224
# ✅ Fetched: Q9JMA1
# ✅ Fetched: P56960
# ✅ Fetched: Q06890
# ✅ Fetched: Q922J3
# ✅ Fetched: Q99K41
# ✅ Fetched: P83093
# ✅ Fetched: Q8BNV1
# ✅ Fetched: Q99JR1
# ✅ Fetched: P54310
# ✅ Fetched: Q08AF3
# ✅ Fetched: Q61739
# ✅ Fetched: Q7SIG6
# ✅ Fetched: Q8K2H4
# ✅ Fetched: P42208
# ✅ Fetched: Q91WK2
# ✅ Fetched: Q99LJ0
# ✅ Fetched: Q9DBG6
# ✅ Fetched: Q99N69
# ✅ Fetched: Q9EQH2
# ✅ Fetched: Q8VHK9
# ✅ Fetched: Q8C0T5
# ✅ Fetched: Q6P5G6
# ✅ Fetched: P07205
# ✅ Fetched: Q99K85
# ✅ Fetched: Q9Z1G4
# ✅ Fetched: P51125
# ✅ Fetched: Q9Y3Y2
# ✅ Fetched: Q15022
# ✅ Fetched: Q8CIE6
# ✅ Fetched: P53621
# ✅ Fetched: Q80X41
# ✅ Fetched: Q8R1K1
# ✅ Fetched: Q9ET22
# ✅ Fetched: Q8K0H5
# ✅ Fetched: Q9CZW5
# ✅ Fetched: P22670
# ✅ Fetched: Q99KN9
# ✅ Fetched: Q3URQ0
# ✅ Fetched: Q6ZQH8
# ✅ Fetched: Q8R574
# ✅ Fetched: Q9D0M1
# ✅ Fetched: Q9DCM0
# ✅ Fetched: Q9D6K9
# ✅ Fetched: Q5SWD9
# ✅ Fetched: Q8K1R3
# ✅ Fetched: Q922D8
# ✅ Fetched: Q3UPF5
# ✅ Fetched: Q9Z2Q5
# ✅ Fetched: Q6PR54
# ✅ Fetched: A2AAY5
# ✅ Fetched: Q91W86
# ✅ Fetched: Q9WV32
# ✅ Fetched: Q8BWW9
# ✅ Fetched: A6H6A9
# ✅ Fetched: Q9CZ44
# ✅ Fetched: Q5VT52
# ✅ Fetched: Q9DCT8
# ✅ Fetched: Q69Z38
# ✅ Fetched: Q8R4R6
# ✅ Fetched: Q9D0L8
# ✅ Fetched: Q9BVK8
# ✅ Fetched: P34884
# ✅ Fetched: Q8TEA8
# ✅ Fetched: P28654
# ✅ Fetched: Q8C2Q3
# ✅ Fetched: Q60631
# ✅ Fetched: O88738
# ✅ Fetched: P16627
# ✅ Fetched: P17066
# ✅ Fetched: P57776
# ✅ Fetched: Q99L04
# ✅ Fetched: Q8BVK9
# ✅ Fetched: P35700
# ✅ Fetched: Q06830
# ✅ Fetched: P25789
# ✅ Fetched: P58771
# ✅ Fetched: P07951
# ✅ Fetched: Q6NXL1
# ✅ Fetched: Q9D7X3
# ✅ Fetched: Q6ZPE2
# ✅ Fetched: Q9ER00
# ✅ Fetched: P97310
# ✅ Fetched: O54724
# ✅ Fetched: P70195
# ✅ Fetched: P34914
# ✅ Fetched: D3YWT1
# ✅ Fetched: P70333
# ✅ Fetched: O35737
# ✅ Fetched: Q9Z2X1
# ✅ Fetched: Q8VI75
# ✅ Fetched: Q8K3K7
# ✅ Fetched: Q61599
# ✅ Fetched: Q8CDM1
# ✅ Fetched: P46940
# ✅ Fetched: Q14978
# ✅ Fetched: Q8C7Q4
# ✅ Fetched: P69566
# ✅ Fetched: Q6VN19
# ✅ Fetched: P51149
# ✅ Fetched: O08739
# ✅ Fetched: Q6R0H7
# ✅ Fetched: Q3TNL8
# ✅ Fetched: Q8BI72
# ✅ Fetched: Q9QYR9
# ✅ Fetched: Q3TBD2
# ✅ Fetched: P52196
# ✅ Fetched: Q9D0I8
# ✅ Fetched: Q99MD9
# ✅ Fetched: Q91V12
# ✅ Fetched: O00154
# ✅ Fetched: Q9JIF0
# ✅ Fetched: Q07076
# ✅ Fetched: O35955
# ✅ Fetched: Q14677
# ✅ Fetched: Q76LS9
# ✅ Fetched: P26323
# ✅ Fetched: Q99ME2
# ✅ Fetched: O14950
# ✅ Fetched: P24844
# ✅ Fetched: Q8CIM8
# ✅ Fetched: Q6PAL7
# ✅ Fetched: Q7M6Y3
# ✅ Fetched: Q9R0A0
# ✅ Fetched: Q9D753
# ✅ Fetched: O14910
# ✅ Fetched: P0C872
# ✅ Fetched: Q9CQ71
# ✅ Fetched: Q9CQA0
# ✅ Fetched: P70460
# ✅ Fetched: P61981
# ✅ Fetched: P55065
# ✅ Fetched: Q9DCA2
# ✅ Fetched: O14981
# ✅ Fetched: P50136
# ✅ Fetched: Q9D964
# ✅ Fetched: Q99LD9
# ✅ Fetched: P62195
# ✅ Fetched: Q8VCR7
# ✅ Fetched: Q3UMC0
# ✅ Fetched: Q9DB77
# ✅ Fetched: Q505D1
# ✅ Fetched: A6H611
# ✅ Fetched: P46467
# ✅ Fetched: Q99LB2
# ✅ Fetched: Q8BJW6
# ✅ Fetched: P51437
# ✅ Fetched: P62906
# ✅ Fetched: P47911
# ✅ Fetched: P70441
# ✅ Fetched: Q9QY81
# ✅ Fetched: Q07797
# ✅ Fetched: Q9JHP7
# ✅ Fetched: P56399
# ✅ Fetched: Q8VHL1
# ✅ Fetched: Q9CX11
# ✅ Fetched: E9Q1F5
# ✅ Fetched: Q8C547
# ✅ Fetched: Q8R3C0
# ✅ Fetched: A2A863
# ✅ Fetched: P23116
# ✅ Fetched: P35278
# ✅ Fetched: Q9DBR0
# ✅ Fetched: Q3UDK1
# ✅ Fetched: Q6ZQ08
# ✅ Fetched: Q80TL7
# ✅ Fetched: Q7Z3U7
# ✅ Fetched: P51855
# ✅ Fetched: Q9R0C0
# ✅ Fetched: Q9CXT8
# ✅ Fetched: P32020
# ✅ Fetched: Q3UPY5
# ✅ Fetched: Q99LM2
# ✅ Fetched: Q9D7A6
# ✅ Fetched: P56812
# ✅ Fetched: Q7TSH6
# ✅ Fetched: P58281
# ✅ Fetched: O35250
# ✅ Fetched: P47856
# ✅ Fetched: Q99J45
# ✅ Fetched: P58854
# ✅ Fetched: Q9CPT3
# ✅ Fetched: Q00519
# ✅ Fetched: Q3UMB9
# ✅ Fetched: Q9D1A2
# ✅ Fetched: Q3TIU4
# ✅ Fetched: Q53EL6
# ✅ Fetched: A6H5Y3
# ✅ Fetched: Q3V1T4
# ✅ Fetched: P61513
# ✅ Fetched: Q60960
# ✅ Fetched: O35343
# ✅ Fetched: Q5SQX6
# ✅ Fetched: Q5SW19
# ✅ Fetched: Q3U898
# ✅ Fetched: Q9CSH3
# ✅ Fetched: Q8C7V3
# ✅ Fetched: P54707
# ✅ Fetched: Q9CVB6
# ✅ Fetched: Q8BWU5
# ✅ Fetched: Q9D1M7
# ✅ Fetched: G3X972
# ✅ Fetched: Q8R1G2
# ✅ Fetched: Q8CCP0
# ✅ Fetched: O60524
# ✅ Fetched: P59108
# ✅ Fetched: Q8C052
# ✅ Fetched: P82664
# ✅ Fetched: Q03734
# ✅ Fetched: Q91WP6
# ✅ Fetched: Q99LB6
# ✅ Fetched: P18760
# ✅ Fetched: P06745
# ✅ Fetched: Q9QXG2
# ✅ Fetched: P83887
# ✅ Fetched: Q9NRH3
# ✅ Fetched: Q9Z0P5
# ✅ Fetched: Q8C0D5
# ✅ Fetched: Q99LB0
# ✅ Fetched: P22599
# ✅ Fetched: Q00896
# ✅ Fetched: P60487
# ✅ Fetched: Q8BFP9
# ✅ Fetched: Q8BH61
# ✅ Fetched: Q61578
# ✅ Fetched: Q6ZPU9
# ✅ Fetched: O35892
# ✅ Fetched: Q99747
# ✅ Fetched: P00920
# ✅ Fetched: Q6NVF9
# ✅ Fetched: Q8BFV2
# ✅ Fetched: Q8BTV2
# ✅ Fetched: P70362
# ✅ Fetched: Q3UZA1
# ✅ Fetched: Q9D4H8
# ✅ Fetched: Q8VE18
# ✅ Fetched: Q9D710
# ✅ Fetched: P68510
# ✅ Fetched: Q04917
# ✅ Fetched: P68254
# ✅ Fetched: Q9CQV8
# ✅ Fetched: Q9CRB6
# ✅ Fetched: E9Q557
# ✅ Fetched: P15924
# ✅ Fetched: Q921F4
# ✅ Fetched: Q60590
# ✅ Fetched: P07361
# ✅ Fetched: Q52KI8
# ✅ Fetched: A1Z198
# ✅ Fetched: Q6UXN9
# ✅ Fetched: Q08879
# ✅ Fetched: P14602
# ✅ Fetched: Q9QZE7
# ✅ Fetched: F8VPN4
# ✅ Fetched: P47758
# ✅ Fetched: O54974
# ✅ Fetched: P62814
# ✅ Fetched: Q922V4
# ✅ Fetched: Q8CHP8
# ✅ Fetched: Q9D708
# ✅ Fetched: E9Q236
# ✅ Fetched: O08911
# ✅ Fetched: O88587
# ✅ Fetched: B2RX12
# ✅ Fetched: Q9D1R2
# ✅ Fetched: O75915
# ✅ Fetched: Q8BHB4
# ✅ Fetched: Q571I9
# ✅ Fetched: Q60967
# ✅ Fetched: Q69ZX6
# ✅ Fetched: Q8BTX9
# ✅ Fetched: O14874
# ✅ Fetched: Q61598
# ✅ Fetched: Q8K4L3
# ✅ Fetched: Q8CCJ3
# ✅ Fetched: Q9DCS9
# ✅ Fetched: Q9WTP7
# ✅ Fetched: O35640
# ✅ Fetched: Q9CX56
# ✅ Fetched: Q8CGA0
# ✅ Fetched: Q3V0K9
# ✅ Fetched: A0A1Y7VJE9
# ✅ Fetched: J3QNT6
# ✅ Fetched: P47813
# ✅ Fetched: Q8BTU1
# ✅ Fetched: Q8C147
# ✅ Fetched: Q8R1A4
# ✅ Fetched: Q64213
# ✅ Fetched: Q99LT0
# ✅ Fetched: Q8BH74
# ✅ Fetched: Q99P72
# ✅ Fetched: Q80X82
# ✅ Fetched: P70671
# ✅ Fetched: P97363
# ✅ Fetched: P55769
# ✅ Fetched: B2RQG2
# ✅ Fetched: Q8CEC0
# ✅ Fetched: P35831
# ✅ Fetched: Q8CGC7
# ✅ Fetched: Q8BGS0
# ✅ Fetched: Q8TBZ6
# ✅ Fetched: O54962
# ✅ Fetched: P28653
# ✅ Fetched: Q8VEE0
# ✅ Fetched: Q9ERE7
# ✅ Fetched: P06800
# ✅ Fetched: Q9DCH2
# ✅ Fetched: P50429
# ✅ Fetched: Q91VH6
# ✅ Fetched: Q4KML4
# ✅ Fetched: P08071
# ✅ Fetched: O75874
# ✅ Fetched: E9Q137
# ✅ Fetched: O55142
# ✅ Fetched: Q7TNB8
# ✅ Fetched: Q04750
# ✅ Fetched: P11387
# ✅ Fetched: Q99JW4
# ✅ Fetched: P61224
# ✅ Fetched: O95716
# ✅ Fetched: Q8BFZ3
# ✅ Fetched: Q562R1
# ✅ Fetched: Q9Z2I9
# ✅ Fetched: Q91W59
# ✅ Fetched: P19253
# ✅ Fetched: O70194
# ✅ Fetched: A2AWA9
# ✅ Fetched: Q9Y3P9
# ✅ Fetched: Q9CX86
# ✅ Fetched: Q99KF1
# ✅ Fetched: Q8R1V4
# ✅ Fetched: Q8R016
# ✅ Fetched: Q8BM96
# ✅ Fetched: P67936
# ✅ Fetched: P62633
# ✅ Fetched: P31266
# ✅ Fetched: O08573
# ✅ Fetched: Q9R0K7
# ✅ Fetched: P60510
# ✅ Fetched: Q9CQA3
# ✅ Fetched: P62244
# ✅ Fetched: P28862
# ✅ Fetched: Q9Z1N5
# ✅ Fetched: P31949
# ✅ Fetched: P70663
# ✅ Fetched: Q91V83
# ✅ Fetched: Q9QZB7
# ✅ Fetched: Q86US8
# ✅ Fetched: Q8BVU5
# ✅ Fetched: Q9CZ04
# ✅ Fetched: Q14980
# ✅ Fetched: Q9R0P5
# ✅ Fetched: P70336
# ✅ Fetched: Q8CC35
# ✅ Fetched: P19639
# ✅ Fetched: Q8R1B4
# ✅ Fetched: P17751
# ✅ Fetched: O70492
# ✅ Fetched: Q91YU8
# ✅ Fetched: D3Z2H9
# ✅ Fetched: Q6P5F9
# ✅ Fetched: P97452
# ✅ Fetched: Q6P069
# ✅ Fetched: Q923D2
# ✅ Fetched: Q3UGS4
# ✅ Fetched: Q99N92
# ✅ Fetched: Q8VDW0
# ✅ Fetched: O00148
# ✅ Fetched: P10639
# ✅ Fetched: Q922Q4
# ✅ Fetched: Q922W5
# ✅ Fetched: Q7Z406
# ✅ Fetched: Q5SX39
# ✅ Fetched: Q9UKX3
# ✅ Fetched: A2AQP0
# ✅ Fetched: Q8BU30
# ✅ Fetched: P62306
# ✅ Fetched: Q91ZW3
# ✅ Fetched: Q8R1Q8
# ✅ Fetched: Q6PDL0
# ✅ Fetched: Q3UE37
# ✅ Fetched: P62280
# ✅ Fetched: Q8VDD9
# ✅ Fetched: Q09014
# ✅ Fetched: Q8C0E3
# ✅ Fetched: P11117
# ✅ Fetched: Q99JR5
# ✅ Fetched: P97822
# ✅ Fetched: Q13185
# ✅ Fetched: P45973
# ✅ Fetched: P83916
# ✅ Fetched: Q3UFY7
# ✅ Fetched: P46460
# ✅ Fetched: Q61554
# ✅ Fetched: Q8K4P0
# ✅ Fetched: Q91WJ8
# ✅ Fetched: Q3ULW8
# ✅ Fetched: Q8C7R4
# ✅ Fetched: P21619
# ✅ Fetched: Q9D2C2
# ✅ Fetched: Q9WU78
# ✅ Fetched: Q13526
# ✅ Fetched: Q9JL16
# ✅ Fetched: Q69ZA1
# ✅ Fetched: P52624
# ✅ Fetched: P07742
# ✅ Fetched: Q91X72
# ✅ Fetched: P21291
# ✅ Fetched: P36552
# ✅ Fetched: Q9BTC8
# ✅ Fetched: Q924K8
# ✅ Fetched: Q15654
# ✅ Fetched: Q9CZD3
# ✅ Fetched: Q8R1G6
# ✅ Fetched: Q9R190
# ✅ Fetched: Q8K4B0
# ✅ Fetched: Q922D4
# ✅ Fetched: P30050
# ✅ Fetched: Q80ZX0
# ✅ Fetched: O95486
# ✅ Fetched: Q3U2P1
# ✅ Fetched: Q99KI0
# ✅ Fetched: Q6WVG3
# ✅ Fetched: Q9CZN8
# ✅ Fetched: O09106
# ✅ Fetched: Q15024
# ✅ Fetched: Q9WVA3
# ✅ Fetched: Q9WV55
# ✅ Fetched: Q9P0L0
# ✅ Fetched: P26443
# ✅ Fetched: Q9Z0S1
# ✅ Fetched: Q922Q1
# ✅ Fetched: Q8CD92
# ✅ Fetched: Q6P3X3
# ✅ Fetched: P60766
# ✅ Fetched: P84095
# ✅ Fetched: P15153
# ✅ Fetched: Q8C0C7
# ✅ Fetched: P62962
# ✅ Fetched: Q1HFZ0
# ✅ Fetched: Q08J23
# ✅ Fetched: Q9ESD7
# ✅ Fetched: Q8VDQ8
# ✅ Fetched: Q8CBY8
# ✅ Fetched: Q8VBW6
# ✅ Fetched: A2AGT5
# ✅ Fetched: Q8NBU5
# ✅ Fetched: Q9R269
# ✅ Fetched: P46061
# ✅ Fetched: O88447
# ✅ Fetched: P58021
# ✅ Fetched: O35326
# ✅ Fetched: P23591
# ✅ Fetched: Q8CC86
# ✅ Fetched: Q9CWQ0
# ✅ Fetched: Q9R0U0
# ✅ Fetched: Q01130
# ✅ Fetched: Q921M7
# ✅ Fetched: Q91W61
# ✅ Fetched: P40201
# ✅ Fetched: O14646
# ✅ Fetched: Q9DCD0
# ✅ Fetched: Q9ER38
# ✅ Fetched: P14824
# ✅ Fetched: P46977
# ✅ Fetched: Q9BTA9
# ✅ Fetched: Q9JII6
# ✅ Fetched: O35218
# ✅ Fetched: Q60591
# ✅ Fetched: P16474
# ✅ Fetched: Q4FK66
# ✅ Fetched: O55126
# ✅ Fetched: O75323
# ✅ Fetched: O55125
# ✅ Fetched: Q13107
# ✅ Fetched: Q9CWX4
# ✅ Fetched: Q8QZV7
# ✅ Fetched: Q61239
# ✅ Fetched: P62330
# ✅ Fetched: Q9EPB4
# ✅ Fetched: P24270
# ✅ Fetched: Q8BHZ0
# ✅ Fetched: P25189
# ✅ Fetched: Q6ZWR6
# ✅ Fetched: Q571H0
# ✅ Fetched: P23949
# ✅ Fetched: Q9DCJ9
# ✅ Fetched: P03987
# ✅ Fetched: Q8CG19
# ✅ Fetched: Q86W92
# ✅ Fetched: O35459
# ✅ Fetched: Q925B0
# ✅ Fetched: P62701
# ✅ Fetched: P22090
# ✅ Fetched: Q8BYW1
# ✅ Fetched: Q8BW10
# ✅ Fetched: O35639
# ✅ Fetched: Q3TC93
# ✅ Fetched: Q99L45
# ✅ Fetched: O35075
# ✅ Fetched: Q8BIK4
# ✅ Fetched: P58929
# ✅ Fetched: P84084
# ✅ Fetched: P61204
# ✅ Fetched: P48453
# ✅ Fetched: Q9R1P1
# ✅ Fetched: Q61595
# ✅ Fetched: Q86UP2
# ✅ Fetched: P62805
# ✅ Fetched: Q9UEW8
# ✅ Fetched: O35841
# ✅ Fetched: O55234
# ✅ Fetched: Q9QUH0
# ✅ Fetched: Q8K2Y9
# ✅ Fetched: Q9EPL9
# ✅ Fetched: O88512
# ✅ Fetched: Q9R0E1
# ✅ Fetched: Q9R059
# ✅ Fetched: P35442
# ✅ Fetched: P27641
# ✅ Fetched: P14211
# ✅ Fetched: P46935
# ✅ Fetched: Q7TSI3
# ✅ Fetched: Q9WVA4
# ✅ Fetched: Q9CQI6
# ✅ Fetched: P01904
# ✅ Fetched: O55201
# ✅ Fetched: G3UYY4
# ✅ Fetched: Q9D1K2
# ✅ Fetched: Q8BXZ1
# ✅ Fetched: Q9H3S7
# ✅ Fetched: P51432
# ✅ Fetched: P50518
# ✅ Fetched: Q6ZQL4
# ✅ Fetched: O08709
# ✅ Fetched: Q8K3G5
# ✅ Fetched: Q8K310
# ✅ Fetched: Q9ERI5
# ✅ Fetched: Q8VEK0
# ✅ Fetched: Q9D1Q6
# ✅ Fetched: Q9D855
# ✅ Fetched: Q80TZ9
# ✅ Fetched: B2RXC1
# ✅ Fetched: P29391
# ✅ Fetched: A2ALS5
# ✅ Fetched: P09528
# ✅ Fetched: P26645
# ✅ Fetched: Q921T2
# ✅ Fetched: Q60692
# ✅ Fetched: Q8VBV3
# ✅ Fetched: O54931
# ✅ Fetched: P33609
# ✅ Fetched: P19324
# ✅ Fetched: Q9QY06
# ✅ Fetched: Q8BH04
# ✅ Fetched: Q6P9Q6
# ✅ Fetched: Q8R361
# ✅ Fetched: Q60972
# ✅ Fetched: Q8VHC3
# ✅ Fetched: Q61553
# ✅ Fetched: Q61937
# ✅ Fetched: P51410
# ✅ Fetched: P70257
# ✅ Fetched: D3YU81
# ✅ Fetched: Q4FJU9
# ✅ Fetched: Q9ES00
# ✅ Fetched: Q8CI75
# ✅ Fetched: Q5SWU9
# ✅ Fetched: A2A6A1
# ✅ Fetched: P46938
# ✅ Fetched: Q9DCE5
# ✅ Fetched: Q8C5N3
# ✅ Fetched: Q80Y81
# ✅ Fetched: A2BH40
# ✅ Fetched: P47757
# ✅ Fetched: Q6A065
# ✅ Fetched: P49591
# ✅ Fetched: Q9CQ49
# ✅ Fetched: P56589
# ✅ Fetched: Q6AXC6
# ✅ Fetched: Q99LD8
# ✅ Fetched: Q9D666
# ✅ Fetched: P08103
# ✅ Fetched: Q02788
# ✅ Fetched: Q62178
# ✅ Fetched: Q60875
# ✅ Fetched: Q8R0X7
# ✅ Fetched: Q7TT37
# ✅ Fetched: Q61247
# ✅ Fetched: P97855
# ✅ Fetched: Q8BK72
# ✅ Fetched: P21956
# ✅ Fetched: Q3UVK0
# ✅ Fetched: Q9D2N9
# ✅ Fetched: P29452
# ✅ Fetched: Q7L2H7
# ✅ Fetched: O88379
# ✅ Fetched: Q8R3V5
# ✅ Fetched: Q4VAE3
# ✅ Fetched: Q99MJ9
# ✅ Fetched: Q9UHD2
# ✅ Fetched: A2ASQ1
# ✅ Fetched: Q62167
# ✅ Fetched: Q9H2M9
# ✅ Fetched: Q8VDS8
# ✅ Fetched: P14685
# ✅ Fetched: Q9CPU0
# ✅ Fetched: P63173
# ✅ Fetched: P49290
# ✅ Fetched: O43447
# ✅ Fetched: Q9D0W5
# ✅ Fetched: Q99JR8
# ✅ Fetched: Q8CI94
# ✅ Fetched: Q9R118
# ✅ Fetched: P08003
# ✅ Fetched: Q9DCT2
# ✅ Fetched: Q9JK53
# ✅ Fetched: Q8CFE3
# ✅ Fetched: C0HKD8
# ✅ Fetched: O35129
# ✅ Fetched: Q99L13
# ✅ Fetched: Q9D5V5
# ✅ Fetched: P70699
# ✅ Fetched: Q91XI1
# ✅ Fetched: P02089
# ✅ Fetched: P02088
# ✅ Fetched: Q8BMK4
# ✅ Fetched: P10630
# ✅ Fetched: P60842
# ✅ Fetched: Q3TVI8
# ✅ Fetched: Q9EPQ7
# ✅ Fetched: P28776
# ✅ Fetched: Q60767
# ✅ Fetched: Q9WUR2
# ✅ Fetched: Q00623
# ✅ Fetched: P47740
# ✅ Fetched: Q99KV1
# ✅ Fetched: P97311
# ✅ Fetched: P37040
# ✅ Fetched: P30876
# ✅ Fetched: Q9WVL3
# ✅ Fetched: Q6PF93
# ✅ Fetched: P04117
# ✅ Fetched: Q99MS7
# ✅ Fetched: P30101
# ✅ Fetched: Q8C092
# ✅ Fetched: Q15542
# ✅ Fetched: P58242
# ✅ Fetched: Q9Z0X1
# ✅ Fetched: P54923
# ✅ Fetched: Q3UBZ5
# ✅ Fetched: Q68FL4
# ✅ Fetched: Q8R3W5
# ✅ Fetched: Q8C1D8
# ✅ Fetched: Q9D0R9
# ✅ Fetched: Q9R1P3
# ✅ Fetched: Q9WTI7
# ✅ Fetched: Q15417
# ✅ Fetched: Q80VP1
# ✅ Fetched: Q9H254
# ✅ Fetched: E9PX29
# ✅ Fetched: Q3UGR5
# ✅ Fetched: Q8BZW8
# ✅ Fetched: Q00612
# ✅ Fetched: Q9CZU6
# ✅ Fetched: Q53QV2
# ✅ Fetched: Q9D0B0
# ✅ Fetched: Q9D967
# ✅ Fetched: O60884
# ✅ Fetched: P0DP26
# ✅ Fetched: Q61655
# ✅ Fetched: P08121
# ✅ Fetched: Q99LE6
# ✅ Fetched: P36371
# ✅ Fetched: Q07113
# ✅ Fetched: P20152
# ✅ Fetched: Q9ESE1
# ✅ Fetched: P10126
# ✅ Fetched: Q9CR16
# ✅ Fetched: Q08752
# ✅ Fetched: P61964
# ✅ Fetched: Q80TR8
# ✅ Fetched: P28076
# ✅ Fetched: Q8K3X4
# ✅ Fetched: Q8R0F6
# ✅ Fetched: Q9JJL8
# ✅ Fetched: P70677
# ✅ Fetched: P28665
# ✅ Fetched: P83741
# ✅ Fetched: Q8VCM8
# ✅ Fetched: Q60772
# ✅ Fetched: P39654
# ✅ Fetched: Q8BH57
# ✅ Fetched: P08228
# ✅ Fetched: P62829
# ✅ Fetched: Q8CBA2
# ✅ Fetched: P58137
# ✅ Fetched: Q9JKB3
# ✅ Fetched: Q7TSV4
# ✅ Fetched: P62826
# ✅ Fetched: Q61820
# ✅ Fetched: Q9CQR2
# ✅ Fetched: P63037
# ✅ Fetched: Q9CPP0
# ✅ Fetched: Q9DBH5
# ✅ Fetched: P09103
# ✅ Fetched: Q8BP47
# ✅ Fetched: O43776
# ✅ Fetched: Q80U44
# ✅ Fetched: Q3TLH4
# ✅ Fetched: Q9BRJ7
# ✅ Fetched: E9Q9G1
# ✅ Fetched: Q6P3D0
# ✅ Fetched: P11247
# ✅ Fetched: P05164
# ✅ Fetched: Q99M28
# ✅ Fetched: P33610
# ✅ Fetched: Q9CWS0
# ✅ Fetched: Q3UVG3
# ✅ Fetched: Q62446
# ✅ Fetched: Q9DBS5
# ✅ Fetched: P63279
# ✅ Fetched: P25206
# ✅ Fetched: Q62318
# ✅ Fetched: O60238
# ✅ Fetched: P32233
# ✅ Fetched: Q91YK2
# ✅ Fetched: Q61830
# ✅ Fetched: Q8VDG3
# ✅ Fetched: Q6PGH2
# ✅ Fetched: Q9Z2X2
# ✅ Fetched: P47753
# ✅ Fetched: P63167
# ✅ Fetched: Q9JJU8
# ✅ Fetched: Q9D554
# ✅ Fetched: Q9CWG9
# ✅ Fetched: P23229
# ✅ Fetched: P70399
# ✅ Fetched: Q8C8N2
# ✅ Fetched: P97369
# ✅ Fetched: Q5SWW4
# ✅ Fetched: P63101
# ✅ Fetched: P51553
# ✅ Fetched: Q13503
# ✅ Fetched: Q9WUD1
# ✅ Fetched: Q9D6J6
# ✅ Fetched: Q3UMF0
# ✅ Fetched: P35527
# ✅ Fetched: P38919
# ✅ Fetched: Q3T9E4
# ✅ Fetched: Q91X20
# ✅ Fetched: Q9D8U0
# ✅ Fetched: Q6A026
# ✅ Fetched: Q29RF7
# ✅ Fetched: P54071
# ✅ Fetched: P48735
# ✅ Fetched: P33240
# ✅ Fetched: Q8BIQ5
# ✅ Fetched: Q8C7E9
# ✅ Fetched: Q3V3R4
# ✅ Fetched: Q9D3U0
# ✅ Fetched: Q8BHL5
# ✅ Fetched: Q8BPU7
# ✅ Fetched: Q96JJ3
# ✅ Fetched: G5E897
# ✅ Fetched: P16015
# ✅ Fetched: Q8N752
# ✅ Fetched: Q8R3I3
# ✅ Fetched: G5E8Q8
# ✅ Fetched: Q99M31
# ✅ Fetched: Q8VE38
# ✅ Fetched: A2A5R2
# ✅ Fetched: Q60759
# ✅ Fetched: Q9DBN5
# ✅ Fetched: P14131
# ✅ Fetched: Q9D8Y7
# ✅ Fetched: O08848
# ✅ Fetched: Q9BDB7
# ✅ Fetched: Q9CXR1
# ✅ Fetched: P49902
# ✅ Fetched: Q8BQM4
# ✅ Fetched: P62753
# ✅ Fetched: Q9Z247
# ✅ Fetched: Q9CZX0
# ✅ Fetched: Q9CQC8
# ✅ Fetched: P47754
# ✅ Fetched: Q8CG47
# ✅ Fetched: Q8CI11
# ✅ Fetched: P62854
# ✅ Fetched: Q13573
# ✅ Fetched: P08113
# ✅ Fetched: Q92598
# ✅ Fetched: P48722
# ✅ Fetched: P15105
# ✅ Fetched: Q62422
# ✅ Fetched: O14556
# ✅ Fetched: A0A075B5N9
# ✅ Fetched: Q64518
# ✅ Fetched: Q8R429
# ✅ Fetched: O75131
# ✅ Fetched: Q86YQ8
# ✅ Fetched: Q07235
# ✅ Fetched: O35887
# ✅ Fetched: Q9Y2H0
# ✅ Fetched: Q78PY7
# ✅ Fetched: Q8BPM2
# ✅ Fetched: E9PYG6
# ✅ Fetched: O88879
# ✅ Fetched: P06151
# ✅ Fetched: Q9EPC1
# ✅ Fetched: Q8VC57
# ✅ Fetched: Q61768
# ✅ Fetched: Q80UM7
# ✅ Fetched: Q06770
# ✅ Fetched: Q02819
# ✅ Fetched: Q6ZQK5
# ✅ Fetched: P56546
# ✅ Fetched: Q922K7
# ✅ Fetched: Q3THG9
# ✅ Fetched: Q8K2Z4
# ✅ Fetched: Q9EQ61
# ✅ Fetched: P70122
# ✅ Fetched: Q6ZQI3
# ✅ Fetched: A2AHR2
# ✅ Fetched: Q3UIR3
# ✅ Fetched: Q8BWZ3
# ✅ Fetched: Q8C7I4
# ✅ Fetched: Q6ZWQ0
# ✅ Fetched: Q8K0F1
# ✅ Fetched: Q99LF4
# ✅ Fetched: Q93034
# ✅ Fetched: P97864
# ✅ Fetched: P42345
# ✅ Fetched: Q14C51
# ✅ Fetched: P50851
# ✅ Fetched: Q91Z53
# ✅ Fetched: Q8C863
# ✅ Fetched: P53995
# ✅ Fetched: Q15555
# ✅ Fetched: Q80WQ2
# ✅ Fetched: Q4VBE8
# ✅ Fetched: Q04447
# ✅ Fetched: Q9CQH8
# ✅ Fetched: Q9HCJ1
# ✅ Fetched: Q8C0I1
# ✅ Fetched: Q8BYY4
# ✅ Fetched: P26516
# ✅ Fetched: Q91W39
# ✅ Fetched: Q8VEH5
# ✅ Fetched: Q9CQT1
# ✅ Fetched: P01872
# ✅ Fetched: Q91W96
# ✅ Fetched: Q14185
# ✅ Fetched: Q8C3J5
# ✅ Fetched: Q9QZN4
# ✅ Fetched: O76031
# ✅ Fetched: P63028
# ✅ Fetched: Q15349
# ✅ Fetched: P05132
# ✅ Fetched: Q9Z0L0
# ✅ Fetched: P08758
# ✅ Fetched: A3KMH1
# ✅ Fetched: Q6ZWY3
# ✅ Fetched: P42677
# ✅ Fetched: P47811
# ✅ Fetched: Q9Z0W3
# ✅ Fetched: Q9JIG7
# ✅ Fetched: P49615
# ✅ Fetched: P56565
# ✅ Fetched: Q8R322
# ✅ Fetched: Q3UMR5
# ✅ Fetched: Q86UA1
# ✅ Fetched: Q9D1D4
# ✅ Fetched: Q8NHV1
# ✅ Fetched: B2RUP2
# ✅ Fetched: P13707
# ✅ Fetched: P61160
# ✅ Fetched: Q8C4Q6
# ✅ Fetched: P00492
# ✅ Fetched: Q8K2D3
# ✅ Fetched: Q9CQV4
# ✅ Fetched: Q9JKF7
# ✅ Fetched: Q9BPZ3
# ✅ Fetched: Q3U308
# ✅ Fetched: Q9CRT8
# ✅ Fetched: E1U8D0
# ✅ Fetched: O08547
# ✅ Fetched: O88492
# ✅ Fetched: Q99JY3
# ✅ Fetched: O09012
# ✅ Fetched: A2RTH5
# ✅ Fetched: Q99PG2
# ✅ Fetched: Q6N069
# ✅ Fetched: Q6PGG2
# ✅ Fetched: Q689Z5
# ✅ Fetched: Q8K2Q0
# ✅ Fetched: Q8CAS9
# ✅ Fetched: A0A140LIF8
# ✅ Fetched: Q9QZH6
# ✅ Fetched: Q6PFD6
# ✅ Fetched: P05555
# ✅ Fetched: Q6VNB8
# ✅ Fetched: Q8CG70
# ✅ Fetched: Q8C522
# ✅ Fetched: P70665
# ✅ Fetched: Q9WVM3
# ✅ Fetched: Q569Z5
# ✅ Fetched: P07607
# ✅ Fetched: Q9D024
# ✅ Fetched: Q91VA7
# ✅ Fetched: Q62351
# ✅ Fetched: Q8QZY1
# ✅ Fetched: P62841
# ✅ Fetched: Q8BWF0
# ✅ Fetched: Q8BV66
# ✅ Fetched: Q3TBT3
# ✅ Fetched: Q64105
# ✅ Fetched: Q64261
# ✅ Fetched: O88428
# ✅ Fetched: Q9JLV5
# ✅ Fetched: Q13347
# ✅ Fetched: Q9D083
# ✅ Fetched: Q9ERA6
# ✅ Fetched: P54103
# ✅ Fetched: Q7TSS2
# ✅ Fetched: Q4PZA2
# ✅ Fetched: Q03265
# ✅ Fetched: Q64151
# ✅ Fetched: P06797
# ✅ Fetched: Q9CQW2
# ✅ Fetched: P06683
# ✅ Fetched: P60228
# ✅ Fetched: P31532
# ✅ Fetched: Q9ERS5
# ✅ Fetched: Q62048
# ✅ Fetched: Q8R2U4
# ✅ Fetched: Q8VE37
# ✅ Fetched: Q9NVW2
# ✅ Fetched: Q9D051
# ✅ Fetched: P0DOV1
# ✅ Fetched: P01831
# ✅ Fetched: Q9D020
# ✅ Fetched: Q63918
# ✅ Fetched: O70378
# ✅ Fetched: Q99KJ8
# ✅ Fetched: Q9CYH6
# ✅ Fetched: L7N257
# ✅ Fetched: P08708
# ✅ Fetched: Q5U5M8
# ✅ Fetched: Q80TN4
# ✅ Fetched: Q6UXI9
# ✅ Fetched: Q91V88
# ✅ Fetched: Q8BKS9
# ✅ Fetched: Q8TB40
# ✅ Fetched: O35074
# ✅ Fetched: O54946
# ✅ Fetched: Q6A009
# ✅ Fetched: Q9JLM4
# ✅ Fetched: Q9CY64
# ✅ Fetched: P09874
# ✅ Fetched: Q8BRF7
# ✅ Fetched: Q62376
# ✅ Fetched: Q61263
# ✅ Fetched: Q8BHL8
# ✅ Fetched: P97494
# ✅ Fetched: P48163
# ✅ Fetched: Q61189
# ✅ Fetched: Q9Z2D1
# ✅ Fetched: Q9R1T2
# ✅ Fetched: Q04207
# ✅ Fetched: Q99P88
# ✅ Fetched: Q9CR68
# ✅ Fetched: Q9JLV1
# ✅ Fetched: O54782
# ✅ Fetched: Q9JJF3
# ✅ Fetched: O35382
# ✅ Fetched: Q91Z38
# ✅ Fetched: Q6P3A8
# ✅ Fetched: Q9CYN2
# ✅ Fetched: O08602
# ✅ Fetched: Q99P30
# ✅ Fetched: Q68FM7
# ✅ Fetched: Q99KQ4
# ✅ Fetched: Q8JZX4
# ✅ Fetched: Q71LX4
# ✅ Fetched: P97821
# ✅ Fetched: Q9D6J5
# ✅ Fetched: Q99J95
# ✅ Fetched: A6H5X4
# ✅ Fetched: Q62036
# ✅ Fetched: Q5PSV9
# ✅ Fetched: P14069
# ✅ Fetched: P06703
# ✅ Fetched: P08134
# ✅ Fetched: P61586
# ✅ Fetched: P61758
# ✅ Fetched: P10605
# ✅ Fetched: O88697
# ✅ Fetched: Q9Y285
# ✅ Fetched: O54786
# ✅ Fetched: P97370
# ✅ Fetched: P08680
# ✅ Fetched: Q9JKK1
# ✅ Fetched: Q8CIB5
# ✅ Fetched: P33611
# ✅ Fetched: P55937
# ✅ Fetched: Q99KY4
# ✅ Fetched: P07758
# ✅ Fetched: Q00898
# ✅ Fetched: Q5SF07
# ✅ Fetched: Q9Y6M1
# ✅ Fetched: A2A654
# ✅ Fetched: P42225
# ✅ Fetched: Q9CXI5
# ✅ Fetched: Q8C3R1
# ✅ Fetched: Q61193
# ✅ Fetched: Q9ESX5
# ✅ Fetched: O35134
# ✅ Fetched: O95602
# ✅ Fetched: Q9QUR6
# ✅ Fetched: Q9Z280
# ✅ Fetched: P28574
# ✅ Fetched: A6NHR9
# ✅ Fetched: Q3TAQ9
# ✅ Fetched: Q8K0Q5
# ✅ Fetched: Q6NSQ9
# ✅ Fetched: O70145
# ✅ Fetched: P62277
# ✅ Fetched: P35922
# ✅ Fetched: Q96NC0
# ✅ Fetched: Q3V1V3
# ✅ Fetched: Q9Z0U1
# ✅ Fetched: A3KGB4
# ✅ Fetched: Q8R015
# ✅ Fetched: P70388
# ✅ Fetched: Q68FG2
# ✅ Fetched: P35282
# ✅ Fetched: P16045
# ✅ Fetched: Q8K4Z5
# ✅ Fetched: Q8C4Y3
# ✅ Fetched: D3Z7P3
# ✅ Fetched: Q925H1
# ✅ Fetched: Q9ESB3
# ✅ Fetched: O08992
# ✅ Fetched: Q921E6
# ✅ Fetched: Q6DFV1
# ✅ Fetched: Q9JM96
# ✅ Fetched: Q99020
# ✅ Fetched: P47941
# ✅ Fetched: Q99KW3
# ✅ Fetched: O70456
# ✅ Fetched: Q16828
# ✅ Fetched: P61294
# ✅ Fetched: P20340
# ✅ Fetched: P01837
# ✅ Fetched: P27046
# ✅ Fetched: Q9NQT8
# ✅ Fetched: O35071
# ✅ Fetched: B1AVY7
# ✅ Fetched: Q9P2P6
# ✅ Fetched: Q80TF6
# ✅ Fetched: Q8R404
# ✅ Fetched: Q9CZR2
# ✅ Fetched: Q91VM5
# ✅ Fetched: Q9R0X4
# ✅ Fetched: P09803
# ✅ Fetched: O15145
# ✅ Fetched: Q62203
# ✅ Fetched: Q8K019
# ✅ Fetched: Q9NYF8
# ✅ Fetched: P53994
# ✅ Fetched: P60866
# ✅ Fetched: O54734
# ✅ Fetched: Q91VK1
# ✅ Fetched: P24369
# ✅ Fetched: P32067
# ✅ Fetched: Q8NF91
# ✅ Fetched: Q9CX97
# ✅ Fetched: Q640N1
# ✅ Fetched: Q8BHX1
# ✅ Fetched: Q9JMF7
# ✅ Fetched: P70318
# ✅ Fetched: Q0P678
# ✅ Fetched: Q99JN2
# ✅ Fetched: Q9DCS2
# ✅ Fetched: Q6WKZ4
# ✅ Fetched: Q9D0S9
# ✅ Fetched: Q06138
# ✅ Fetched: Q9H3W5
# ✅ Fetched: Q9D1M0
# ✅ Fetched: Q9R207
# ✅ Fetched: Q3U1Y4
# ✅ Fetched: Q9D945
# ✅ Fetched: P10852
# ...
# ✅ Fetched: O88456
# ✅ Fetched: Q8BSK8
# ✅ Fetched: Q61425
# ✅ Fetched: P70288
# ✅ Fetched: Q9CPW2
# ✅ Fetched: Q86UY6
# ✅ Fetched: O88845
# ✅ Fetched: Q8K0D0
# ✅ Fetched: Q9Z1R9
# ✅ Fetched: P56135
# ✅ Fetched: P12110
# ✅ Fetched: B9EKI3
# ✅ Fetched: Q9CPR5
# ✅ Fetched: P37804
# ✅ Fetched: O08997
# ✅ Fetched: P21271
# ✅ Fetched: Q68FH4
# ✅ Fetched: O43790
# ✅ Fetched: Q9NSB2
# ✅ Fetched: P10155
# ✅ Fetched: Q6ZPY7
# ✅ Fetched: Q8BGA7
# ✅ Fetched: Q91WA6
# ✅ Fetched: Q8BMZ5
# ✅ Fetched: P49282
# ✅ Fetched: Q05048
# ✅ Fetched: Q6GV12
# ✅ Fetched: Q9NQX4
# ✅ Fetched: Q8CFE4
# ✅ Fetched: P28843
# ✅ Fetched: Q80YC5
# ✅ Fetched: Q99LC3
# ✅ Fetched: P09021
# ✅ Fetched: Q9D1P0
# ✅ Fetched: Q9ESP1
# ✅ Fetched: Q99470
# ✅ Fetched: P41236
# ✅ Fetched: Q5T0B9
# ✅ Fetched: Q922J9
# ✅ Fetched: P53564
# ✅ Fetched: O43617
# ✅ Fetched: Q3TWW8
# ✅ Fetched: Q7TS74
# ✅ Fetched: Q9CVD2
# ✅ Fetched: P60059
# ✅ Fetched: Q9JMD0
# ✅ Fetched: Q3TNH5
# ✅ Fetched: P15066
# ✅ Fetched: O14957
# ✅ Fetched: P53350
# ✅ Fetched: E9PZJ8
# ✅ Fetched: Q2UY11
# ✅ Fetched: Q3TYS2
# ✅ Fetched: Q80ZV0
# ✅ Fetched: P31786
# ✅ Fetched: O95870
# ✅ Fetched: Q80V94
# ✅ Fetched: Q99LS3
# ✅ Fetched: O15155
# ✅ Fetched: Q6A028
# ✅ Fetched: Q8R0Y8
# ✅ Fetched: Q3U3R4
# ✅ Fetched: Q8VDT9
# ✅ Fetched: Q13523
# ✅ Fetched: Q9JK92
# ✅ Fetched: O75063
# ✅ Fetched: Q4FZC9
# ✅ Fetched: Q8VCH8
# ✅ Fetched: Q8BX57
# ✅ Fetched: Q8CIV8
# ✅ Fetched: Q9Z1A1
# ✅ Fetched: Q9DBS9
# ✅ Fetched: Q9DBJ3
# ✅ Fetched: Q3UM29
# ✅ Fetched: P22366
# ✅ Fetched: O35864
# ✅ Fetched: Q921M4
# ✅ Fetched: Q61543
# ✅ Fetched: Q3UFY8
# ✅ Fetched: O88842
# ✅ Fetched: Q9CZU4
# ✅ Fetched: Q64362
# ✅ Fetched: Q922Q9
# ✅ Fetched: Q99KK9
# ✅ Fetched: Q9DB16
# ✅ Fetched: Q66JV4
# ✅ Fetched: Q8VCL2
# ✅ Fetched: Q9D0D4
# ✅ Fetched: Q9JHJ3
# ✅ Fetched: Q921V5
# ✅ Fetched: A0A075B666
# ✅ Fetched: Q8CIV2
# ✅ Fetched: A0A087WPM2
# ✅ Fetched: Q16763
# ✅ Fetched: P70188
# ✅ Fetched: Q8BTJ4
# ✅ Fetched: Q8K114
# ✅ Fetched: O43156
# ✅ Fetched: Q80YQ8
# ✅ Fetched: P52875
# ✅ Fetched: Q9D7Z3
# ✅ Fetched: Q80U38
# ✅ Fetched: Q8R2K1
# ✅ Fetched: Q8BHK9
# ✅ Fetched: B1AVZ0
# ✅ Fetched: P62324
# ✅ Fetched: Q09PK2
# ✅ Fetched: P47802
# ✅ Fetched: Q8BIW1
# ✅ Fetched: Q921C5
# ✅ Fetched: Q91WS7
# ✅ Fetched: Q9DBZ1
# ✅ Fetched: Q9CQA5
# ✅ Fetched: Q8VDM1
# ✅ Fetched: Q9D1K7
# ✅ Fetched: Q9JM14
# ✅ Fetched: Q9Z100
# ✅ Fetched: P04202
# ✅ Fetched: Q9QYS9
# ✅ Fetched: Q8BFT2
# ✅ Fetched: Q91YD9
# ✅ Fetched: Q8K2A7
# ✅ Fetched: Q15427
# ✅ Fetched: Q91VZ6
# ✅ Fetched: P41240
# ✅ Fetched: Q9CR21
# ✅ Fetched: Q9Z1Z0
# ✅ Fetched: Q05816
# ✅ Fetched: Q8VBX6
# ✅ Fetched: Q9WU79
# ✅ Fetched: P35288
# ✅ Fetched: Q8CEC6
# ✅ Fetched: A6NHN6
# ✅ Fetched: Q9CT10
# ✅ Fetched: O00178
# ✅ Fetched: Q8CI08
# ✅ Fetched: Q8CA72
# ✅ Fetched: B2RT14
# ✅ Fetched: Q504N7
# ✅ Fetched: Q62084
# ✅ Fetched: Q3UM18
# ✅ Fetched: Q5I1X5
# ✅ Fetched: Q8BTZ4
# ✅ Fetched: P11047
# ✅ Fetched: Q9D9K3
# ✅ Fetched: Q969P6
# ✅ Fetched: P97499
# ✅ Fetched: Q8JZK9
# ✅ Fetched: Q9CWN7
# ✅ Fetched: Q8QZR4
# ✅ Fetched: P52623
# ✅ Fetched: Q9WTX2
# ✅ Fetched: Q9CQT5
# ✅ Fetched: P43883
# ✅ Fetched: Q80Y44
# ✅ Fetched: Q9H6F5
# ✅ Fetched: Q3UD01
# ✅ Fetched: Q6QI06
# ✅ Fetched: Q9JJ89
# ✅ Fetched: P70295
# ✅ Fetched: Q9D7N6
# ✅ Fetched: D3Z2R5
# ✅ Fetched: Q61510
# ✅ Fetched: Q8K3W0
# ✅ Fetched: O54950
# ✅ Fetched: Q8BYU6
# ✅ Fetched: P97770
# ✅ Fetched: Q91WG2
# ✅ Fetched: P47930
# ✅ Fetched: Q62388
# ✅ Fetched: Q3TLI0
# ✅ Fetched: P49356
# ✅ Fetched: Q13546
# ✅ Fetched: Q9QYE6
# ✅ Fetched: O89079
# ✅ Fetched: Q9Z0R4
# ✅ Fetched: Q8C1E7
# ✅ Fetched: Q3UFB2
# ✅ Fetched: Q9NWK9
# ✅ Fetched: Q9Z2E1
# ✅ Fetched: O70251
# ✅ Fetched: Q8CHI8
# ✅ Fetched: Q9CQL5
# ✅ Fetched: P63208
# ✅ Fetched: Q8R2E9
# ✅ Fetched: P40818
# ✅ Fetched: Q08857
# ✅ Fetched: Q99KP3
# ✅ Fetched: Q8CF89
# ✅ Fetched: Q9WU40
# ✅ Fetched: P08508
# ✅ Fetched: Q91XX1
# ✅ Fetched: O00762
# ✅ Fetched: Q62000
# ✅ Fetched: O95573
# ✅ Fetched: Q8BQ30
# ✅ Fetched: P49840
# ✅ Fetched: Q9JK23
# ✅ Fetched: Q8CCH2
# ✅ Fetched: Q0P5X1
# ✅ Fetched: Q8VCB1
# ✅ Fetched: Q8BTY8
# ✅ Fetched: P62482
# ✅ Fetched: Q03347
# ✅ Fetched: Q8BYZ7
# ✅ Fetched: Q9D8S3
# ✅ Fetched: Q5NCE8
# ✅ Fetched: P01910
# ✅ Fetched: O88907
# ✅ Fetched: Q8K2Q9
# ✅ Fetched: O88665
# ✅ Fetched: Q7TQK5
# ✅ Fetched: Q9QUM0
# ✅ Fetched: Q8K1E6
# ✅ Fetched: Q8BVI5
# ✅ Fetched: Q8N1P7
# ✅ Fetched: Q8K3C3
# ✅ Fetched: Q3B7Z2
# ✅ Fetched: P62072
# ✅ Fetched: Q60930
# ✅ Fetched: P45880
# ✅ Fetched: Q9Y276
# ✅ Fetched: Q8K2C7
# ✅ Fetched: P49915
# ✅ Fetched: Q5S006
# ✅ Fetched: P04441
# ✅ Fetched: P97477
# ✅ Fetched: P97814
# ✅ Fetched: O35678
# ✅ Fetched: Q8BP27
# ✅ Fetched: Q9QZI8
# ✅ Fetched: P46782
# ✅ Fetched: O75460
# ✅ Fetched: Q99KI3
# ✅ Fetched: P17433
# ✅ Fetched: Q9D385
# ✅ Fetched: Q922S4
# ✅ Fetched: Q8R366
# ✅ Fetched: Q9WVF7
# ✅ Fetched: P28347
# ✅ Fetched: O95989
# ✅ Fetched: Q5Y5T1
# ✅ Fetched: Q99N16
# ✅ Fetched: Q8BG81
# ✅ Fetched: P50452
# ✅ Fetched: Q8BGS2
# ✅ Fetched: Q61846
# ✅ Fetched: Q9DB96
# ✅ Fetched: Q53FT3
# ✅ Fetched: P02689
# ✅ Fetched: Q8R3H7
# ✅ Fetched: Q3UDP0
# ✅ Fetched: Q61464
# ✅ Fetched: Q9D009
# ✅ Fetched: Q9NU22
# ✅ Fetched: Q9CQI3
# ✅ Fetched: Q2TBE6
# ✅ Fetched: P01111
# ✅ Fetched: Q99L85
# ✅ Fetched: Q9Y2D5
# ✅ Fetched: Q9JI19
# ✅ Fetched: O55033
# ✅ Fetched: P14115
# ✅ Fetched: Q02388
# ✅ Fetched: Q8WWM9
# ✅ Fetched: Q68CQ4
# ✅ Fetched: Q3UZZ4
# ✅ Fetched: Q7TN29
# ✅ Fetched: Q921N7
# ✅ Fetched: Q9DB27
# ✅ Fetched: Q9CZ83
# ✅ Fetched: Q9JJA7
# ✅ Fetched: A2ACQ1
# ✅ Fetched: Q2YDW2
# ✅ Fetched: Q9D9I4
# ✅ Fetched: P35237
# ✅ Fetched: Q810V0
# ✅ Fetched: Q99598
# ✅ Fetched: Q791T5
# ✅ Fetched: Q9CXF7
# ✅ Fetched: Q96HQ2
# ✅ Fetched: Q6T4R5
# ✅ Fetched: Q8TDP1
# ✅ Fetched: O88630
# ✅ Fetched: Q8BV49
# ✅ Fetched: G3UZV2
# ✅ Fetched: P56528
# ✅ Fetched: Q9CZH3
# ✅ Fetched: Q9D773
# ✅ Fetched: Q9EQX4
# ✅ Fetched: Q96BN2
# ✅ Fetched: O35900
# ✅ Fetched: P21460
# ✅ Fetched: O75208
# ✅ Fetched: Q15007
# ✅ Fetched: P62875
# ✅ Fetched: Q923D4
# ✅ Fetched: O88351
# ✅ Fetched: Q3URQ4
# ✅ Fetched: Q8BJ37
# ✅ Fetched: P15121
# ✅ Fetched: P51912
# ✅ Fetched: Q9JJX7
# ✅ Fetched: Q6NSQ5
# ✅ Fetched: Q13206
# ✅ Fetched: O94915
# ✅ Fetched: Q9D2Y4
# ✅ Fetched: Q91WK5
# ✅ Fetched: P25098
# ✅ Fetched: Q99J93
# ✅ Fetched: Q9R062
# ✅ Fetched: Q8K0C1
# ✅ Fetched: Q80YQ2
# ✅ Fetched: Q6P3E7
# ✅ Fetched: A0A338P7C9
# ✅ Fetched: F6PZL4
# ✅ Fetched: O70139
# ✅ Fetched: P41105
# ✅ Fetched: Q3TFQ1
# ✅ Fetched: F8VQ05
# ✅ Fetched: P78318
# ✅ Fetched: Q9CQ26
# ✅ Fetched: Q9JM13
# ✅ Fetched: P83876
# ✅ Fetched: P17439
# ✅ Fetched: Q05D32
# ✅ Fetched: Q9BVS4
# ✅ Fetched: Q8BHS3
# ✅ Fetched: Q92618
# ✅ Fetched: Q9CQZ1
# ✅ Fetched: Q8R4Y4
# ✅ Fetched: Q8CHG7
# ✅ Fetched: P06702
# ✅ Fetched: Q9CR20
# ✅ Fetched: P15531
# ✅ Fetched: Q8VCA8
# ✅ Fetched: Q8CHS8
# ✅ Fetched: Q5T1M5
# ✅ Fetched: Q9EQ08
# ✅ Fetched: Q9Z1N2
# ✅ Fetched: Q8VED5
# ✅ Fetched: P23475
# ✅ Fetched: Q8NCM8
# ✅ Fetched: Q91Z69
# ✅ Fetched: P46414
# ✅ Fetched: Q9D8U8
# ✅ Fetched: Q3UND0
# ✅ Fetched: P57105
# ✅ Fetched: Q3TBW2
# ✅ Fetched: Q7TMC8
# ✅ Fetched: Q8VBZ3
# ✅ Fetched: Q8BHN0
# ✅ Fetched: Q8R570
# ✅ Fetched: O70422
# ✅ Fetched: Q8K2Y7
# ✅ Fetched: P70347
# ✅ Fetched: P19221
# ✅ Fetched: O15347
# ✅ Fetched: Q6PCM2
# ✅ Fetched: Q99LI8
# ✅ Fetched: Q5NCF2
# ✅ Fetched: O88974
# ✅ Fetched: Q8BL97
# ✅ Fetched: Q01081
# ✅ Fetched: Q04837
# ✅ Fetched: Q9CYR0
# ✅ Fetched: Q9DAM7
# ✅ Fetched: Q8CI70
# ✅ Fetched: Q64462
# ✅ Fetched: P05412
# ✅ Fetched: Q8BND3
# ✅ Fetched: Q9CWY3
# ✅ Fetched: Q9JJA2
# ✅ Fetched: Q3UH60
# ✅ Fetched: P63313
# ✅ Fetched: Q5EBL4
# ✅ Fetched: P11032
# ✅ Fetched: Q9D7P6
# ✅ Fetched: Q9WV84
# ✅ Fetched: Q99LL5
# ✅ Fetched: Q8K057
# ✅ Fetched: Q9Z2A9
# ✅ Fetched: Q9CQ06
# ✅ Fetched: Q6PAC3
# ✅ Fetched: Q8BHC7
# ✅ Fetched: O35972
# ✅ Fetched: Q8BP40
# ✅ Fetched: P11688
# ✅ Fetched: Q64449
# ✅ Fetched: Q9CQC7
# ✅ Fetched: P35174
# ✅ Fetched: O88413
# ✅ Fetched: Q96FS4
# ✅ Fetched: P07141
# ✅ Fetched: Q6NVF4
# ✅ Fetched: A2RUB1
# ✅ Fetched: A6NF83
# ✅ Fetched: Q8BW75
# ✅ Fetched: Q9Z2E2
# ✅ Fetched: P07091
# ✅ Fetched: Q3V300
# ✅ Fetched: Q8WZB0
# ✅ Fetched: Q9UPN6
# ✅ Fetched: E9Q6J6
# ✅ Fetched: Q8K183
# ✅ Fetched: Q6PD21
# ✅ Fetched: Q6R327
# ✅ Fetched: Q9CQY5
# ✅ Fetched: O35954
# ✅ Fetched: Q99K28
# ✅ Fetched: O96028
# ✅ Fetched: P51175
# ✅ Fetched: P23242
# ✅ Fetched: P17302
# ✅ Fetched: P97450
# ✅ Fetched: Q6P9J9
# ✅ Fetched: Q91WG4
# ✅ Fetched: Q8C079
# ✅ Fetched: Q6PAV2
# ✅ Fetched: O15234
# ✅ Fetched: Q9CQJ6
# ✅ Fetched: Q60716
# ✅ Fetched: Q3LR78
# ✅ Fetched: P35762
# ✅ Fetched: Q3TLS3
# ✅ Fetched: Q3TWF6
# ✅ Fetched: O14531
# ✅ Fetched: O88939
# ✅ Fetched: Q2VPQ9
# ✅ Fetched: Q9CWU6
# ✅ Fetched: Q9CR26
# ✅ Fetched: Q91VS7
# ✅ Fetched: Q8BWB6
# ✅ Fetched: Q8BKZ9
# ✅ Fetched: Q3TN34
# ✅ Fetched: Q9CQJ8
# ✅ Fetched: O75937
# ✅ Fetched: Q9DB25
# ✅ Fetched: Q02384
# ✅ Fetched: P11609
# ✅ Fetched: P15586
# ✅ Fetched: P50637
# ✅ Fetched: Q9D1C8
# ✅ Fetched: A2A6Q5
# ✅ Fetched: Q2VIS4
# ✅ Fetched: Q8WUH2
# ✅ Fetched: P59235
# ✅ Fetched: P15535
# ✅ Fetched: Q9BTT4
# ✅ Fetched: Q9D4F8
# ✅ Fetched: Q91VC4
# ✅ Fetched: Q9DCF9
# ✅ Fetched: Q9Z2X8
# ✅ Fetched: Q9HAU0
# ✅ Fetched: Q8VBT9
# ✅ Fetched: Q8BH43
# ✅ Fetched: Q9D142
# ✅ Fetched: Q9JHS9
# ✅ Fetched: Q9BXD5
# ✅ Fetched: Q8WVC6
# ✅ Fetched: Q8QZR5
# ✅ Fetched: P53798
# ✅ Fetched: O94808
# ✅ Fetched: Q9CZ28
# ✅ Fetched: Q3U7U3
# ✅ Fetched: P70429
# ✅ Fetched: P11169
# ✅ Fetched: O55242
# ✅ Fetched: P58404
# ✅ Fetched: E9Q6B2
# ✅ Fetched: Q60876
# ✅ Fetched: Q9D2Z4
# ✅ Fetched: Q9UMX1
# ✅ Fetched: Q64459
# ✅ Fetched: O94898
# ✅ Fetched: A2AIL4
# ✅ Fetched: Q9WU62
# ✅ Fetched: Q8C569
# ✅ Fetched: F8VQB6
# ✅ Fetched: Q8BX17
# ✅ Fetched: P09813
# ✅ Fetched: Q5XJY4
# ✅ Fetched: Q8C7D2
# ✅ Fetched: Q8VCD5
# ✅ Fetched: Q6ZQK0
# ✅ Fetched: Q5SNT6
# ✅ Fetched: Q9WTQ5
# ✅ Fetched: P18572
# ✅ Fetched: Q78IK4
# ✅ Fetched: P26151
# ✅ Fetched: P98182
# ✅ Fetched: Q62371
# ✅ Fetched: Q8BGV0
# ✅ Fetched: Q9DC63
# ✅ Fetched: Q3UI43
# ✅ Fetched: Q640M1
# ✅ Fetched: Q80WQ6
# ✅ Fetched: P97390
# ✅ Fetched: Q91V09
# ✅ Fetched: Q6PB70
# ✅ Fetched: Q9WVC3
# ✅ Fetched: O08804
# ✅ Fetched: Q9D1B9
# ✅ Fetched: Q80WG5
# ✅ Fetched: O75223
# ✅ Fetched: Q9WVJ9
# ✅ Fetched: Q91YE3
# ✅ Fetched: Q9D8X0
# ✅ Fetched: Q6P8I4
# ✅ Fetched: Q9JHE7
# ✅ Fetched: P15954
# ✅ Fetched: O15116
# ✅ Fetched: Q922Y2
# ✅ Fetched: Q8QZS1
# ✅ Fetched: P61599
# ✅ Fetched: Q4V339
# ✅ Fetched: Q8BZ20
# ✅ Fetched: Q9CQA6
# ✅ Fetched: O89112
# ✅ Fetched: Q8BGU5
# ✅ Fetched: Q9Z2A5
# ✅ Fetched: Q8BUH8
# ✅ Fetched: Q9Z2C5
# ✅ Fetched: Q923L6
# ✅ Fetched: P11672
# ✅ Fetched: Q925J9
# ✅ Fetched: Q9D1F4
# ✅ Fetched: Q9D2E2
# ✅ Fetched: Q60648
# ✅ Fetched: Q3U4L8
# ✅ Fetched: Q9WU84
# ✅ Fetched: P31152
# ✅ Fetched: Q99N57
# ✅ Fetched: Q8K1T1
# ✅ Fetched: Q99LE1
# ✅ Fetched: Q922P8
# ✅ Fetched: Q9D0K0
# ✅ Fetched: Q80V24
# ✅ Fetched: Q8JZP9
# ✅ Fetched: Q7TPE5
# ✅ Fetched: Q8BUE4
# ✅ Fetched: Q8R0F3
# ✅ Fetched: P59242
# ✅ Fetched: Q9Z2A0
# ✅ Fetched: Q6ZQA6
# ✅ Fetched: A2AJI0
# ✅ Fetched: Q05020
# ✅ Fetched: O35387
# ✅ Fetched: Q8CDG3
# ✅ Fetched: Q99LJ7
# ✅ Fetched: Q6PGF7
# ✅ Fetched: Q5SRX1
# ✅ Fetched: A6X919
# ✅ Fetched: Q9CQ13
# ✅ Fetched: P16254
# ✅ Fetched: Q0HA38
# ✅ Fetched: Q8BK75
# ✅ Fetched: Q8R0F8
# ✅ Fetched: O35711
# ✅ Fetched: Q9D0J8
# ✅ Fetched: Q9DC33
# ✅ Fetched: Q9QZ23
# ✅ Fetched: Q92831
# ✅ Fetched: Q9WTK3
# ✅ Fetched: P52655
# ✅ Fetched: P06240
# ✅ Fetched: P99025
# ✅ Fetched: Q9UBX5
# ✅ Fetched: Q3UP87
# ✅ Fetched: B1AQJ2
# ✅ Fetched: Q9QYF9
# ✅ Fetched: Q5D862
# ✅ Fetched: O09164
# ✅ Fetched: Q91ZW2
# ✅ Fetched: Q9CQM5
# ✅ Fetched: Q3TP92
# ✅ Fetched: Q61362
# ✅ Fetched: A2A7S8
# ✅ Fetched: O08600
# ✅ Fetched: Q78PG9
# ✅ Fetched: Q9WV34
# ✅ Fetched: O08811
# ✅ Fetched: Q8K2G4
# ✅ Fetched: Q9NSE4
# ✅ Fetched: O43505
# ✅ Fetched: P97304
# ✅ Fetched: Q6NZL6
# ✅ Fetched: P60330
# ✅ Fetched: Q3TAP4
# ✅ Fetched: Q6IAA8
# ✅ Fetched: Q9EP72
# ✅ Fetched: Q8BYB9
# ✅ Fetched: P05204
# ✅ Fetched: O70325
# ✅ Fetched: Q8CBY3
# ✅ Fetched: Q64695
# ✅ Fetched: Q8CG72
# ✅ Fetched: Q61592
# ✅ Fetched: E9Q735
# ✅ Fetched: Q924D0
# ✅ Fetched: Q9R0L7
# ✅ Fetched: Q7Z6K5
# ✅ Fetched: O35083
# ✅ Fetched: P24390
# ✅ Fetched: Q8TBQ9
# ✅ Fetched: Q8K1N4
# ✅ Fetched: Q9JJG9
# ✅ Fetched: Q91WC1
# ✅ Fetched: Q8K2R5
# ✅ Fetched: Q9JKC8
# ✅ Fetched: Q8C156
# ✅ Fetched: Q5QJE6
# ✅ Fetched: Q792Z1
# ✅ Fetched: Q9WUP4
# ✅ Fetched: Q08122
# ✅ Fetched: Q9ULJ7
# ✅ Fetched: Q8VEG4
# ✅ Fetched: Q9JKP7
# ✅ Fetched: Q9UM07
# ✅ Fetched: Q8VE80
# ✅ Fetched: Q8C142
# ✅ Fetched: Q69ZI1
# ✅ Fetched: Q96HR3
# ✅ Fetched: Q60949
# ✅ Fetched: Q08775
# ✅ Fetched: Q9CRW3
# ✅ Fetched: Q8R1K4
# ✅ Fetched: O95376
# ✅ Fetched: Q9JI44
# ✅ Fetched: Q9CQ40
# ✅ Fetched: P59759
# ✅ Fetched: O70279
# ✅ Fetched: O60831
# ✅ Fetched: Q9JKN1
# ✅ Fetched: Q99496
# ✅ Fetched: O75356
# ✅ Fetched: Q9ES97
# ✅ Fetched: O89050
# ✅ Fetched: Q9CQL7
# ✅ Fetched: Q922E6
# ✅ Fetched: Q9NYU1
# ✅ Fetched: Q9D1G2
# ✅ Fetched: Q9JLB0
# ✅ Fetched: P43346
# ✅ Fetched: Q9D1N9
# ✅ Fetched: Q6ZPR6
# ✅ Fetched: Q8C6E0
# ✅ Fetched: Q9H6L2
# ✅ Fetched: A2AKG8
# ✅ Fetched: Q9ESD6
# ✅ Fetched: Q8CHY6
# ✅ Fetched: P81069
# ✅ Fetched: Q8BVW0
# ✅ Fetched: Q3UJP5
# ✅ Fetched: Q78IS1
# ✅ Fetched: Q3UJ81
# ✅ Fetched: Q6ZPZ3
# ✅ Fetched: P58059
# ✅ Fetched: Q99PL7
# ✅ Fetched: P33622
# ✅ Fetched: Q8K021
# ✅ Fetched: P30355
# ✅ Fetched: Q8VDQ9
# ✅ Fetched: Q9D8N2
# ✅ Fetched: Q8VCH5
# ✅ Fetched: Q9CQ54
# ✅ Fetched: Q922H9
# ✅ Fetched: Q14AX6
# ✅ Fetched: Q8CHK3
# ✅ Fetched: Q9BZG1
# ✅ Fetched: P30837
# ✅ Fetched: P08069
# ✅ Fetched: Q9D7J9
# ✅ Fetched: P05156
# ✅ Fetched: O88968
# ✅ Fetched: P31428
# ✅ Fetched: Q923L7
# ✅ Fetched: Q64471
# ✅ Fetched: Q80U28
# ✅ Fetched: Q9QYC7
# ✅ Fetched: Q6SKR2
# ✅ Fetched: O15258
# ✅ Fetched: P20664
# ✅ Fetched: Q91V98
# ✅ Fetched: Q9D786
# ✅ Fetched: Q7TSZ8
# ✅ Fetched: Q9CS74
# ✅ Fetched: Q9WUH1
# ✅ Fetched: Q9DCV4
# ✅ Fetched: O08688
# ✅ Fetched: Q9D2P4
# ✅ Fetched: P32507
# ✅ Fetched: Q92665
# ✅ Fetched: Q8K2C9
# ✅ Fetched: P70340
# ✅ Fetched: Q8BUN5
# ✅ Fetched: Q9D7H3
# ✅ Fetched: Q8K1L5
# ✅ Fetched: Q5U462
# ✅ Fetched: F2Z461
# ✅ Fetched: Q9EQC1
# ✅ Fetched: Q8R5A3
# ✅ Fetched: Q6ZPY2
# ✅ Fetched: P10810
# ✅ Fetched: Q99P65
# ✅ Fetched: Q8BLK9
# ✅ Fetched: F8VPP8
# ✅ Fetched: Q4PJX1
# ✅ Fetched: Q9R112
# ✅ Fetched: O08734
# ✅ Fetched: Q810J8
# ✅ Fetched: Q9DCT6
# ✅ Fetched: P10922
# ✅ Fetched: Q76KJ5
# ✅ Fetched: Q9CQN6
# ✅ Fetched: Q8BJU9
# ✅ Fetched: Q9CWS4
# ✅ Fetched: O75995
# ✅ Fetched: Q08481
# ✅ Fetched: Q9D6L8
# ✅ Fetched: Q14527
# ✅ Fetched: P20918
# ✅ Fetched: Q9DB29
# ✅ Fetched: Q8VCX5
# ✅ Fetched: Q9D7E3
# ✅ Fetched: Q921W4
# ✅ Fetched: P50427
# ✅ Fetched: Q8K305
# ✅ Fetched: P58058
# ✅ Fetched: Q3TMV7
# ✅ Fetched: A3KMP2
# ✅ Fetched: Q5JWR5
# ✅ Fetched: Q9JJ66
# ✅ Fetched: Q80T85
# ✅ Fetched: Q9QZD8
# ✅ Fetched: P62838
# ✅ Fetched: P97480
# ✅ Fetched: P70387
# ✅ Fetched: P18052
# ✅ Fetched: Q9CXD9
# ✅ Fetched: Q9CQL4
# ✅ Fetched: P09925
# ✅ Fetched: Q99J47
# ✅ Fetched: O88895
# ✅ Fetched: Q99JW5
# ✅ Fetched: P26006
# ✅ Fetched: Q9QYC0
# ✅ Fetched: Q8CE96
# ✅ Fetched: P61961
# ✅ Fetched: Q7TPS5
# ✅ Fetched: Q78XF5
# ✅ Fetched: Q80YW0
# ✅ Fetched: Q8C2B3
# ✅ Fetched: E9Q2I4
# ✅ Fetched: Q6NXN1
# ✅ Fetched: Q9JLY7
# ✅ Fetched: Q921C3
# ✅ Fetched: Q91VN4
# ✅ Fetched: Q9QWF0
# ✅ Fetched: Q06180
# ✅ Fetched: D3YXK1
# ✅ Fetched: P62075
# ✅ Fetched: Q8CI15
# ✅ Fetched: O70494
# ✅ Fetched: O14907
# ✅ Fetched: Q64430
# ✅ Fetched: Q8JZV7
# ✅ Fetched: Q8R2Q8
# ✅ Fetched: Q9EQ32
# ✅ Fetched: A0AAA9WW07
# ✅ Fetched: Q91VT4
# ✅ Fetched: Q86TM3
# ✅ Fetched: Q9CQT2
# ✅ Fetched: Q8BHG9
# ✅ Fetched: Q64516
# ✅ Fetched: A2A8L5
# ✅ Fetched: Q69Z61
# ✅ Fetched: Q921Q7
# ✅ Fetched: Q9CY52
# ✅ Fetched: Q80XU3
# ✅ Fetched: O75317
# ✅ Fetched: Q5SVR0
# ✅ Fetched: Q9D787
# ✅ Fetched: Q80X32
# ✅ Fetched: Q6S5J6
# ✅ Fetched: P23611
# ✅ Fetched: Q8R2Q4
# ✅ Fetched: Q811J3
# ✅ Fetched: Q9R0M4
# ✅ Fetched: Q8BIA4
# ✅ Fetched: Q9D2R8
# ✅ Fetched: Q8BXL7
# ✅ Fetched: P38432
# ✅ Fetched: P29972
# ✅ Fetched: Q3TXU5
# ✅ Fetched: Q9P212
# ✅ Fetched: Q91WC9
# ✅ Fetched: Q8BMK1
# ✅ Fetched: Q9D958
# ✅ Fetched: P09234
# ✅ Fetched: Q6NXY1
# ✅ Fetched: Q64302
# ✅ Fetched: O95400
# ✅ Fetched: Q99LW0
# ✅ Fetched: O35166
# ✅ Fetched: Q8CGC4
# ✅ Fetched: Q8K2F8
# ✅ Fetched: P60840
# ✅ Fetched: P61009
# ✅ Fetched: Q08297
# ✅ Fetched: O35566
# ✅ Fetched: Q6NZR2
# ✅ Fetched: Q9CQF8
# ✅ Fetched: Q91VT1
# ✅ Fetched: Q8VC28
# ✅ Fetched: Q60969
# ✅ Fetched: Q9EPA7
# ✅ Fetched: O95166
# ✅ Fetched: O14925
# ✅ Fetched: Q9R020
# ✅ Fetched: Q3UN02
# ✅ Fetched: Q9CQK7
# ✅ Fetched: Q60769
# ✅ Fetched: Q14CH1
# ✅ Fetched: Q8K4F6
# ✅ Fetched: Q78WZ7
# ✅ Fetched: Q61093
# ✅ Fetched: Q9UNP4
# ✅ Fetched: P33215
# ✅ Fetched: Q6NWV3
# ✅ Fetched: P22605
# ✅ Fetched: Q80UK8
# ✅ Fetched: Q8CI33
# ✅ Fetched: P53701
# ✅ Fetched: Q60596
# ✅ Fetched: O88874
# ✅ Fetched: Q99J56
# ✅ Fetched: P12388
# 📝 Writing 697012 peptides into 14 MetaboScape-compatible files...
# ✅ metaboscape_peptides_part1.csv saved with 50000 rows
# ✅ metaboscape_peptides_part2.csv saved with 50000 rows
# ✅ metaboscape_peptides_part3.csv saved with 50000 rows
# ✅ metaboscape_peptides_part4.csv saved with 50000 rows
# ✅ metaboscape_peptides_part5.csv saved with 50000 rows
# ✅ metaboscape_peptides_part6.csv saved with 50000 rows
# ✅ metaboscape_peptides_part7.csv saved with 50000 rows
# ✅ metaboscape_peptides_part8.csv saved with 50000 rows
# ✅ metaboscape_peptides_part9.csv saved with 50000 rows
# ✅ metaboscape_peptides_part10.csv saved with 50000 rows
# ✅ metaboscape_peptides_part11.csv saved with 50000 rows
# ✅ metaboscape_peptides_part12.csv saved with 50000 rows
# ✅ metaboscape_peptides_part13.csv saved with 50000 rows
# ✅ metaboscape_peptides_part14.csv saved with 47012 rows
#
# 🎉 Digestion complete. All peptide chunks saved.

# %%
import pandas as pd
import pyopenms as oms
import csv
import math

# ----------- Step 1: Parse Local FASTA File (Whole Human Proteome) -----------
def parse_fasta(file_path):
    proteins = []
    with open(file_path, "r") as f:
        lines = f.readlines()
        name, seq = "", ""
        for line in lines:
            line = line.strip()
            if line.startswith(">"):
                if name and seq:
                    proteins.append((name, seq))
                name = line[1:]
                seq = ""
            else:
                seq += line
        if name and seq:
            proteins.append((name, seq))
    return proteins

# Path to your downloaded human proteome FASTA
fasta_file = "mcherry.fasta"
proteins = parse_fasta(fasta_file)

# ----------- Step 2: Setup Digestion Parameters -----------
digestion = oms.ProteaseDigestion()
digestion.setEnzyme("Trypsin")
digestion.setMissedCleavages(2)
min_len = 6
max_len = 40

modifications = oms.ModifiedPeptideGenerator.getModifications([b"Oxidation (M)"])

# ----------- Step 3: Digest Proteins and Prepare Peptides -----------
all_rows = []

for protein_name, protein_seq in proteins:
    try:
        aa_seq = oms.AASequence.fromString(protein_seq)
    except Exception as e:
        print(f"⚠️ Error parsing {protein_name}: {e}")
        continue

    peptides = []
    digestion.digest(aa_seq, peptides, min_len, max_len)

    modified_peptides = []
    for p in peptides:
        oms.ModifiedPeptideGenerator.applyVariableModifications(modifications, p, 1, modified_peptides, False)

    all_peptides = set([p.toString() for p in peptides] + [p.toString() for p in modified_peptides])
    all_peptides = [pep for pep in all_peptides if "X" not in pep]

    for pep_str in all_peptides:
        try:
            seq_obj = oms.AASequence.fromString(pep_str)
            formula = seq_obj.getFormula().toString()
            mass = seq_obj.getMonoWeight()
        except Exception as e:
            formula = f"Error: {e}"
            mass = ""

        name = f"{protein_name}@{pep_str}"
        row = ["", formula, name, mass, "", "", "", "", "", "", "", "", "", "", "", ""]
        all_rows.append(row)

# ----------- Step 4: Write into Chunks of 50,000 for MetaboScape -----------
chunk_size = 50000
total_parts = math.ceil(len(all_rows) / chunk_size)
output_prefix = "human_proteome_metaboscape_peptides_part"

print(f"📝 Writing {len(all_rows)} peptides into {total_parts} MetaboScape-compatible files...")

for i in range(total_parts):
    chunk = all_rows[i * chunk_size:(i + 1) * chunk_size]
    filename = f"{output_prefix}{i + 1}.csv"
    with open(filename, "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow([
            "RT", "Formula", "Name", "Mass", "CCS [M+H]+", "CCS [M+Na]+", "CCS [M-H]-",
            "KEGG", "CAS", "PubChem", "ChemSpider", "HMDB", "BioCyc",
            "Metlin", "LipidMaps", "UserID", "InChI"
        ])
        writer.writerows(chunk)
    print(f"✅ {filename} saved with {len(chunk)} rows")

print("\n🎉 Digestion complete. All peptide chunks saved.")
# Out:
# 📝 Writing 117 peptides into 1 MetaboScape-compatible files...
# ✅ human_proteome_metaboscape_peptides_part1.csv saved with 117 rows
#
# 🎉 Digestion complete. All peptide chunks saved.
